# %%
# %load_ext watermark
import datetime as dt
import pandas as pd
import numpy as np
from scipy import stats


import IPython
from PIL import Image as PILImage
from IPython.display import Markdown as md
from IPython.display import display
from myst_nb import glue

# code descriptions
dfCodes = pd.read_csv("resources/codes_with_group_names_2015.csv")

# set the index of to codes
dfCodes.set_index("code", inplace=True)

# code description map
code_d_map = dfCodes.description

# code material map
code_m_map = dfCodes.material

pdtype = pd.core.frame.DataFrame
pstype = pd.core.series.Series

def scaleTheColumn(x):
    
    xmin = x.min()
    xmax = x.max()
    xscaled = (x-xmin)/(xmax-xmin)
    
    return xscaled

def rotateText(x):
    return 'writing-mode: vertical-lr; transform: rotate(-180deg);  padding:10px; margins:0; vertical-align: baseline;'

def cleanSurveyResults(data):
    # performs data cleaning operations on the
    # default data
    
    data['loc_date'] = list(zip(data.location, data["date"]))
    data['date'] = pd.to_datetime(data["date"])
    
    # get rid of microplastics
    mcr = data[data.groupname == "micro plastics (< 5mm)"].code.unique()
    
    # replace the bad code
    data.code = data.code.replace('G207', 'G208')
    data = data[~data.code.isin(mcr)]
    
    # walensee has no landuse values
    data = data[data.water_name_slug != 'walensee']   
    
    return data

class SurveyResults:
    """Creates a dataframe from a valid filename. Assigns the column names and defines a list of
    codes and locations that can be used in the CodeData class.
    """
    
    file_name = 'resources/checked_sdata_eos_2020_21.csv'
    columns_to_keep=[
        'loc_date',
        'location', 
        'river_bassin',
        'water_name_slug',
        'city',
        'w_t', 
        'intersects', 
        'code', 
        'pcs_m',
        'quantity'
    ]
        
    def __init__(self, data: str = file_name, clean_data: bool = True, columns: list = columns_to_keep, w_t: str = None):
        self.dfx = pd.read_csv(data)
        self.df_results = None
        self.locations = None
        self.valid_codes = None
        self.clean_data = clean_data
        self.columns = columns
        self.w_t = w_t
        
    def validCodes(self):
        # creates a list of unique code values for the data set    
        conditions = [
            isinstance(self.df_results, pdtype),
            "code" in self.df_results.columns
        ]

        if all(conditions):

            try:
                valid_codes = self.df_results.code.unique()
            except ValueError:
                print("There was an error retrieving the unique code names, self.df.code.unique() failed.")
                raise
            else:
                self.valid_codes = valid_codes
                
        
    def surveyResults(self):
        
        # if this method has been called already
        # return the result
        if self.df_results is not None:
            return self.df_results
        
        # for the default data self.clean data must be called        
        if self.clean_data is True:
            fd = cleanSurveyResults(self.dfx)
            
        # if the data is clean then if can be used directly
        else:
            fd = self.dfx
        
        # filter the data by the variable w_t
        if self.w_t is not None:
            fd = fd[fd.w_t == self.w_t]            
         
        # keep only the required columns
        if self.columns:
            fd = fd[self.columns]
        
        # assign the survey results to the class attribute
        self.df_results = fd
        
        # define the list of codes in this df
        self.validCodes()
        
        return self.df_results
    
    def surveyLocations(self):
        if self.locations is not None:
            return self.locations
        if self.df_results is not None:
            self.locations = self.dfResults.location.unique()
            return self.locations
        else:
            print("There is no survey data loaded")
            return None    

# this defines the css rules for the note-book table displays
header_row = {'selector': 'th:nth-child(1)', 'props': f'background-color: #FFF;'}
even_rows = {"selector": 'tr:nth-child(even)', 'props': f'background-color: rgba(139, 69, 19, 0.08);'}
odd_rows = {'selector': 'tr:nth-child(odd)', 'props': 'background: #FFF;'}
table_font = {'selector': 'tr', 'props': 'font-size: 12px;'}
table_css_styles = [even_rows, odd_rows, table_font, header_row]

# collecting survey data
fdx = SurveyResults()
df = fdx.surveyResults()

# exclude the data from the walensee area
# inlcuding river samples
location_no_luse = [
    "linth_route9brucke",
    "seez_spennwiesenbrucke",
    "limmat_dietikon_keiserp",
    "seez"
]

city_no_luse = ["Walenstadt", "Weesen", "Glarus Nord", "Quarten"]

df = df[(~df.city.isin(city_no_luse))]
df = df[~df.location.isin(location_no_luse)]

# use the same criteria from the project results
codes = df[df.quantity > 20].code.unique()

# the intersect data
ind = pd.read_csv('resources/hex-3000m-cleaned/river-intersect-length.csv')

# merge the intersection data with the survey data
ints_and_data = df.merge(ind, on="location", how="outer")

# define the locations of interest
locations = df.location.unique()

data = ints_and_data[(ints_and_data.code.isin(codes)) & (ints_and_data.location.isin(locations))].copy()

# the number of intersects is from old map data
# it can be dropped for
data.drop("intersects", inplace=True, axis=1)

n_c_names = {
    "KLASSE": 'class',
    "NAMN": 'name',
    "BREITE": 'size',
    "water_name_slug":"feature",
}
data.rename(columns=n_c_names, inplace=True)
data.fillna(0, inplace=True)

def collectCorrelation(data, codes, columns):
    results = []
    for code in codes:
        d = data[data.code == code]
        dx = d.pcs_m.values
        for name in columns:
            dy = d[name].values            
            c, p = stats.spearmanr(dx, dy)
            results.append({"code":code, "variable":name, "rho":c, "p":p})
    return results

def resultsDf(rhovals: pdtype = None, pvals: pdtype = None)-> pdtype:
    results_df = []
    for i, n in enumerate(pvals.index):
        arow_of_ps = pvals.iloc[i]
        p_fail = arow_of_ps[ arow_of_ps > 0.05]
        arow_of_rhos = rhovals.iloc[i]
        
        for label in p_fail.index:
            arow_of_rhos[label] = 0
        results_df.append(arow_of_rhos)
    
    return results_df

def styleBufferResults(buffer_results):
    buffer_results.columns.name = None
    bfr = buffer_results.style.format(precision=2).set_table_styles(table_css_styles)
    bfr = bfr.background_gradient(axis=None, vmin=buffer_results.min().min(), vmax=buffer_results.max().max(), cmap="coolwarm")
    bfr = bfr.applymap_index(rotateText, axis=1)
    
    return bfr

def countTheNumberOfCorrelationsPerBuffer(pvals: pdtype = None, rhovals: pdtype = None) -> (pdtype, pstype):
    
    # the number of times p <= 0.05
    number_p_less_than = (pvals <= 0.05).sum()
    number_p_less_than.name = "correlated"
    
    # the number of postive correlations
    number_pos = (rhovals > 0).sum()
    number_pos.name = "positive"
    
    # the number of negative correlations
    number_neg = (rhovals < 0).sum()
    number_neg.name = "negative"

    ncorrelated = pd.DataFrame([number_p_less_than, number_pos, number_neg])
    ncorrelated["total"] = ncorrelated.sum(axis=1)
    totals = ncorrelated.total    
    
    return ncorrelated, totals

# %% [markdown]
# (distancetoriver)=
# # River discharge and lake intersections
#
# In the intitial report and in the project-results the influence of river inputs was quantitied by the number of river intersects within 1500 m of a survey location. With this method 13 possible correlations were identified, 11 positive and two negative. This method does not take into account the distance to the intersection, the length of the river section within the 1500 m buffer nor does it consider the size of the inputs.
#
# Here we consider the distance, the length, the size and the class of each river within 1 500 m of the survey location.

# %% [markdown]
# ```{figure} resources/images/stream_length_buffer_land_use.jpeg
# ---
# name: dist_to_int
# ---
# ` `
# ```
# {numref}`figure %s: <dist_to_int>` Measuring the distance to the intersection and length of the intersection in the buffer. Location: grand-clos, St. Gingolph - Lac Léman.

# %% [markdown]
# ## Extracting the values from the map layer
#
# The map layers that are publicly available have changed since the land-use attributes were originally considered for the project national survey. At that time we did not consider the length or distance. The size and the class of each river was not indicated on the previous map layers either. All that has changed:
#
# 1. There are fewer rivers and streams in the new map layers
# 2. Each river (section) is labled with the size, class, name and designated as man-made or natural.
#
# To extract the required data for the analysis for each location and river the following steps were followed:
#
# 1. Identify locations of interest
# 2. Construct a buffer around each point
# 3. Mark the intersection of the river with the buffer and the lake
# 4. Calculate the length of the river section that traverses the buffer
# 5. Calculate the straight line distance from the survey location to the point where the river leaves the buffer and enters the lake
#
# Most locations have more than one intersection. Which means that the survey result for a code is considered under all the possible conditions for each location. The results from St. Gingolph illustrate this:

# %%
data[(data.location == 'grand-clos') & (data.code == "Gfrags")&(data.loc_date == ("grand-clos", "2020-05-07"))].head().style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_4cb93 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_4cb93 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_4cb93 tr {
#   font-size: 12px;
# }
# #T_4cb93 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_4cb93">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cb93_level0_col0" class="col_heading level0 col0" >loc_date</th>
#       <th id="T_4cb93_level0_col1" class="col_heading level0 col1" >location</th>
#       <th id="T_4cb93_level0_col2" class="col_heading level0 col2" >river_bassin</th>
#       <th id="T_4cb93_level0_col3" class="col_heading level0 col3" >feature</th>
#       <th id="T_4cb93_level0_col4" class="col_heading level0 col4" >city</th>
#       <th id="T_4cb93_level0_col5" class="col_heading level0 col5" >w_t</th>
#       <th id="T_4cb93_level0_col6" class="col_heading level0 col6" >code</th>
#       <th id="T_4cb93_level0_col7" class="col_heading level0 col7" >pcs_m</th>
#       <th id="T_4cb93_level0_col8" class="col_heading level0 col8" >quantity</th>
#       <th id="T_4cb93_level0_col9" class="col_heading level0 col9" >name</th>
#       <th id="T_4cb93_level0_col10" class="col_heading level0 col10" >size</th>
#       <th id="T_4cb93_level0_col11" class="col_heading level0 col11" >class</th>
#       <th id="T_4cb93_level0_col12" class="col_heading level0 col12" >distance</th>
#       <th id="T_4cb93_level0_col13" class="col_heading level0 col13" >length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cb93_level0_row0" class="row_heading level0 row0" >32125</th>
#       <td id="T_4cb93_row0_col0" class="data row0 col0" >('grand-clos', '2020-05-07')</td>
#       <td id="T_4cb93_row0_col1" class="data row0 col1" >grand-clos</td>
#       <td id="T_4cb93_row0_col2" class="data row0 col2" >rhone</td>
#       <td id="T_4cb93_row0_col3" class="data row0 col3" >lac-leman</td>
#       <td id="T_4cb93_row0_col4" class="data row0 col4" >Saint-Gingolph</td>
#       <td id="T_4cb93_row0_col5" class="data row0 col5" >l</td>
#       <td id="T_4cb93_row0_col6" class="data row0 col6" >Gfrags</td>
#       <td id="T_4cb93_row0_col7" class="data row0 col7" >2.560000</td>
#       <td id="T_4cb93_row0_col8" class="data row0 col8" >82.000000</td>
#       <td id="T_4cb93_row0_col9" class="data row0 col9" >Canal Stockalper</td>
#       <td id="T_4cb93_row0_col10" class="data row0 col10" >18.000000</td>
#       <td id="T_4cb93_row0_col11" class="data row0 col11" >8.000000</td>
#       <td id="T_4cb93_row0_col12" class="data row0 col12" >1114.305677</td>
#       <td id="T_4cb93_row0_col13" class="data row0 col13" >498.263964</td>
#     </tr>
#     <tr>
#       <th id="T_4cb93_level0_row1" class="row_heading level0 row1" >32126</th>
#       <td id="T_4cb93_row1_col0" class="data row1 col0" >('grand-clos', '2020-05-07')</td>
#       <td id="T_4cb93_row1_col1" class="data row1 col1" >grand-clos</td>
#       <td id="T_4cb93_row1_col2" class="data row1 col2" >rhone</td>
#       <td id="T_4cb93_row1_col3" class="data row1 col3" >lac-leman</td>
#       <td id="T_4cb93_row1_col4" class="data row1 col4" >Saint-Gingolph</td>
#       <td id="T_4cb93_row1_col5" class="data row1 col5" >l</td>
#       <td id="T_4cb93_row1_col6" class="data row1 col6" >Gfrags</td>
#       <td id="T_4cb93_row1_col7" class="data row1 col7" >2.560000</td>
#       <td id="T_4cb93_row1_col8" class="data row1 col8" >82.000000</td>
#       <td id="T_4cb93_row1_col9" class="data row1 col9" >Le Rhône</td>
#       <td id="T_4cb93_row1_col10" class="data row1 col10" >1.000000</td>
#       <td id="T_4cb93_row1_col11" class="data row1 col11" >4.000000</td>
#       <td id="T_4cb93_row1_col12" class="data row1 col12" >1372.531919</td>
#       <td id="T_4cb93_row1_col13" class="data row1 col13" >475.233563</td>
#     </tr>
#     <tr>
#       <th id="T_4cb93_level0_row2" class="row_heading level0 row2" >32127</th>
#       <td id="T_4cb93_row2_col0" class="data row2 col0" >('grand-clos', '2020-05-07')</td>
#       <td id="T_4cb93_row2_col1" class="data row2 col1" >grand-clos</td>
#       <td id="T_4cb93_row2_col2" class="data row2 col2" >rhone</td>
#       <td id="T_4cb93_row2_col3" class="data row2 col3" >lac-leman</td>
#       <td id="T_4cb93_row2_col4" class="data row2 col4" >Saint-Gingolph</td>
#       <td id="T_4cb93_row2_col5" class="data row2 col5" >l</td>
#       <td id="T_4cb93_row2_col6" class="data row2 col6" >Gfrags</td>
#       <td id="T_4cb93_row2_col7" class="data row2 col7" >2.560000</td>
#       <td id="T_4cb93_row2_col8" class="data row2 col8" >82.000000</td>
#       <td id="T_4cb93_row2_col9" class="data row2 col9" >Le Tové</td>
#       <td id="T_4cb93_row2_col10" class="data row2 col10" >10.000000</td>
#       <td id="T_4cb93_row2_col11" class="data row2 col11" >10.000000</td>
#       <td id="T_4cb93_row2_col12" class="data row2 col12" >632.923894</td>
#       <td id="T_4cb93_row2_col13" class="data row2 col13" >1021.844171</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Testing the impacts of river inputs
#
# The method of aggregation leaves a few options for testing the impact of river inputs. Recall that there are river and lake side samples, the sampling conditions are not homogenous and the results differ both in magnitude of pcs/m and the variety of objects found, see [IQAASL -lakes and rivers](https://hammerdirt-analyst.github.io/IQAASL-End-0f-Sampling-2021/lakes_rivers.html) and compare the median pcs/m in the national results.
#
# 1. River and lake samples can be tested togethor
# 2. River and lake samples can be tested separately
# 3. The distance and length parameters can be aggregated
#    1. average distance to intersection per location
#    2. total river network length per location
#    3. Rivers and lake samples tested together
#
# ### Lake surveys
#
# As illustrated above some locations have mulitple intersection within the 1500 m buffer and some have none. Lake locations that have no intersections within the buffer are given a distance of 0 and length of 0. The class and size are both 20, indicating the smallest class and river size possible (example below). The name of the river intersection is given, in the case there are no intersections within a 1500 m buffer then name=None. Removing the records with name=None eliminates all lake records with no intersection data. However, for rivers the intersection name = the name of the feature that was sampled.

# %%
data[(data.location == 'versoix') & (data.code == "Gfrags")&(data.loc_date == ("versoix", "2020-10-13"))].head().style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_28545 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_28545 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_28545 tr {
#   font-size: 12px;
# }
# #T_28545 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_28545">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28545_level0_col0" class="col_heading level0 col0" >loc_date</th>
#       <th id="T_28545_level0_col1" class="col_heading level0 col1" >location</th>
#       <th id="T_28545_level0_col2" class="col_heading level0 col2" >river_bassin</th>
#       <th id="T_28545_level0_col3" class="col_heading level0 col3" >feature</th>
#       <th id="T_28545_level0_col4" class="col_heading level0 col4" >city</th>
#       <th id="T_28545_level0_col5" class="col_heading level0 col5" >w_t</th>
#       <th id="T_28545_level0_col6" class="col_heading level0 col6" >code</th>
#       <th id="T_28545_level0_col7" class="col_heading level0 col7" >pcs_m</th>
#       <th id="T_28545_level0_col8" class="col_heading level0 col8" >quantity</th>
#       <th id="T_28545_level0_col9" class="col_heading level0 col9" >name</th>
#       <th id="T_28545_level0_col10" class="col_heading level0 col10" >size</th>
#       <th id="T_28545_level0_col11" class="col_heading level0 col11" >class</th>
#       <th id="T_28545_level0_col12" class="col_heading level0 col12" >distance</th>
#       <th id="T_28545_level0_col13" class="col_heading level0 col13" >length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28545_level0_row0" class="row_heading level0 row0" >108961</th>
#       <td id="T_28545_row0_col0" class="data row0 col0" >('versoix', '2020-10-13')</td>
#       <td id="T_28545_row0_col1" class="data row0 col1" >versoix</td>
#       <td id="T_28545_row0_col2" class="data row0 col2" >rhone</td>
#       <td id="T_28545_row0_col3" class="data row0 col3" >lac-leman</td>
#       <td id="T_28545_row0_col4" class="data row0 col4" >Versoix</td>
#       <td id="T_28545_row0_col5" class="data row0 col5" >l</td>
#       <td id="T_28545_row0_col6" class="data row0 col6" >Gfrags</td>
#       <td id="T_28545_row0_col7" class="data row0 col7" >0.680000</td>
#       <td id="T_28545_row0_col8" class="data row0 col8" >35.000000</td>
#       <td id="T_28545_row0_col9" class="data row0 col9" >0</td>
#       <td id="T_28545_row0_col10" class="data row0 col10" >20.000000</td>
#       <td id="T_28545_row0_col11" class="data row0 col11" >20.000000</td>
#       <td id="T_28545_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_28545_row0_col13" class="data row0 col13" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### River surveys
#
# The intersection of one river to another was not considered. Therefore, for river surveys the measured parameter is the length of the river in the buffer that was sampled. The class and size are set to 20 and the distance to intersection is 0. River sample locations, for this analysis, are considered the same as a lake locations with no corresponding intersections.

# %%
data[(data.location == 'schusspark-strand') & (data.code == "Gfrags")&(data.loc_date == ("schusspark-strand", "2020-08-08"))].style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_3398e tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_3398e tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_3398e tr {
#   font-size: 12px;
# }
# #T_3398e th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_3398e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3398e_level0_col0" class="col_heading level0 col0" >loc_date</th>
#       <th id="T_3398e_level0_col1" class="col_heading level0 col1" >location</th>
#       <th id="T_3398e_level0_col2" class="col_heading level0 col2" >river_bassin</th>
#       <th id="T_3398e_level0_col3" class="col_heading level0 col3" >feature</th>
#       <th id="T_3398e_level0_col4" class="col_heading level0 col4" >city</th>
#       <th id="T_3398e_level0_col5" class="col_heading level0 col5" >w_t</th>
#       <th id="T_3398e_level0_col6" class="col_heading level0 col6" >code</th>
#       <th id="T_3398e_level0_col7" class="col_heading level0 col7" >pcs_m</th>
#       <th id="T_3398e_level0_col8" class="col_heading level0 col8" >quantity</th>
#       <th id="T_3398e_level0_col9" class="col_heading level0 col9" >name</th>
#       <th id="T_3398e_level0_col10" class="col_heading level0 col10" >size</th>
#       <th id="T_3398e_level0_col11" class="col_heading level0 col11" >class</th>
#       <th id="T_3398e_level0_col12" class="col_heading level0 col12" >distance</th>
#       <th id="T_3398e_level0_col13" class="col_heading level0 col13" >length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3398e_level0_row0" class="row_heading level0 row0" >71862</th>
#       <td id="T_3398e_row0_col0" class="data row0 col0" >('schusspark-strand', '2020-08-08')</td>
#       <td id="T_3398e_row0_col1" class="data row0 col1" >schusspark-strand</td>
#       <td id="T_3398e_row0_col2" class="data row0 col2" >aare</td>
#       <td id="T_3398e_row0_col3" class="data row0 col3" >schuss</td>
#       <td id="T_3398e_row0_col4" class="data row0 col4" >Biel/Bienne</td>
#       <td id="T_3398e_row0_col5" class="data row0 col5" >r</td>
#       <td id="T_3398e_row0_col6" class="data row0 col6" >Gfrags</td>
#       <td id="T_3398e_row0_col7" class="data row0 col7" >0.060000</td>
#       <td id="T_3398e_row0_col8" class="data row0 col8" >3.000000</td>
#       <td id="T_3398e_row0_col9" class="data row0 col9" >La Suze</td>
#       <td id="T_3398e_row0_col10" class="data row0 col10" >20.000000</td>
#       <td id="T_3398e_row0_col11" class="data row0 col11" >20.000000</td>
#       <td id="T_3398e_row0_col12" class="data row0 col12" >0.000000</td>
#       <td id="T_3398e_row0_col13" class="data row0 col13" >3248.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Description of the survey results

# %%
## The survey results
locations = df.location.unique()
samples = df.loc_date.unique()
lakes = df[df.w_t == "l"].drop_duplicates("loc_date").w_t.value_counts().values[0]
rivers = df[df.w_t == "r"].drop_duplicates("loc_date").w_t.value_counts().values[0]
codes_identified = df[df.quantity > 0].code.unique()
codes_possible = df.code.unique()
total_id = df.quantity.sum()

data_summary = {
    "n locations": len(locations),
    "n samples": len(samples),
    "n lake samples": lakes,
    "n river samples": rivers,
    "n identified object types": len(codes_identified),
    "n possible object types": len(codes_possible),
    "total number of objects": total_id
}

pd.DataFrame(index = data_summary.keys(), data=data_summary.values(), columns=["total"]).style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_c86bb tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_c86bb tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_c86bb tr {
#   font-size: 12px;
# }
# #T_c86bb th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_c86bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c86bb_level0_col0" class="col_heading level0 col0" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c86bb_level0_row0" class="row_heading level0 row0" >n locations</th>
#       <td id="T_c86bb_row0_col0" class="data row0 col0" >128</td>
#     </tr>
#     <tr>
#       <th id="T_c86bb_level0_row1" class="row_heading level0 row1" >n samples</th>
#       <td id="T_c86bb_row1_col0" class="data row1 col0" >349</td>
#     </tr>
#     <tr>
#       <th id="T_c86bb_level0_row2" class="row_heading level0 row2" >n lake samples</th>
#       <td id="T_c86bb_row2_col0" class="data row2 col0" >300</td>
#     </tr>
#     <tr>
#       <th id="T_c86bb_level0_row3" class="row_heading level0 row3" >n river samples</th>
#       <td id="T_c86bb_row3_col0" class="data row3 col0" >49</td>
#     </tr>
#     <tr>
#       <th id="T_c86bb_level0_row4" class="row_heading level0 row4" >n identified object types</th>
#       <td id="T_c86bb_row4_col0" class="data row4 col0" >191</td>
#     </tr>
#     <tr>
#       <th id="T_c86bb_level0_row5" class="row_heading level0 row5" >n possible object types</th>
#       <td id="T_c86bb_row5_col0" class="data row5 col0" >211</td>
#     </tr>
#     <tr>
#       <th id="T_c86bb_level0_row6" class="row_heading level0 row6" >total number of objects</th>
#       <td id="T_c86bb_row6_col0" class="data row6 col0" >46832</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### River and lake samples
#
# The survey resutls for both river and lakes are tested for correlation. Each intersection is tested once. Consider the example from St. Gingolph under this model each results is tested against the distance and length of each intersection for each location, this includes the size and the class.
#
# __River and lake samples not aggregated__

# %%
# the columns being tested against pcs_m
columns = ["distance", "length", "size", "class"]

# conduct the test
corellation_results = collectCorrelation(data, codes, columns)
crp = pd.DataFrame(corellation_results)
pvals = crp.pivot(index="code", columns="variable", values="p")
rhovals = crp.pivot(index="code", columns="variable", values="rho")

# display the results
a_df = pd.DataFrame(resultsDf(rhovals, pvals))
a_df["item"] = a_df.index.map(lambda x: code_d_map.loc[x])
a_df.set_index("item", inplace=True, drop=True)
a_df.index.name = None
styleBufferResults(a_df)
# Out:
# <style type="text/css">
# #T_e7231 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_e7231 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_e7231 tr {
#   font-size: 12px;
# }
# #T_e7231 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_e7231_row0_col0, #T_e7231_row22_col3 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_e7231_row0_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_e7231_row0_col2, #T_e7231_row11_col3 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_e7231_row0_col3, #T_e7231_row5_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e7231_row1_col0, #T_e7231_row1_col1, #T_e7231_row1_col3, #T_e7231_row2_col0, #T_e7231_row2_col1, #T_e7231_row2_col2, #T_e7231_row2_col3, #T_e7231_row3_col0, #T_e7231_row3_col1, #T_e7231_row3_col2, #T_e7231_row3_col3, #T_e7231_row4_col1, #T_e7231_row4_col2, #T_e7231_row5_col2, #T_e7231_row6_col0, #T_e7231_row6_col1, #T_e7231_row6_col2, #T_e7231_row6_col3, #T_e7231_row7_col0, #T_e7231_row7_col1, #T_e7231_row7_col2, #T_e7231_row7_col3, #T_e7231_row8_col0, #T_e7231_row8_col1, #T_e7231_row8_col2, #T_e7231_row8_col3, #T_e7231_row9_col2, #T_e7231_row12_col2, #T_e7231_row13_col2, #T_e7231_row14_col2, #T_e7231_row15_col0, #T_e7231_row15_col2, #T_e7231_row15_col3, #T_e7231_row16_col2, #T_e7231_row17_col0, #T_e7231_row17_col1, #T_e7231_row17_col2, #T_e7231_row17_col3, #T_e7231_row18_col2, #T_e7231_row19_col3, #T_e7231_row20_col2, #T_e7231_row21_col2, #T_e7231_row23_col3, #T_e7231_row24_col2, #T_e7231_row24_col3, #T_e7231_row25_col2, #T_e7231_row26_col0, #T_e7231_row26_col1, #T_e7231_row26_col2, #T_e7231_row26_col3, #T_e7231_row27_col1, #T_e7231_row27_col2, #T_e7231_row28_col1, #T_e7231_row28_col2, #T_e7231_row29_col1, #T_e7231_row29_col2, #T_e7231_row30_col0, #T_e7231_row30_col1, #T_e7231_row30_col2, #T_e7231_row30_col3, #T_e7231_row31_col2, #T_e7231_row32_col0, #T_e7231_row32_col1, #T_e7231_row32_col2, #T_e7231_row32_col3, #T_e7231_row33_col0, #T_e7231_row33_col1, #T_e7231_row33_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_e7231_row1_col2 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_e7231_row4_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e7231_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e7231_row5_col1, #T_e7231_row23_col1 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_e7231_row5_col3, #T_e7231_row11_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e7231_row9_col0, #T_e7231_row29_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_e7231_row9_col1, #T_e7231_row11_col1, #T_e7231_row12_col1 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_e7231_row9_col3, #T_e7231_row10_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_e7231_row10_col0, #T_e7231_row12_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e7231_row10_col1 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_e7231_row10_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e7231_row11_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e7231_row12_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e7231_row13_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e7231_row13_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_e7231_row13_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e7231_row14_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e7231_row14_col1, #T_e7231_row19_col1 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_e7231_row14_col3 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_e7231_row15_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_e7231_row16_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e7231_row16_col1, #T_e7231_row31_col1 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_e7231_row16_col3, #T_e7231_row21_col3 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e7231_row18_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e7231_row18_col1 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_e7231_row18_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e7231_row19_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_e7231_row19_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_e7231_row20_col0, #T_e7231_row23_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_e7231_row20_col1 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_e7231_row20_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e7231_row21_col0, #T_e7231_row31_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e7231_row21_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e7231_row22_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e7231_row22_col1, #T_e7231_row33_col2 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_e7231_row22_col2 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e7231_row23_col2 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_e7231_row24_col0, #T_e7231_row24_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_e7231_row25_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e7231_row25_col1 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_e7231_row25_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_e7231_row27_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_e7231_row27_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_e7231_row28_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e7231_row28_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e7231_row29_col0 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_e7231_row31_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e7231_row34_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e7231_row34_col1 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_e7231_row34_col2, #T_e7231_row35_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_e7231_row34_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_e7231_row35_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e7231_row35_col1 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_e7231_row35_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e7231_level0_col0, #T_e7231_level0_col1, #T_e7231_level0_col2, #T_e7231_level0_col3 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_e7231">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7231_level0_col0" class="col_heading level0 col0" >class</th>
#       <th id="T_e7231_level0_col1" class="col_heading level0 col1" >distance</th>
#       <th id="T_e7231_level0_col2" class="col_heading level0 col2" >length</th>
#       <th id="T_e7231_level0_col3" class="col_heading level0 col3" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7231_level0_row0" class="row_heading level0 row0" >Food containers single use foamed or plastic</th>
#       <td id="T_e7231_row0_col0" class="data row0 col0" >-0.14</td>
#       <td id="T_e7231_row0_col1" class="data row0 col1" >0.19</td>
#       <td id="T_e7231_row0_col2" class="data row0 col2" >-0.11</td>
#       <td id="T_e7231_row0_col3" class="data row0 col3" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_e7231_level0_row1" class="row_heading level0 row1" >Clothing, towels & rags</th>
#       <td id="T_e7231_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_e7231_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_e7231_row1_col2" class="data row1 col2" >0.09</td>
#       <td id="T_e7231_row1_col3" class="data row1 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e7231_level0_row2" class="row_heading level0 row2" >Paper packaging</th>
#       <td id="T_e7231_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_e7231_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_e7231_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_e7231_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>

# %% [markdown]
# #### The number of correlations

# %%
ncorrelated, total = countTheNumberOfCorrelationsPerBuffer(pvals, rhovals)
ncorrelated.style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_e5b31 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_e5b31 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_e5b31 tr {
#   font-size: 12px;
# }
# #T_e5b31 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_e5b31">
#   <thead>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th id="T_e5b31_level0_col0" class="col_heading level0 col0" >class</th>
#       <th id="T_e5b31_level0_col1" class="col_heading level0 col1" >distance</th>
#       <th id="T_e5b31_level0_col2" class="col_heading level0 col2" >length</th>
#       <th id="T_e5b31_level0_col3" class="col_heading level0 col3" >size</th>
#       <th id="T_e5b31_level0_col4" class="col_heading level0 col4" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5b31_level0_row0" class="row_heading level0 row0" >correlated</th>
#       <td id="T_e5b31_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_e5b31_row0_col1" class="data row0 col1" >21</td>
#       <td id="T_e5b31_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_e5b31_row0_col3" class="data row0 col3" >21</td>
#       <td id="T_e5b31_row0_col4" class="data row0 col4" >76</td>
#     </tr>
#     <tr>
#       <th id="T_e5b31_level0_row1" class="row_heading level0 row1" >positive</th>
#       <td id="T_e5b31_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_e5b31_row1_col1" class="data row1 col1" >21</td>
#       <td id="T_e5b31_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_e5b31_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_e5b31_row1_col4" class="data row1 col4" >24</td>
#     </tr>
#     <tr>
#       <th id="T_e5b31_level0_row2" class="row_heading level0 row2" >negative</th>
#       <td id="T_e5b31_row2_col0" class="data row2 col0" >23</td>
#       <td id="T_e5b31_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_e5b31_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_e5b31_row2_col3" class="data row2 col3" >21</td>
#       <td id="T_e5b31_row2_col4" class="data row2 col4" >52</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Notes:__
#
# __inverse correlations__ The __size__ and __class__ rankings start at zero, zero is the biggest. As an example the Aare and Rhône rivers are class 4. The correlations (if there are any) should be interpreted as 1/x:
#
# 1. If the correlation is negative: the density is greater as the size get bigger or the river is more important
# 2. If the correlation is positive: the density is greater as the size gets smaller of the river is less important
#
# Therefore, objects that are positively correlated with size and class were found more often at the intersects of smaller and less important rivers.
#
# __Lake samples__
#
# The survey results for lakes are tested for correlation, river samples are excluded. Each intersection is tested once. The same as the previous model.

# %%
datax = data[data.w_t == "l"]
columns = ["distance", "length", "size", "class"]
corellation_results = collectCorrelation(datax, codes, columns)
crp = pd.DataFrame(corellation_results)
pvals = crp.pivot(index="code", columns="variable", values="p")
rhovals = crp.pivot(index="code", columns="variable", values="rho")

# display the results
a_df = pd.DataFrame(resultsDf(rhovals, pvals))
a_df["item"] = a_df.index.map(lambda x: code_d_map.loc[x])
a_df.set_index("item", inplace=True, drop=True)
a_df.index.name = None
styleBufferResults(a_df)
# Out:
# <style type="text/css">
# #T_fc3b0 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_fc3b0 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_fc3b0 tr {
#   font-size: 12px;
# }
# #T_fc3b0 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_fc3b0_row0_col0, #T_fc3b0_row0_col2, #T_fc3b0_row0_col3, #T_fc3b0_row1_col0, #T_fc3b0_row1_col1, #T_fc3b0_row1_col2, #T_fc3b0_row1_col3, #T_fc3b0_row2_col0, #T_fc3b0_row2_col1, #T_fc3b0_row2_col2, #T_fc3b0_row2_col3, #T_fc3b0_row3_col0, #T_fc3b0_row3_col1, #T_fc3b0_row3_col2, #T_fc3b0_row3_col3, #T_fc3b0_row4_col1, #T_fc3b0_row5_col0, #T_fc3b0_row5_col1, #T_fc3b0_row6_col3, #T_fc3b0_row7_col1, #T_fc3b0_row7_col2, #T_fc3b0_row8_col0, #T_fc3b0_row8_col1, #T_fc3b0_row8_col2, #T_fc3b0_row8_col3, #T_fc3b0_row9_col0, #T_fc3b0_row9_col2, #T_fc3b0_row9_col3, #T_fc3b0_row10_col1, #T_fc3b0_row10_col2, #T_fc3b0_row10_col3, #T_fc3b0_row11_col0, #T_fc3b0_row11_col2, #T_fc3b0_row11_col3, #T_fc3b0_row12_col0, #T_fc3b0_row12_col2, #T_fc3b0_row12_col3, #T_fc3b0_row13_col2, #T_fc3b0_row13_col3, #T_fc3b0_row14_col1, #T_fc3b0_row15_col0, #T_fc3b0_row15_col2, #T_fc3b0_row15_col3, #T_fc3b0_row17_col0, #T_fc3b0_row17_col1, #T_fc3b0_row17_col2, #T_fc3b0_row17_col3, #T_fc3b0_row19_col0, #T_fc3b0_row19_col2, #T_fc3b0_row19_col3, #T_fc3b0_row20_col0, #T_fc3b0_row20_col2, #T_fc3b0_row22_col0, #T_fc3b0_row22_col1, #T_fc3b0_row22_col2, #T_fc3b0_row22_col3, #T_fc3b0_row23_col0, #T_fc3b0_row23_col1, #T_fc3b0_row23_col2, #T_fc3b0_row23_col3, #T_fc3b0_row24_col1, #T_fc3b0_row24_col2, #T_fc3b0_row24_col3, #T_fc3b0_row25_col1, #T_fc3b0_row25_col2, #T_fc3b0_row25_col3, #T_fc3b0_row26_col0, #T_fc3b0_row26_col1, #T_fc3b0_row26_col2, #T_fc3b0_row26_col3, #T_fc3b0_row27_col0, #T_fc3b0_row27_col1, #T_fc3b0_row27_col2, #T_fc3b0_row27_col3, #T_fc3b0_row28_col1, #T_fc3b0_row28_col2, #T_fc3b0_row29_col1, #T_fc3b0_row29_col2, #T_fc3b0_row30_col0, #T_fc3b0_row30_col1, #T_fc3b0_row30_col2, #T_fc3b0_row30_col3, #T_fc3b0_row31_col3, #T_fc3b0_row32_col0, #T_fc3b0_row32_col1, #T_fc3b0_row32_col3, #T_fc3b0_row33_col0, #T_fc3b0_row33_col1, #T_fc3b0_row34_col0, #T_fc3b0_row34_col1, #T_fc3b0_row34_col2, #T_fc3b0_row34_col3, #T_fc3b0_row35_col1, #T_fc3b0_row35_col3 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_fc3b0_row0_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_fc3b0_row4_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_fc3b0_row4_col2 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_fc3b0_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fc3b0_row5_col2 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_fc3b0_row5_col3, #T_fc3b0_row25_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_fc3b0_row6_col0 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_fc3b0_row6_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_fc3b0_row6_col2 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_fc3b0_row7_col0, #T_fc3b0_row20_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_fc3b0_row7_col3, #T_fc3b0_row19_col1, #T_fc3b0_row21_col2 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_fc3b0_row9_col1 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_fc3b0_row10_col0, #T_fc3b0_row20_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_fc3b0_row11_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_fc3b0_row12_col1 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_fc3b0_row13_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_fc3b0_row13_col1 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_fc3b0_row14_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_fc3b0_row14_col2 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_fc3b0_row14_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_fc3b0_row15_col1 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_fc3b0_row16_col0, #T_fc3b0_row21_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_fc3b0_row16_col1, #T_fc3b0_row31_col2 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_fc3b0_row16_col2 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_fc3b0_row16_col3, #T_fc3b0_row18_col3, #T_fc3b0_row31_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_fc3b0_row18_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_fc3b0_row18_col1 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_fc3b0_row18_col2 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_fc3b0_row21_col0 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_fc3b0_row21_col1 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_fc3b0_row24_col0 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_fc3b0_row28_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_fc3b0_row28_col3, #T_fc3b0_row29_col3 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_fc3b0_row29_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_fc3b0_row31_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_fc3b0_row32_col2 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_fc3b0_row33_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fc3b0_row33_col3 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_fc3b0_row35_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_fc3b0_row35_col2 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_fc3b0_level0_col0, #T_fc3b0_level0_col1, #T_fc3b0_level0_col2, #T_fc3b0_level0_col3 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_fc3b0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc3b0_level0_col0" class="col_heading level0 col0" >class</th>
#       <th id="T_fc3b0_level0_col1" class="col_heading level0 col1" >distance</th>
#       <th id="T_fc3b0_level0_col2" class="col_heading level0 col2" >length</th>
#       <th id="T_fc3b0_level0_col3" class="col_heading level0 col3" >size</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc3b0_level0_row0" class="row_heading level0 row0" >Food containers single use foamed or plastic</th>
#       <td id="T_fc3b0_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_fc3b0_row0_col1" class="data row0 col1" >0.11</td>
#       <td id="T_fc3b0_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_fc3b0_row0_col3" class="data row0 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fc3b0_level0_row1" class="row_heading level0 row1" >Clothing, towels & rags</th>
#       <td id="T_fc3b0_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_fc3b0_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_fc3b0_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_fc3b0_row1_col3" class="data row1 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fc3b0_level0_row2" class="row_heading level0 row2" >Paper packaging</th>
#       <td id="T_fc3b0_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_fc3b0_row2_col1" class="data row2 col1" >0.00</td>
#       <td id="T_fc3b0_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_fc3b0_row2_col3" class="data row2 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fc3b0_level0_row3" class="row_heading level0 row3" >Fireworks paper tubes and fragments</th>
#       <td id="T_fc3b0_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_fc3b0_row3_col1" class="data row3 col1" >0.00</td>
#       <td id="T_fc3b0_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_fc3b0_row3_col3" class="data row3 col3" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_fc3b0_level0_row4" class="row_heading level0 row4" >Foil wrappers, aluminum foil</th>
#       <td id="T_fc3b0_row4_col0" class="data row4 col0" >-0.19</td>
#       <td id="T_fc3b0_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_fc3b0_row4_col2" class="data row4 col2" >0.09</td>
#       <td id="T_fc3b0_row4_col3" class="data row4 col3" >-0.23</td>
#     </tr>
#     <tr>
#       <th id="T_fc3b0_level0_row5" class="row_heading level0 row5" >Metal bottle caps, lids & pull tabs from ca

# %% [markdown]
# #### The number of correlations

# %%
ncorrelated, total = countTheNumberOfCorrelationsPerBuffer(pvals, rhovals)
ncorrelated.style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_62487 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_62487 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_62487 tr {
#   font-size: 12px;
# }
# #T_62487 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_62487">
#   <thead>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th id="T_62487_level0_col0" class="col_heading level0 col0" >class</th>
#       <th id="T_62487_level0_col1" class="col_heading level0 col1" >distance</th>
#       <th id="T_62487_level0_col2" class="col_heading level0 col2" >length</th>
#       <th id="T_62487_level0_col3" class="col_heading level0 col3" >size</th>
#       <th id="T_62487_level0_col4" class="col_heading level0 col4" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62487_level0_row0" class="row_heading level0 row0" >correlated</th>
#       <td id="T_62487_row0_col0" class="data row0 col0" >15</td>
#       <td id="T_62487_row0_col1" class="data row0 col1" >13</td>
#       <td id="T_62487_row0_col2" class="data row0 col2" >11</td>
#       <td id="T_62487_row0_col3" class="data row0 col3" >11</td>
#       <td id="T_62487_row0_col4" class="data row0 col4" >50</td>
#     </tr>
#     <tr>
#       <th id="T_62487_level0_row1" class="row_heading level0 row1" >positive</th>
#       <td id="T_62487_row1_col0" class="data row1 col0" >3</td>
#       <td id="T_62487_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_62487_row1_col2" class="data row1 col2" >11</td>
#       <td id="T_62487_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_62487_row1_col4" class="data row1 col4" >27</td>
#     </tr>
#     <tr>
#       <th id="T_62487_level0_row2" class="row_heading level0 row2" >negative</th>
#       <td id="T_62487_row2_col0" class="data row2 col0" >12</td>
#       <td id="T_62487_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_62487_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_62487_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_62487_row2_col4" class="data row2 col4" >23</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Aggregated intersection and length
#
# The length and distance parameters are aggregated in the following way:
#
# 1. length: the sum of the length of all intersections in the buffer
# 2. distance: the average distance to an intersection
#
# Because we are aggregating, the size and class values for each intersection are not considered. The example for St. Gingolph is below.

# %%
intersects_agg = ind.groupby(["location"], as_index=False).agg({'distance':'mean', 'length':'sum'})

ints_and_data = df.merge(intersects_agg, on=["location"])
locations = df.location.unique()

data = ints_and_data[(ints_and_data.code.isin(codes)) & (ints_and_data.location.isin(locations))].copy()
data.fillna(0, inplace=True)
data.rename(columns=n_c_names, inplace=True)
data.drop("intersects", inplace=True, axis=1)

data[(data.location == 'grand-clos') & (data.code == "Gfrags")&(data.loc_date == ("grand-clos", "2020-05-07"))]
# Out:
#                        loc_date    location river_bassin    feature
# 17351  (grand-clos, 2020-05-07)  grand-clos        rhone  lac-leman  \
#
#                  city w_t    code  pcs_m  quantity     distance       length
# 17351  Saint-Gingolph   l  Gfrags   2.56        82  1039.920497  1995.341698

# %% [markdown]
# __River and lake samples aggregated__

# %%
columns = ["distance", "length"]

corellation_results = collectCorrelation(data, codes, columns)
crp = pd.DataFrame(corellation_results)
pvals = crp.pivot(index="code", columns="variable", values="p")
rhovals = crp.pivot(index="code", columns="variable", values="rho")

# display the results
a_df = pd.DataFrame(resultsDf(rhovals, pvals))
a_df["item"] = a_df.index.map(lambda x: code_d_map.loc[x])
a_df.set_index("item", inplace=True, drop=True)
a_df.index.name = None
styleBufferResults(a_df)
# Out:
# <style type="text/css">
# #T_e2ff8 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_e2ff8 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_e2ff8 tr {
#   font-size: 12px;
# }
# #T_e2ff8 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_e2ff8_row0_col0, #T_e2ff8_row15_col1 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_e2ff8_row0_col1, #T_e2ff8_row1_col0, #T_e2ff8_row1_col1, #T_e2ff8_row2_col0, #T_e2ff8_row2_col1, #T_e2ff8_row3_col0, #T_e2ff8_row3_col1, #T_e2ff8_row4_col1, #T_e2ff8_row5_col1, #T_e2ff8_row6_col0, #T_e2ff8_row6_col1, #T_e2ff8_row7_col0, #T_e2ff8_row7_col1, #T_e2ff8_row8_col0, #T_e2ff8_row9_col1, #T_e2ff8_row10_col1, #T_e2ff8_row11_col1, #T_e2ff8_row12_col1, #T_e2ff8_row13_col1, #T_e2ff8_row14_col1, #T_e2ff8_row15_col0, #T_e2ff8_row16_col1, #T_e2ff8_row17_col0, #T_e2ff8_row17_col1, #T_e2ff8_row19_col1, #T_e2ff8_row20_col1, #T_e2ff8_row21_col1, #T_e2ff8_row22_col1, #T_e2ff8_row23_col0, #T_e2ff8_row23_col1, #T_e2ff8_row24_col1, #T_e2ff8_row25_col1, #T_e2ff8_row26_col1, #T_e2ff8_row27_col0, #T_e2ff8_row27_col1, #T_e2ff8_row28_col0, #T_e2ff8_row28_col1, #T_e2ff8_row29_col0, #T_e2ff8_row29_col1, #T_e2ff8_row30_col0, #T_e2ff8_row31_col1, #T_e2ff8_row32_col0, #T_e2ff8_row32_col1, #T_e2ff8_row33_col0, #T_e2ff8_row33_col1, #T_e2ff8_row34_col1, #T_e2ff8_row35_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_e2ff8_row4_col0 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_e2ff8_row5_col0 {
#   background-color: #f6a283;
#   color: #000000;
# }
# #T_e2ff8_row8_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e2ff8_row9_col0 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_e2ff8_row10_col0 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_e2ff8_row11_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_e2ff8_row12_col0 {
#   background-color: #dc5d4a;
#   color: #f1f1f1;
# }
# #T_e2ff8_row13_col0 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_e2ff8_row14_col0, #T_e2ff8_row35_col0 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_e2ff8_row16_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e2ff8_row18_col0 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_e2ff8_row18_col1 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_e2ff8_row19_col0 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_e2ff8_row20_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_e2ff8_row21_col0 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_e2ff8_row22_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_e2ff8_row24_col0 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_e2ff8_row25_col0 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_e2ff8_row26_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_e2ff8_row30_col1 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_e2ff8_row31_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_e2ff8_row34_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_e2ff8_level0_col0, #T_e2ff8_level0_col1 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_e2ff8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2ff8_level0_col0" class="col_heading level0 col0" >distance</th>
#       <th id="T_e2ff8_level0_col1" class="col_heading level0 col1" >length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2ff8_level0_row0" class="row_heading level0 row0" >Food containers single use foamed or plastic</th>
#       <td id="T_e2ff8_row0_col0" class="data row0 col0" >0.21</td>
#       <td id="T_e2ff8_row0_col1" class="data row0 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row1" class="row_heading level0 row1" >Clothing, towels & rags</th>
#       <td id="T_e2ff8_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_e2ff8_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row2" class="row_heading level0 row2" >Paper packaging</th>
#       <td id="T_e2ff8_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_e2ff8_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row3" class="row_heading level0 row3" >Fireworks paper tubes and fragments</th>
#       <td id="T_e2ff8_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_e2ff8_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row4" class="row_heading level0 row4" >Foil wrappers, aluminum foil</th>
#       <td id="T_e2ff8_row4_col0" class="data row4 col0" >0.11</td>
#       <td id="T_e2ff8_row4_col1" class="data row4 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row5" class="row_heading level0 row5" >Metal bottle caps, lids & pull tabs from cans</th>
#       <td id="T_e2ff8_row5_col0" class="data row5 col0" >0.19</td>
#       <td id="T_e2ff8_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row6" class="row_heading level0 row6" >Glass drink bottles, pieces</th>
#       <td id="T_e2ff8_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_e2ff8_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row7" class="row_heading level0 row7" >Construction material; bricks, pipes, cement</th>
#       <td id="T_e2ff8_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_e2ff8_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row8" class="row_heading level0 row8" >Glass or ceramic fragments > 2.5 cm</th>
#       <td id="T_e2ff8_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_e2ff8_row8_col1" class="data row8 col1" >-0.11</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row9" class="row_heading level0 row9" >Drink lids</th>
#       <td id="T_e2ff8_row9_col0" class="data row9 col0" >0.22</td>
#       <td id="T_e2ff8_row9_col1" class="data row9 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row10" class="row_heading level0 row10" >Lids for chemicals, detergents (non-food)</th>
#       <td id="T_e2ff8_row10_col0" class="data row10 col0" >0.14</td>
#       <td id="T_e2ff8_row10_col1" class="data row10 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row11" class="row_heading level0 row11" >Lids unidentified</th>
#       <td id="T_e2ff8_row11_col0" class="data row11 col0" >0.23</td>
#       <td id="T_e2ff8_row11_col1" class="data row11 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row12" class="row_heading level0 row12" >Lid/cap rings from plastic bottles/containers</th>
#       <td id="T_e2ff8_row12_col0" class="data row12 col0" >0.25</td>
#       <td id="T_e2ff8_row12_col1" class="data row12 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row13" class="row_heading level0 row13" >Tobacco; plastic packaging, containers</th>
#       <td id="T_e2ff8_row13_col0" class="data row13 col0" >0.29</td>
#       <td id="T_e2ff8_row13_col1" class="data row13 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row14" class="row_heading level0 row14" >Cigarette filters</th>
#       <td id="T_e2ff8_row14_col0" class="data row14 col0" >0.24</td>
#       <td id="T_e2ff8_row14_col1" class="data row14 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row15" class="row_heading level0 row15" >Bags; plastic shopping/carrier/grocery and pieces</th>
#       <td id="T_e2ff8_row15_col0" class="data row15 col0" >0.00</td>
#       <td id="T_e2ff8_row15_col1" class="data row15 col1" >0.21</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row16" class="row_heading level0 row16" >Food wrappers; candy, snacks</th>
#       <td id="T_e2ff8_row16_col0" class="data row16 col0" >0.30</td>
#       <td id="T_e2ff8_row16_col1" class="data row16 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_e2ff8_level0_row17" class="row_heading level0 row17" >Coverings; plastic packaging, sheeting for protecting large cargo items</th>
#       <td id="T_

# %% [markdown]
# #### The number of correlations

# %%
ncorrelated, total = countTheNumberOfCorrelationsPerBuffer(pvals, rhovals)
ncorrelated.style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_d9faf tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_d9faf tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_d9faf tr {
#   font-size: 12px;
# }
# #T_d9faf th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_d9faf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th id="T_d9faf_level0_col0" class="col_heading level0 col0" >distance</th>
#       <th id="T_d9faf_level0_col1" class="col_heading level0 col1" >length</th>
#       <th id="T_d9faf_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9faf_level0_row0" class="row_heading level0 row0" >correlated</th>
#       <td id="T_d9faf_row0_col0" class="data row0 col0" >21</td>
#       <td id="T_d9faf_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_d9faf_row0_col2" class="data row0 col2" >25</td>
#     </tr>
#     <tr>
#       <th id="T_d9faf_level0_row1" class="row_heading level0 row1" >positive</th>
#       <td id="T_d9faf_row1_col0" class="data row1 col0" >21</td>
#       <td id="T_d9faf_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_d9faf_row1_col2" class="data row1 col2" >24</td>
#     </tr>
#     <tr>
#       <th id="T_d9faf_level0_row2" class="row_heading level0 row2" >negative</th>
#       <td id="T_d9faf_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_d9faf_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_d9faf_row2_col2" class="data row2 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Lake samples aggregated__

# %%
datax = data[data.w_t == 'l']
corellation_results = collectCorrelation(datax, codes, columns)
crp = pd.DataFrame(corellation_results)
pvals = crp.pivot(index="code", columns="variable", values="p")
rhovals = crp.pivot(index="code", columns="variable", values="rho")

# display the results
a_df = pd.DataFrame(resultsDf(rhovals, pvals))
a_df["item"] = a_df.index.map(lambda x: code_d_map.loc[x])
a_df.set_index("item", inplace=True, drop=True)
a_df.index.name = None
styleBufferResults(a_df)
# Out:
# <style type="text/css">
# #T_988de tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_988de tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_988de tr {
#   font-size: 12px;
# }
# #T_988de th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_988de_row0_col0 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_988de_row0_col1, #T_988de_row21_col0 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_988de_row1_col0, #T_988de_row1_col1, #T_988de_row2_col0, #T_988de_row2_col1, #T_988de_row3_col0, #T_988de_row3_col1, #T_988de_row4_col0, #T_988de_row5_col1, #T_988de_row6_col1, #T_988de_row7_col0, #T_988de_row7_col1, #T_988de_row8_col0, #T_988de_row10_col0, #T_988de_row14_col0, #T_988de_row15_col0, #T_988de_row17_col0, #T_988de_row17_col1, #T_988de_row18_col0, #T_988de_row19_col0, #T_988de_row20_col1, #T_988de_row22_col0, #T_988de_row23_col0, #T_988de_row23_col1, #T_988de_row24_col0, #T_988de_row24_col1, #T_988de_row25_col0, #T_988de_row25_col1, #T_988de_row26_col1, #T_988de_row27_col0, #T_988de_row27_col1, #T_988de_row28_col0, #T_988de_row29_col0, #T_988de_row30_col0, #T_988de_row31_col0, #T_988de_row32_col0, #T_988de_row33_col0, #T_988de_row34_col0, #T_988de_row35_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_988de_row4_col1, #T_988de_row11_col1 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_988de_row5_col0, #T_988de_row28_col1 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_988de_row6_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_988de_row8_col1 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_988de_row9_col0 {
#   background-color: #f2c9b4;
#   color: #000000;
# }
# #T_988de_row9_col1 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_988de_row10_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_988de_row11_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_988de_row12_col0, #T_988de_row26_col0, #T_988de_row29_col1 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_988de_row12_col1 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_988de_row13_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_988de_row13_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_988de_row14_col1 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_988de_row15_col1 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_988de_row16_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_988de_row16_col1 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_988de_row18_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_988de_row19_col1 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_988de_row20_col0, #T_988de_row32_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_988de_row21_col1, #T_988de_row34_col1 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_988de_row22_col1, #T_988de_row30_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_988de_row31_col1 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_988de_row33_col1 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_988de_row35_col1 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_988de_level0_col0, #T_988de_level0_col1 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_988de">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_988de_level0_col0" class="col_heading level0 col0" >distance</th>
#       <th id="T_988de_level0_col1" class="col_heading level0 col1" >length</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_988de_level0_row0" class="row_heading level0 row0" >Food containers single use foamed or plastic</th>
#       <td id="T_988de_row0_col0" class="data row0 col0" >0.12</td>
#       <td id="T_988de_row0_col1" class="data row0 col1" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row1" class="row_heading level0 row1" >Clothing, towels & rags</th>
#       <td id="T_988de_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_988de_row1_col1" class="data row1 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row2" class="row_heading level0 row2" >Paper packaging</th>
#       <td id="T_988de_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_988de_row2_col1" class="data row2 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row3" class="row_heading level0 row3" >Fireworks paper tubes and fragments</th>
#       <td id="T_988de_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_988de_row3_col1" class="data row3 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row4" class="row_heading level0 row4" >Foil wrappers, aluminum foil</th>
#       <td id="T_988de_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_988de_row4_col1" class="data row4 col1" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row5" class="row_heading level0 row5" >Metal bottle caps, lids & pull tabs from cans</th>
#       <td id="T_988de_row5_col0" class="data row5 col0" >0.13</td>
#       <td id="T_988de_row5_col1" class="data row5 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row6" class="row_heading level0 row6" >Glass drink bottles, pieces</th>
#       <td id="T_988de_row6_col0" class="data row6 col0" >-0.20</td>
#       <td id="T_988de_row6_col1" class="data row6 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row7" class="row_heading level0 row7" >Construction material; bricks, pipes, cement</th>
#       <td id="T_988de_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_988de_row7_col1" class="data row7 col1" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row8" class="row_heading level0 row8" >Glass or ceramic fragments > 2.5 cm</th>
#       <td id="T_988de_row8_col0" class="data row8 col0" >0.00</td>
#       <td id="T_988de_row8_col1" class="data row8 col1" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row9" class="row_heading level0 row9" >Drink lids</th>
#       <td id="T_988de_row9_col0" class="data row9 col0" >0.13</td>
#       <td id="T_988de_row9_col1" class="data row9 col1" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row10" class="row_heading level0 row10" >Lids for chemicals, detergents (non-food)</th>
#       <td id="T_988de_row10_col0" class="data row10 col0" >0.00</td>
#       <td id="T_988de_row10_col1" class="data row10 col1" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row11" class="row_heading level0 row11" >Lids unidentified</th>
#       <td id="T_988de_row11_col0" class="data row11 col0" >0.12</td>
#       <td id="T_988de_row11_col1" class="data row11 col1" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row12" class="row_heading level0 row12" >Lid/cap rings from plastic bottles/containers</th>
#       <td id="T_988de_row12_col0" class="data row12 col0" >0.13</td>
#       <td id="T_988de_row12_col1" class="data row12 col1" >0.13</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row13" class="row_heading level0 row13" >Tobacco; plastic packaging, containers</th>
#       <td id="T_988de_row13_col0" class="data row13 col0" >0.17</td>
#       <td id="T_988de_row13_col1" class="data row13 col1" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row14" class="row_heading level0 row14" >Cigarette filters</th>
#       <td id="T_988de_row14_col0" class="data row14 col0" >0.00</td>
#       <td id="T_988de_row14_col1" class="data row14 col1" >0.18</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row15" class="row_heading level0 row15" >Bags; plastic shopping/carrier/grocery and pieces</th>
#       <td id="T_988de_row15_col0" class="data row15 col0" >0.00</td>
#       <td id="T_988de_row15_col1" class="data row15 col1" >0.23</td>
#     </tr>
#     <tr>
#       <th id="T_988de_level0_row16" class="row_heading level0 row16" >Food wrappers; candy, snacks</th>
#       <td id="T_988de_row16_col0" class="data row16 col0" >0.14</td>
#       <td id="T_988de_row16_col1" class="data row16 col1" >0.27</td>
#     </tr>
#     <tr>
#       <th id

# %% [markdown]
# #### The number of correlations

# %%
ncorrelated, total = countTheNumberOfCorrelationsPerBuffer(pvals, rhovals)
ncorrelated.style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_7d2bf tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_7d2bf tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_7d2bf tr {
#   font-size: 12px;
# }
# #T_7d2bf th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_7d2bf">
#   <thead>
#     <tr>
#       <th class="index_name level0" >variable</th>
#       <th id="T_7d2bf_level0_col0" class="col_heading level0 col0" >distance</th>
#       <th id="T_7d2bf_level0_col1" class="col_heading level0 col1" >length</th>
#       <th id="T_7d2bf_level0_col2" class="col_heading level0 col2" >total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d2bf_level0_row0" class="row_heading level0 row0" >correlated</th>
#       <td id="T_7d2bf_row0_col0" class="data row0 col0" >11</td>
#       <td id="T_7d2bf_row0_col1" class="data row0 col1" >23</td>
#       <td id="T_7d2bf_row0_col2" class="data row0 col2" >34</td>
#     </tr>
#     <tr>
#       <th id="T_7d2bf_level0_row1" class="row_heading level0 row1" >positive</th>
#       <td id="T_7d2bf_row1_col0" class="data row1 col0" >10</td>
#       <td id="T_7d2bf_row1_col1" class="data row1 col1" >22</td>
#       <td id="T_7d2bf_row1_col2" class="data row1 col2" >32</td>
#     </tr>
#     <tr>
#       <th id="T_7d2bf_level0_row2" class="row_heading level0 row2" >negative</th>
#       <td id="T_7d2bf_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_7d2bf_row2_col1" class="data row2 col1" >1</td>
#       <td id="T_7d2bf_row2_col2" class="data row2 col2" >2</td>
#     </tr>
#   </tbody>
# </table>

# %%
today = dt.datetime.now().date().strftime("%d/%m/%Y")
where = "Biel, CH"

my_block = f"""

This script updated {today} in {where}

> \u2764\ufe0f what you do everyday

*analyst at hammerdirt*
"""

md(my_block)
# Out:
# This script updated 09/05/2023 in Biel, CH
#
# > ❤️ what you do everyday
#
# *analyst at hammerdirt*

# %%
# %watermark --iversions -b -r
# Out:
# Git repo: https://github.com/hammerdirt-analyst/landuse.git
#
# Git branch: main
#
# PIL    : 9.5.0
# pandas : 2.0.0
# IPython: 8.12.0
# numpy  : 1.24.2
# scipy  : 1.10.1
