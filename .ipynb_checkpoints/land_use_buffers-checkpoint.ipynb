# %%
# sys, file and nav packages:
import datetime as dt

# math packages:
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.distributions.empirical_distribution import ECDF

# charting:
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import ticker
from matplotlib import colors
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.gridspec import GridSpec
import seaborn as sns

# home brew utitilties
import resources.utility_functions as ut
import resources.abundance_classes as ac
import resources.chart_kwargs as ck

import resources.sr_ut as sut

# images and display
import base64, io, IPython
from PIL import Image as PILImage
from IPython.display import Markdown as md
from IPython.display import display, Math, Latex


# set some parameters:
today = dt.datetime.now().date().strftime("%Y-%m-%d")
start_date = '2020-03-01'
end_date ='2021-10-31'

a_fail_rate = 100

unit_label = 'p/100m'
reporting_unit = 100

# name of the output folder:
name_of_project = 'dist_map'

a_color = 'dodgerblue'

# colors for gradients
colors = ['beige', 'navajowhite', 'sandybrown', 'salmon', 'sienna']
nodes = [0.0, 0.2, 0.6, 0.8, 1.0]
cmap2 = LinearSegmentedColormap.from_list("mycmap", list(zip(nodes, colors)))

# set the maps
bassin_map = PILImage.open("resources/maps/survey_locations_all.jpeg")
bassin_pallette = {'rhone':'dimgray', 'aare':'salmon', 'linth':'tan', 'ticino':'steelblue', 'reuss':'purple'}

# define the feature level and components
this_level = 'river_bassin'
comps = ['linth', 'rhone', 'aare', 'ticino']
comp_labels = {"linth":"Linth/Limmat", "rhone":"Rhône", 'aare':"Aare", "ticino":"Ticino/Cerisio", "reuss":"Reuss"}
comp_palette = {"Linth/Limmat":"dimgray", "Rhône":"tan", "Aare":"salmon", "Ticino/Cerisio":"steelblue", "Reuss":"purple"}

# explanatory variables:
luse_exp = ['% to buildings', '% to recreation', '% to agg', '% to woods', 'streets km', 'intersects']

# columns needed
use_these_cols = ['loc_date' ,
                  '% to buildings',
                  '% to trans', 
                  '% to recreation',
                  '% to agg',
                  '% to woods',
                  'population',
                  'river_bassin',
                  'water_name_slug',
                  'streets km',
                  'intersects',
                  'length',
                  'groupname',
                  'code'
                 ]

# these are default
top_name = ["All survey areas"]

# add the folder to the directory tree:
project_directory = ut.make_project_folder('output', name_of_project)

# get your data:
df= pd.read_csv('resources/results_with_land_use_2015.csv')
river_bassins = ut.json_file_get("resources/river_basins.json")
dfBeaches = pd.read_csv("resources/beaches_with_land_use_rates.csv")
dfCodes = pd.read_csv("resources/codes_with_group_names_2015.csv")
dfDims = pd.read_csv("resources/dims_data.csv")

# set the index of the beach data to location slug
dfBeaches.set_index('slug', inplace=True)

city_map = dfBeaches['city']

# map locations to feature names
location_wname_key = dfBeaches.water_name_slug

# map water_name_slug to water_name
wname_wname = dfBeaches[['water_name_slug','water_name']].reset_index(drop=True).drop_duplicates()
wname_wname.set_index('water_name_slug', inplace=True)
        
def make_plot_with_spearmans(data, ax, n):
    """Gets Spearmans ranked correlation and make A/B scatter plot. Must proived a
    matplotlib axis object.
    """    
    sns.scatterplot(data=data, x=n, y=unit_label, ax=ax, color='black', s=30, edgecolor='white', alpha=0.6)
    corr, a_p = stats.spearmanr(data[n], data[unit_label])
    
    return ax, corr, a_p

dfCodes.set_index("code", inplace=True)

# these descriptions need to be shortened for display
dfCodes = sut.shorten_the_value(["G74", "description", "Insulation: includes spray foams"], dfCodes)
dfCodes = sut.shorten_the_value(["G940", "description", "Foamed EVA for crafts and sports"], dfCodes)
dfCodes = sut.shorten_the_value(["G96", "description", "Sanitary-pads/tampons, applicators"], dfCodes)
dfCodes = sut.shorten_the_value(["G178", "description", "Metal bottle caps and lids"], dfCodes)
dfCodes = sut.shorten_the_value(["G82", "description", "Expanded foams 2.5cm - 50cm"], dfCodes)
dfCodes = sut.shorten_the_value(["G81", "description", "Expanded foams .5cm - 2.5cm"], dfCodes)
dfCodes = sut.shorten_the_value(["G117", "description", "Expanded foams < 5mm"], dfCodes)
dfCodes = sut.shorten_the_value(["G75", "description", "Plastic/foamed polystyrene 0 - 2.5cm"], dfCodes)
dfCodes = sut.shorten_the_value(["G76", "description", "Plastic/foamed polystyrene 2.5cm - 50cm"], dfCodes)
dfCodes = sut.shorten_the_value(["G24", "description", "Plastic lid rings"], dfCodes)
dfCodes = sut.shorten_the_value(["G33", "description", "Lids for togo drinks plastic"], dfCodes)
dfCodes = sut.shorten_the_value(["G3", "description", "Plastic bags, carier bags"], dfCodes)
dfCodes = sut.shorten_the_value(["G204", "description", "Bricks, pipes not plastic"], dfCodes)

# make a map to the code descriptions
code_description_map = dfCodes.description

# make a map to the code descriptions
code_material_map = dfCodes.material

# %%
temporal = (df.date >= '2020-03-31')&(df.date <= '2021-05-31')

# %%
# this is the data before the expanded fragmented plastics and foams are aggregated to Gfrags and Gfoams
before_agg = pd.read_csv("resources/agg_results_with_land_use_2015.csv")

# this is the aggregated survey data that is being used
fd = df[temporal]
fd.loc_date.nunique()
# Out:
# 383

# %%
x = pd.read_csv("resources/checked_sdata_eos_2020_21.csv")
x.quantity.sum()
# Out:
# 54744

# %%
x.loc_date.nunique()
# Out:
# 386

# %%
fd['loc_dates'] = list(zip(fd.location.values, fd.date.values))
fd['date'] = pd.to_datetime(fd.date)

material_totals = fd.groupby('material').quantity.sum()
code_totals = fd.groupby(['code'], as_index=False).agg({unit_label:'median', 'quantity':'sum'})

# cumulative statistics for each code
code_totals["% of total"] = ((code_totals.quantity/code_totals.quantity.sum())*100).round(2)
code_totals["fail"] = code_totals.code.map(lambda x: fd[(fd.code == x) & (fd.quantity > 0)].loc_date.nunique())
code_totals["fail rate"] = ((code_totals.fail/fd.loc_date.nunique())*100).astype('int')
code_totals.set_index('code', inplace=True)
code_totals['material'] = code_totals.index.map(lambda x: code_material_map[x])
code_totals['item'] = code_totals.index.map(lambda x: code_description_map[x])

# daily survey totals
dt_all = fd.groupby(['loc_date','location',this_level, 'water_name_slug','city','date'], as_index=False).agg({unit_label:'sum', 'quantity':'sum'})

# gather the municpalities and the population:
fd_pop_map = dfBeaches.loc[fd.location.unique()][['city','population']].copy()
fd_pop_map.drop_duplicates(inplace=True)
fd_pop_map.set_index('city', drop=True, inplace=True)

# material totals
fd_mat_t = code_totals[['material', 'quantity']].groupby('material', as_index=False).quantity.sum()
fd_mat_t["% of total"] = fd_mat_t.quantity/fd_mat_t.quantity.sum()

# material table for display
fd_mat_totals = fd_mat_t.sort_values(by='quantity', ascending=False)
cols_to_use = {'material':'Material','quantity':'Quantity', '% of total':'% of total'}

# format columns for material table
fd_mat_totals['% of total'] =(fd_mat_totals['% of total']*100).round(1)
fd_mat_totals['quantity']=fd_mat_totals.quantity.map(lambda x: '{:,}'.format(x))
fd_mat_totals['% of total']=fd_mat_totals['% of total'].map(lambda x:F"{x}%")
fd_mat_t = fd_mat_totals[cols_to_use.keys()].values

# summary statistics:
# number of samples
fd_n_samps = len(dt_all)
# quantity
fd_n_obj = fd.quantity.sum()
# number of locations
fd_n_locs = fd.location.nunique()
# number of cities
fd_n_munis = len(fd_pop_map.index)
# populations
fd_effected_population = fd_pop_map.sum()
# list of locations
fd_locs = fd.location.unique()
# list of survey keys
fd_samps = fd.loc_date.unique()

# gather the dimensional data for the time frame from dfDims
fd_dims= dfDims[(dfDims.location.isin(fd_locs))&(dfDims.date >= start_date)&(dfDims.date <= end_date)].copy()
fd_dims['loc_dates'] = list(zip(fd_dims.location.values, fd_dims.date.values))


# map the survey area name to the dims data record
m_ap_to_survey_area = fd[['location', this_level]].drop_duplicates().to_dict(orient='records')
a_new_map = {x['location']:x[this_level] for x in m_ap_to_survey_area}
fd_dims['survey area'] = fd_dims.location.map(lambda x: ut.use_this_key(x, a_new_map))

# %%
fd.water_name_slug.unique()
# Out:
# array(['lac-leman', 'lago-di-lugano', 'cassarate', 'ticino',
#        'lago-maggiore', 'aarenidau-buren-kanal', 'limmat', 'emme',
#        'zugersee', 'neuenburgersee', 'thunersee', 'aare',
#        'quatre-cantons', 'bielersee', 'sihl', 'walensee', 'zurichsee',
#        'rhone', 'schuss', 'brienzersee', 'jona', 'reuss', 'linthkanal',
#        'maggia', 'la-thiele', 'dorfbach', 'escherkanal', 'seez'],
#       dtype=object)

# %%
pd.set_option('display.max_rows', 100)

# %%
a = fd[fd.w_t == 'l']
a = a[~a.location.isin(['quatre-cantons', 'zugersee'])].city.unique()
b = [i+1 for i,n in enumerate(a)]
pd.DataFrame({"num":b, "place":a})
# Out:
#     num               place
# 0     1    La Tour-de-Peilz
# 1     2         Préverenges
# 2     3              Lugano
# 3     4            Brissago
# 4     5          Gambarogno
# 5     6             Minusio
# 6     7                 Zug
# 7     8   Yverdon-les-Bains
# 8     9            Lausanne
# 9    10              Genève
# 10   11      Saint-Gingolph
# 11   12           Unterseen
# 12   13           Neuchâtel
# 13   14              Weggis
# 14   15         Biel/Bienne
# 15   16               Vevey
# 16   17              Vinelz
# 17   18              Erlach
# 18   19              Weesen
# 19   20     Rapperswil-Jona
# 20   21         Richterswil
# 21   22              Ascona
# 22   23          Walenstadt
# 23   24          Freienbach
# 24   25       Küsnacht (ZH)
# 25   26     Cheyres-Châbles
# 26   27                Thun
# 27   28              Zürich
# 28   29         Brienz (BE)
# 29   30               Spiez
# 30   31     Bourg-en-Lavaux
# 31   32             Allaman
# 32   33             Quarten
# 33   34            Lüscherz
# 34   35               Stäfa
# 35   36              Boudry
# 36   37               Nidau
# 37   38  Saint-Sulpice (VD)
# 38   39         Glarus Nord
# 39   40         Le Landeron
# 40   41            Montreux
# 41   42            Grandson
# 42   43          Beatenberg
# 43   44          Tolochenaz
# 44   45               Gland
# 45   46          Schmerikon
# 46   47           Estavayer
# 47   48             Versoix
# 48   49              Ligerz
# 49   50             Bönigen
# 50   51                Gals
# 51   52      Hauterive (NE)
# 52   53            Cudrefin

# %%
fd[fd.river_bassin == 'aare'].water_name_slug.unique()
# Out:
# array(['aarenidau-buren-kanal', 'emme', 'neuenburgersee', 'thunersee',
#        'aare', 'bielersee', 'schuss', 'brienzersee', 'la-thiele'],
#       dtype=object)

# %% [markdown]
# # Map - QGIS layer of contribution and distribution object results

# %%
dist = ['G67', 'Gfoam', 'G89', 'G95', 'Gfrags', 'G112', 'G74', 'G117']
cont = ['G27', 'G30', 'G178', 'G200']

d_c_d = fd[fd.code.isin([*dist, *cont])].copy()
d_c_d['dist'], d_c_d['cont'] = False, False
d_c_d.loc[d_c_d.code.isin(dist), 'dist'] = True
d_c_d.loc[d_c_d.code.isin(cont), 'cont'] = True

d_c_dq = d_c_d[(d_c_d.dist == True) | (d_c_d.cont == True)].copy()

# %%
gone = ["loc_date", "location", "dist","cont"]

dcdt = d_c_dq.groupby(gone, as_index=False)[unit_label].sum()

dcdt.head()
# Out:
#                              loc_date          location   dist   cont  p/100m
# 0            ('aabach', '2020-10-22')            aabach  False   True      33
# 1            ('aabach', '2020-10-22')            aabach   True  False      45
# 2  ('aare-limmatspitz', '2020-07-13')  aare-limmatspitz  False   True      10
# 3  ('aare-limmatspitz', '2020-07-13')  aare-limmatspitz   True  False      30
# 4         ('aare-port', '2021-04-23')         aare-port  False   True     132

# %%
dcdx = dcdt.groupby(["location", "dist","cont"], as_index=False)[unit_label].median()

# %%
lat_map = dfBeaches['latitude']
lon_map= dfBeaches['longitude']
dcdx = dcdx.set_index('location')
dcdx['latitude'] = dcdx.index.map(lambda x: lat_map.loc[x])
dcdx['longitude'] = dcdx.index.map(lambda x: lon_map.loc[x])

# %%
dist = dcdx[dcdx.dist == True].copy()
cont = dcdx[dcdx.cont == True].copy()

dist.to_csv("output/dist_map/dists.csv", index=False)
cont.to_csv("output/dist_map/conts.csv", index=False)

# %%
f_c = fd[fd.code.isin(['G27', 'Gfrags', 'Gfoam', 'G89', 'G112'])].copy()
f_cdt = f_c.groupby(['loc_date','location', 'code'], as_index=False)[unit_label].sum()
f_cdt = f_cdt.groupby(['location', 'code'], as_index=False)[unit_label].median()

# %%
f_cd = f_cdt.pivot(columns='code', values=unit_label, index='location')
f_cd['latitude'] = f_cd.index.map(lambda x: lat_map.loc[x])
f_cd['longitude'] = f_cd.index.map(lambda x: lon_map.loc[x])

f_cd['ratio'] = f_cd.Gfrags/f_cd.G27
f_cd.fillna(0, inplace=True)
f_cd.head()
# Out:
# code                        G112    G27  G89  Gfoam  Gfrags   latitude  \
# location
# aabach                      23.0   23.0  3.0    0.0     3.0  47.220989
# aare-limmatspitz             0.0    2.0  0.0    7.0     3.0  47.501060
# aare-port                    0.0  112.0  0.0    0.0    28.0  47.116170
# aare-solothurn-lido-strand   0.0  100.0  0.0    0.0     0.0  47.196949
# aare_bern_gerberm            0.0   19.0  3.0    0.0     5.0  46.989363
#
# code                        longitude     ratio
# location
# aabach                       8.940365  0.130435
# aare-limmatspitz             8.237371  1.500000
# aare-port                    7.269550  0.250000
# aare-solothurn-lido-strand   7.521643  0.000000
# aare_bern_gerberm            7.452098  0.263158

# %%
nsamps = fd.groupby('location').loc_date.nunique()
new_gis =  dfBeaches.merge(f_cd)
new_gis.head()
# Out:
#                      location   latitude  longitude  post country water  \
# 0                      Aabach  47.220989   8.940365  8716      CH     l
# 1            Aare Limmatspitz  47.501060   8.237371  5300      CH     r
# 2                   Aare Port  47.116170   7.269550  2558      CH     r
# 3  Aare Solothurn Lido Strand  47.196949   7.521643  4500      CH     r
# 4           Aare_bern_gerberm  46.989363   7.452098  3004      CH     r
#
#                water_name   city_slug        water_name_slug  is_2020  ...  \
# 0               Zurichsee  schmerikon              zurichsee     True  ...
# 1                    Aare  gebenstorf                   aare     True  ...
# 2  Aare|Nidau-Büren-Kanal        port  aarenidau-buren-kanal     True  ...
# 3                    Aare   solothurn                   aare     True  ...
# 4                    Aare        bern                   aare     True  ...
#
#   % to water  % to unproductive  is_slr   both  G112    G27  G89  Gfoam  \
# 0   0.520518           0.118790   False  False  23.0   23.0  3.0    0.0
# 1   0.118671           0.003165   False  False   0.0    2.0  0.0    7.0
# 2   0.041116           0.001468   False  False   0.0  112.0  0.0    0.0
# 3   0.069697           0.001515   False  False   0.0  100.0  0.0    0.0
# 4   0.039589           0.001466    True   True   0.0   19.0  3.0    0.0
#
#    Gfrags     ratio
# 0     3.0  0.130435
# 1     3.0  1.500000
# 2    28.0  0.250000
# 3     0.0  0.000000
# 4     5.0  0.263158
#
# [5 rows x 88 columns]

# %%
new_gis = pd.concat([dfBeaches.loc[fd_locs],f_cd], axis=1)

new_gis["samps"] = new_gis.index.map(lambda x: nsamps.loc[x])

new_gis.to_csv("output/dist_map/ratios.csv", index=False)

# %%
fd[fd.river_bassin == 'ticino'].water_name_slug.unique()
# Out:
# array(['lago-di-lugano', 'cassarate', 'ticino', 'lago-maggiore', 'maggia'],
#       dtype=object)

# %%
a = fd[fd.date < "2021-02-01"]
a.location.nunique()
# Out:
# 111

# %%
a.loc_date.nunique()
# Out:
# 303

# %% [markdown]
# ### Model nb dist

# %% [markdown]
# ## notes
#
# 1. Find the likelihood for a single observation
# 2. Find the log-liklihood for a single observation
# 3. Take the derivative of log-likelihood with respect to $\theta$
# 5. Set the score function to zero and solve for theta

# %%
exps = ['population','% to buildings', '% to trans', '% to recreation', '% to agg', '% to woods', 'streets']
gone = ["loc_date", "location", "dist","cont"]
dandc = d_c_d.groupby([*gone, *exps], as_index=False)[unit_label].sum()
gfrag = fd[fd.code == 'Gfrags'].groupby([*gone[:2], *exps], as_index=False)[unit_label].sum()
g27 = fd[fd.code == 'G27'].groupby([*gone[:2], *exps], as_index=False)[unit_label].sum()
sts = fd.groupby([*gone[:2], *exps], as_index=False)[unit_label].sum()

# %%
# check the dispersion fo the three data types
dandc_mean, dandc_var = dandc[unit_label].mean(), dandc[unit_label].var()
print(dandc_mean, dandc_var)
# Out:
# 103.26943005181347 43065.31512133492

# %%
dtall_mean, dtall_var = dt_all[unit_label].mean(), dt_all[unit_label].var()
print(dtall_mean, dtall_var)
# Out:
# 327.940414507772 282463.7029338537

# %%
g27_mean, g27_var = g27[unit_label].mean(), g27[unit_label].var()
print(g27_mean, g27_var )
# Out:
# 54.24352331606217 9987.332750151401

# %%
gfrag_mean, gfrag_var = gfrag[unit_label].mean(), gfrag[unit_label].var()
print(gfrag_mean, gfrag_var )
# Out:
# 22.0440414507772 2549.107146221654

# %% [markdown]
# **sts should equal dt_all**

# %%
sts_mean, sts_var = sts[unit_label].mean(), sts[unit_label].var()
print(sts_mean, sts_var )
# Out:
# 327.940414507772 282463.7029338537

# %%
data= d_c_d.groupby(gone, as_index=False)[unit_label].sum()
data[(data.cont == False)&(data.dist == False)][unit_label].to_numpy()
# Out:
# array([], dtype=int64)

# %%
d_ec = ECDF(data[data.dist == True][unit_label].to_numpy())
c_ec = ECDF(data[data.cont == True][unit_label].to_numpy())
g27_ec = ECDF(g27[unit_label].to_numpy())
gfrag_ec = ECDF(gfrag[unit_label].to_numpy())

fig, ax = plt.subplots(figsize=(8,8))

sns.lineplot(x=d_ec.x, y=d_ec.y, color='salmon', label='distribution', ax=ax)
sns.lineplot(x=c_ec.x, y=c_ec.y, color='dodgerblue', label='contribution', ax=ax)
sns.lineplot(x=g27_ec.x, y=g27_ec.y, color='red', label='G27', ax=ax)
sns.lineplot(x=gfrag_ec.x, y=gfrag_ec.y, color='blue', label='Gfrag', ax=ax)
plt.show()

# %%
# merge into one 
objs_merged = data[['loc_date', 'location', 'dist', unit_label]].copy()

# store the mean per class
the_mean = objs_merged.groupby('dist')[unit_label].mean()

# store the difference
mean_diff = the_mean.loc[True] - the_mean.loc[False]
new_means=[]
# permutation resampling:
for element in np.arange(5000):
    objs_merged['new_class'] = objs_merged['dist'].sample(frac=1).values
    b=objs_merged.groupby('new_class').mean()
    new_means.append((b.loc[True] - b.loc[False]).values[0])
emp_p = np.count_nonzero(new_means >= (the_mean.loc[True] - the_mean.loc[False])) / 5000

# chart the results
fig, ax = plt.subplots()

sns.histplot(new_means, ax=ax)
ax.set_title(F"$\u0394\mu$ = {np.round(mean_diff, 2)}, perm=5000, p={emp_p} ", **ck.title_k14)
ax.set_ylabel('permutations', **ck.xlab_k14)
ax.set_xlabel("$\mu$ distribtuion - $\mu$ contribution", **ck.xlab_k14)
plt.show()

# %%
# make svg

# %%
colors_palette = {
    'G156':'dimgray', 'G178': 'teal',
    'G177': 'darkslategray',
    'G200': 'lightseagreen',
    'G27':'darkorange',
    'G30':'darkkhaki',
    'G67':'rosybrown',
    'G89': 'salmon',
    'G95':'magenta',
    'G82': 'maroon',
    'G79':'brown',
    'G208': 'turquoise',
    'G124':'indigo',
    'G25': 'chocolate',
    'G31': 'goldenrod',
    'G21':'tan',
    'Gfrags':'brown',
    'Gfoam':'maroon',
    'G117':'cornsilk',
    'G941':'plum',
    'G74':'coral',
    'G112': 'yellow',
    'G24':'navajowhite',
    'G23':'peru',
    'G100':'pink',
    'G32':'khaki',
    'G33':'lemonchiffon',
    'G35':'blue'
    
}

# %%
dist = ['G67', 'Gfoam', 'G89', 'G95', 'Gfrags', 'G112', 'G74', 'G117']
cont = ['G27', 'G30', 'G178', 'G200']

d_and_c = ["Gfoam", "Gfrags",'G27', 'G30']

# %%
fd.date.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0       2021-05-01
# 1       2021-05-01
# 2       2021-05-01
# 3       2021-05-01
# 4       2021-05-01
#            ...
# 87617   2020-10-13
# 87618   2020-11-12
# 87619   2020-12-10
# 87620   2021-01-10
# 87621   2021-02-12
# Name: date, Length: 87622, dtype: datetime64[ns]>

# %%
fd.head()
# Out:
#         date  code  pcs_m  quantity   location                     loc_date  \
# 0 2021-05-01  G155   0.01         1  maladaire  ('maladaire', '2021-05-01')
# 1 2021-05-01   G27   0.35        27  maladaire  ('maladaire', '2021-05-01')
# 2 2021-05-01  G177   0.01         1  maladaire  ('maladaire', '2021-05-01')
# 3 2021-05-01   G31   0.03         2  maladaire  ('maladaire', '2021-05-01')
# 4 2021-05-01  G940   0.01         1  maladaire  ('maladaire', '2021-05-01')
#
#   water_name_slug river_bassin       groupname  population  ...  p/100m  \
# 0       lac-leman        rhone      recreation     11828.0  ...       1
# 1       lac-leman        rhone         tobacco     11828.0  ...      35
# 2       lac-leman        rhone  food and drink     11828.0  ...       1
# 3       lac-leman        rhone  food and drink     11828.0  ...       3
# 4       lac-leman        rhone      recreation     11828.0  ...       1
#
#    material              city  w_t  month         eom  length   area  water  \
# 0     Paper  La Tour-de-Peilz    l      5  2021-05-31      77  231.0      l
# 1   Plastic  La Tour-de-Peilz    l      5  2021-05-31      77  231.0      l
# 2     Metal  La Tour-de-Peilz    l      5  2021-05-31      77  231.0      l
# 3   Plastic  La Tour-de-Peilz    l      5  2021-05-31      77  231.0      l
# 4   Plastic  La Tour-de-Peilz    l      5  2021-05-31      77  231.0      l
#
#                  loc_dates
# 0  (maladaire, 2021-05-01)
# 1  (maladaire, 2021-05-01)
# 2  (maladaire, 2021-05-01)
# 3  (maladaire, 2021-05-01)
# 4  (maladaire, 2021-05-01)
#
# [5 rows x 32 columns]

# %%
b.head()
# Out:
#                dist      p/100m
# new_class
# False      0.487047   97.878238
# True       0.512953  108.660622

# %%
b = fd.groupby(['loc_date', 'location', 'city','code'], as_index=False).agg({unit_label:'sum', 'quantity':'sum'})

# %%
dts = b[b.code.isin(d_and_c )].groupby(['city','code'], as_index=False)[unit_label].mean().round(1)
dts.pivot(columns='code', index='city', values=unit_label)
# Out:
# code                G27   G30  Gfoam  Gfrags
# city
# Aarau               0.0   0.0    5.0     0.0
# Allaman            37.0  53.0    9.3    44.7
# Ascona             98.2  14.8    3.4     9.8
# Beatenberg         54.5  12.0    9.5    32.5
# Bellinzona         11.5   0.5    0.0     1.2
# ...                 ...   ...    ...     ...
# Weesen             20.6   5.9    3.5     3.9
# Weggis             12.7   4.7    2.7     0.0
# Yverdon-les-Bains  17.6  10.4    2.6    13.4
# Zug                22.0   2.7    0.0     0.0
# Zürich             74.0  25.2    6.9    15.4
#
# [77 rows x 4 columns]

# %%
cdt = b.groupby('city', as_index=False).agg({unit_label:'mean', 'quantity':'sum', 'loc_date':'nunique'})
cdt[unit_label] = cdt[unit_label].round(1)
cdt.rename(columns={unit_label:'pcs/m', 'quantity':'Q', 'loc_date':'S', 'location':'L'}, inplace = True)

cdt
# Out:
#                  city  pcs/m     Q   S
# 0               Aarau    0.2     7   1
# 1             Allaman    2.8   631   3
# 2              Ascona    1.0   433   5
# 3          Beatenberg    1.0   104   2
# 4          Bellinzona    0.5   187   4
# ..                ...    ...   ...  ..
# 72             Weesen    0.4  1033  14
# 73             Weggis    0.3    58   3
# 74  Yverdon-les-Bains    0.5  1446  14
# 75                Zug    0.3    62   3
# 76             Zürich    1.4  2564  20
#
# [77 rows x 4 columns]

# %%
agg_pcs_quantity = {unit_label:'sum', 'quantity':'sum'}

# %%
fd.columns
# Out:
# Index(['date', 'code', 'pcs_m', 'quantity', 'location', 'loc_date',
#        'water_name_slug', 'river_bassin', 'groupname', 'population', 'streets',
#        'intersects', 'string_date', 'fail', '% to buildings', '% to trans',
#        '% to recreation', '% to agg', '% to woods', '% to water',
#        '% to unproductive', 'streets km', 'p/100m', 'material', 'city', 'w_t',
#        'month', 'eom', 'length', 'area', 'water', 'loc_dates'],
#       dtype='object')

# %%
# code groups aggregated by survey for each survey area
cg_t = fd.groupby(['river_bassin','loc_date', 'groupname'], as_index=False).agg(agg_pcs_quantity)

# get the fail rates for each group per survey
cg_t['fail']=False
cg_t['fail'] = cg_t.quantity.where(lambda x: x == 0, True)

# aggregate all that for each survey area
cg_t = cg_t.groupby(['river_bassin', 'groupname'], as_index=False).agg({unit_label:'mean', 'quantity':'sum', 'fail':'sum', 'loc_date':'nunique'})
cg_t.head()
# Out:
#   river_bassin               groupname     p/100m  quantity  fail  loc_date
# 0         aare             agriculture  18.857143       983   113       140
# 1         aare          food and drink  43.935714      2683   137       140
# 2         aare          infrastructure  20.364286      1834   127       140
# 3         aare  micro plastics (< 5mm)  10.042857       698    74       140
# 4         aare      packaging non food  15.300000       931   121       140

# %%
# quantity per water survey area
cg_tq = cg_t.groupby('river_bassin').quantity.sum()

# assign survey area total to each record
for a_feature in cg_tq.index:
    cg_t.loc[cg_t.river_bassin == a_feature, 'f_total'] = cg_tq.loc[a_feature]

# get the percent of total for each group for each survey area
cg_t['pt'] = (cg_t.quantity/cg_t.f_total).round(2)

# pivot that
data_table = cg_t.pivot(columns='river_bassin', index='groupname', values='pt')

# add a column for the survey area totals and the national totals:
# the aggregated totals for the survey area

# the median value is always calculated from the survey result:
sa_cg = fd.groupby(['river_bassin', 'loc_date','groupname'], as_index=False).agg(agg_pcs_quantity)

# the median value is always calculated from the survey result:
sa_cg = fd.groupby(['river_bassin', 'groupname'], as_index=False).agg({unit_label:'median', 'quantity':'sum'})

# aggregate all data
fd_cg = sa_cg.groupby('groupname', as_index=False).agg({unit_label:'median', 'quantity':'sum'})

# add percent of total column
fd_cg['pt'] = (fd_cg.quantity/fd_cg.quantity.sum()).round(2)

# set the index
fd_cg.set_index('groupname', inplace=True)

# name survey area column
fd_cg[top_name[0]] = fd_cg['pt']

data_pt = pd.concat([data_table, fd_cg[top_name[0]]], axis=1)

# %%
len(data_pt.columns)
# Out:
# 5

# %%
data_pt
# Out:
#                         aare  linth  rhone  ticino  All survey areas
# groupname
# agriculture             0.07   0.06   0.05    0.04              0.06
# food and drink          0.19   0.22   0.18    0.21              0.19
# infrastructure          0.13   0.15   0.22    0.16              0.18
# micro plastics (< 5mm)  0.05   0.03   0.10    0.10              0.08
# packaging non food      0.07   0.07   0.04    0.06              0.05
# personal items          0.03   0.04   0.02    0.03              0.03
# plastic pieces          0.14   0.10   0.15    0.09              0.14
# recreation              0.05   0.05   0.04    0.02              0.04
# tobacco                 0.20   0.24   0.12    0.26              0.17
# unclassified            0.01   0.01   0.01    0.00              0.01
# waste water             0.04   0.02   0.06    0.02              0.05

# %%
unit_label
# Out:
# 'p/100m'

# %%
# median p/50m solve cg_t for unit_label
data_table = cg_t.pivot(columns='river_bassin', index='groupname', values=unit_label)
data_table = data_table.applymap(lambda x: round(x, 1))
# column for all the data
a = fd.groupby(['groupname', 'loc_date'], as_index=False)[unit_label].sum()
a[top_name[0]] = a[unit_label]
a = a.groupby('groupname')[top_name[0]].mean()
a = a.round()

# stick that together
data = pd.concat([data_table, a], axis=1)

# format for display
data.rename(columns={x:comp_labels[x] for x in data.columns[:-2]}, inplace=True)

fig, ax = plt.subplots(figsize=(14,18.5))

axone = ax
sns.heatmap(data , ax=axone, cmap=cmap2, annot=True, annot_kws={"fontsize":24}, fmt='g', cbar=False, linewidth=.1, square=True, linecolor='white')

axone.set_ylabel("")
axone.tick_params(labelsize=20, which='both', axis='both', labeltop=True, labelbottom=False, bottom=False)

plt.setp(axone.get_xticklabels(), rotation=90, fontsize=20)
plt.setp(axone.get_yticklabels(), rotation=0, fontsize=20)
plt.savefig('output/try.svg')
plt.show()

# %%
# aggregate the survey data
fd_dims['loc_date'] = list(zip(fd_dims.location.astype('str'), fd_dims.date.astype('str')))
a = dt_all.set_index('loc_date')['quantity']

# map quantity per survey to the dims data
fd_dims['quantity'] = fd_dims.loc_date.map(lambda x: ut.use_this_key(x, a))

# keep the dims that did not get tagged with a qty
no_qty = fd_dims[fd_dims.quantity == 'bad key']

# drop the dims that did not match
som_dims = fd_dims[fd_dims.quantity != 'bad key'].copy()
som_dims['survey area'] = som_dims['survey area'].map(lambda x: comp_labels[x])
dims_table = som_dims.groupby(['survey area']).agg({'quantity':'sum','total_w':'sum', 'mac_plast_w':'sum', 'area':'sum', 'length':'sum'})


# row shading for chart
a_color='dodgerblue'

# format the aggregated dimensional data for printing
dims_table.rename(columns={'samples':'samples','quantity':'items', 'total_w':'total kg', 'mac_plast_w':'plastic kg', 'area':'m²', 'length':'meters'}, inplace=True)

dims_table.loc['All survey areas']= dims_table.sum(numeric_only=True, axis=0)
# format kilos
dims_table['plastic kg'] = dims_table['plastic kg']/1000
dims_table[[x for x in dims_table.columns if x not in ['plastic kg', 'total kg']]] = dims_table[[x for x in dims_table.columns if x not in ['plastic kg', 'total kg']]].applymap(lambda x: '{:,}'.format(int(x)))



dims_table[['plastic kg', 'total kg']] = dims_table[['plastic kg', 'total kg']].applymap(lambda x: '{:.2f}'.format(x))

# make table
data = dims_table.reset_index()

# get the sum of all survey areas
# dims_table['survey area'] = dims_table['survey area'].map(lambda x: comp_labels[x])

# %%
data
# Out:
#         survey area items total kg plastic kg m² meters
# 0  All survey areas     0     0.00       0.00  0      0

# %%
def make_a_summary_table(ax, data, cols_to_use, a_color='dodgerblue', font_size=12, s_et_bottom_row=True):
    """ Makes a table of values with alternate row cololrs.

    Args:
    ax: object: matplotlib table object
    data: array: the 2d array used to generate the table object
    cols_to_use: array: the list of column names
    a_color: str: matplotlib named color, face and edgecolor of table cells
    font_size: int: the font size for the table cells
    s_et_bottom_row: bool: whether or not to draw bottom line on the last row

    Returns:
    The table object formatted.
    """

    ax.auto_set_font_size(False)
    the_cells = ax.get_celld()

    line_color = mpl.colors.to_rgba(a_color)
    banded_color = (*line_color[:-1], 0.1)

    # the different areas of formatting
    top_row = [(0, i) for i, x in enumerate(cols_to_use)]
    bottom_row = [(len(data), i) for i, x in enumerate(cols_to_use)]
    top_columns = top_row[1:]
    data_rows = [x for x in list(the_cells.keys()) if x not in top_row]
    odd_rows = [x for x in data_rows if x[0] % 2 > 0]
    first_column = [x for x in data_rows if x[1] == 0]

    # make the first cell a littel smaller than the others
    ax[0, 0].set_height(1 / (len(data)))
    ax[0, 0].set_text_props(**{'va': 'top'})

    for a_cell in top_row:
        ax[a_cell].visible_edges = 'B'
        ax[a_cell].set_text_props(**{'fontsize': font_size})
        ax[a_cell].set_edgecolor('white')
        ax[a_cell].PAD = .2

    for a_cell in top_columns:
        ax[a_cell].set_height((1.25 / (len(data))))
        ax[a_cell].set_text_props(**{'va': 'center'})

        ax[a_cell].set_edgecolor(line_color)
        ax[a_cell].visible_edges = 'T'

    for a_cell in odd_rows:
        ax[a_cell].set_facecolor(banded_color)

    for a_cell in data_rows:
        ax[a_cell].set_height(.75 / (len(data)))
        ax[a_cell].visible_edges = 'BTLR'
        ax[a_cell].set_text_props(**{'fontsize': font_size})
        ax[a_cell].set_edgecolor('white')
        ax[a_cell]._text.set_horizontalalignment('center')

    for a_cell in first_column:
        ax[a_cell]._text.set_horizontalalignment('right')
        ax[a_cell].PAD = .02

    if s_et_bottom_row is True:
        for a_cell in bottom_row:
            ax[a_cell].visible_edges = 'B'
            ax[a_cell].set_edgecolor(line_color)
            ax[a_cell].set_facecolor(banded_color)
           
                
                

    return ax


fig, axs = plt.subplots(figsize=(len(data.columns)*2,len(data)*1.1))
ut.hide_spines_ticks_grids(axs)

the_first_table_data = axs.table(data.values,  colLabels=data.columns, colWidths=[.22, *[.13]*6], bbox=[0, 0, 1, 1])

a_summary_table_one = make_a_summary_table(the_first_table_data,data.values,data.columns, a_color, font_size=20, s_et_bottom_row=False)

a_summary_table_one.get_celld()[(0,0)].get_text().set_text(" ")
plt.tight_layout()
plt.savefig('output/try2.svg')
plt.show()

plt.close()

# %%
# the surveys to chart
fd_dindex = dt_all.set_index('date')
sns.set_style('whitegrid')

# monthly median survey total
monthly_plot = fd_dindex[unit_label].resample('M').median()

# scale the chart as needed to accomodate for extreme values
scale_back = 98
# the results gets applied to the y_limit function in the chart
the_90th = np.percentile(dt_all[unit_label], scale_back)

# months locator, can be confusing
# https://matplotlib.org/stable/api/dates_api.html
months = mdates.MonthLocator(interval=1)
months_fmt = mdates.DateFormatter('%b')
days = mdates.DayLocator(interval=7)
fig, ax = plt.subplots(figsize=(10,10))

rate = "Monthly"

line_label = "monthly median"


sns.scatterplot(data=fd_dindex, x='date', y=unit_label, hue='river_bassin', s=100, palette=bassin_pallette, alpha=0.8, ax=ax)

sns.lineplot(data=monthly_plot, x=monthly_plot.index, y=monthly_plot, color='magenta', label=line_label, ax=ax)

ax.set_ylim(0,the_90th )

ax.set_xlabel("")
ax.set_ylabel(unit_label, fontsize=20, labelpad=20)

ax.xaxis.set_minor_locator(days)
ax.xaxis.set_major_formatter(months_fmt)

ax.tick_params(labelsize=20, which='both', axis='both')

plt.tight_layout()
plt.savefig('output/try3.svg')
plt.show()
plt.close()

# %%
# the labels for the summary table:
change_names = {'count':'# samples', 
                'mean':F"average {unit_label}",
                'std':'standard deviation', 
                'min p/50m':'min', '25%':'25%',
                '50%':'50%', '75%':'75%',
                'max':F"max {unit_label}", 'min':F"min {unit_label}",
                'total objects':'total objects',
                '# locations':'# locations',
                'survey year':'survey year'
               }

# convenience function to change the index names in a series
def anew_dict(x):
    new_dict = {}
    for param in x.index:
        new_dict.update({change_names[param]:x[param]})
    return new_dict  

# select data
data = dt_all

# get the basic statistics from pd.describe
desc_2020 = data[unit_label].describe().round(2)

# add project totals
desc_2020['total objects'] = data.quantity.sum()
desc_2020['# locations'] = fd.location.nunique()

# change the names
combined_summary = pd.Series(anew_dict(desc_2020))

# format the output for printing:
samples = (desc_2020.index[0], int(desc_2020.loc[desc_2020.index[0]]))
total = ('total objects', "{:,}".format(int(desc_2020.loc['total objects'])))
cs = [(x, "{:,}".format((combined_summary[x]))) for x in combined_summary.index[1:-2] ]
cs.append(total)

combined_summary = [samples, *cs]

# make tables
fig, axs = plt.subplots(1,2, figsize=(10,8))

# summary table
# names for the table columns
a_col = [top_name[0], 'total']

axone = axs[0]
ut.hide_spines_ticks_grids(axone)

a_table = axone.table(cellText=combined_summary,  colLabels=a_col, colWidths=[.5,.25,.25], loc='lower center', bbox=[0,0,1,1])
the_material_table_data = make_a_summary_table(a_table,combined_summary[:-1],a_col, s_et_bottom_row=False, font_size=20)
the_material_table_data.get_celld()[(0,0)].get_text().set_text(" ")
# material table
axtwo = axs[1]
axtwo.set_xlabel(" ")
ut.hide_spines_ticks_grids(axtwo)

# data to use
data = fd_mat_t.copy()

# column names for display
cols_to_use = {'material':'Material','quantity':'Quantity', '% of total':'% of total'}

a_table = axtwo.table(cellText=data,  colLabels=list(cols_to_use.values()), colWidths=[.4, .3,.3], loc='lower center', bbox=[0,0,1,1])
the_material_table_data = make_a_summary_table(a_table,data,list(cols_to_use.values()), s_et_bottom_row=False, font_size=20)
the_material_table_data.get_celld()[(0,0)].get_text().set_text(" ")
plt.tight_layout()
plt.subplots_adjust(wspace=0.2)
plt.savefig('output/try4.svg')
plt.show()

# %%
# format values for table
# the top ten by quantity
most_abundant = code_totals.sort_values(by='quantity', ascending=False)[:10]

# the most common
most_common = code_totals[code_totals["fail rate"] > 50].sort_values(by='quantity', ascending=False)

# merge with most_common and drop duplicates
m_common = pd.concat([most_abundant, most_common]).drop_duplicates()
m_common['item'] = m_common.index.map(lambda x: code_description_map.loc[x])
m_common['% of total'] = m_common["% of total"].map(lambda x: F"{x}%")
m_common['quantity'] = m_common.quantity.map(lambda x: '{:,}'.format(x))
m_common['fail rate'] = m_common['fail rate'].map(lambda x: F"{x}%")
m_common[unit_label] = m_common[unit_label].round(1)

# final table data
cols_to_use = {'item':'Item','quantity':'Quantity', '% of total':'% of total', 'fail rate':'fail rate',unit_label:unit_label}
all_survey_areas = m_common[cols_to_use.keys()].values

fig, axs = plt.subplots(figsize=(11,len(m_common)*1))

ut.hide_spines_ticks_grids(axs)

the_first_table_data = axs.table(all_survey_areas,  colLabels=list(cols_to_use.values()), colWidths=[.4, .13,.13,.13, .13], bbox=[0, 0, 1, 1])

a_summary_table_one = make_a_summary_table(the_first_table_data,m_common,list(cols_to_use.values()), a_color, font_size=20)
a_summary_table_one.get_celld()[(0,0)].get_text().set_text(" ")
plt.tight_layout()
plt.savefig('output/try5.svg')
plt.show()
plt.close()

# %%
m_common_st = fd[fd.code.isin(m_common.index)].groupby(['river_bassin', 'loc_date','code'], as_index=False).agg(agg_pcs_quantity)
m_common_ft = m_common_st.groupby(['river_bassin', 'code'], as_index=False)[unit_label].mean()

# proper name of water feature for display
m_common_ft['f_name'] = m_common_ft.river_bassin.map(lambda x: comp_labels[x])

# map the desctiption to the code
m_common_ft['item'] = m_common_ft.code.map(lambda x: code_description_map.loc[x])

# pivot that
m_c_p = m_common_ft[['item', unit_label, 'f_name']].pivot(columns='f_name', index='item')

# quash the hierarchal column index
m_c_p.columns = m_c_p.columns.get_level_values(1)

# the aggregated totals all the data
fd_mc = fd[fd.code.isin(m_common.index)].groupby(['loc_date','code'], as_index=False).agg(agg_pcs_quantity)
fd_mc = fd_mc.groupby('code', as_index=False)[unit_label].median()

# set the item, index and column name for the aggregated survey area results
fd_mc['item'] = fd_mc.code.map(lambda x: code_description_map.loc[x])
fd_mc.set_index('item', inplace=True)

# the column of values for the survye area
fd_mc[top_name[0]] = fd_mc[unit_label]
ad_t_ten = pd.concat([m_c_p, fd_mc[top_name[0]]], axis=1).sort_values(by=top_name[0], ascending=False)

# chart that
fig, ax  = plt.subplots(figsize=(14,18.5))
axone = ax

sns.heatmap(ad_t_ten, ax=axone, cmap=cmap2, annot=True, annot_kws={"fontsize":20}, fmt=".1f", square=True, cbar=False, linewidth=.1, linecolor='white')

axone.set_ylabel("")
axone.tick_params(labelsize=20, which='both', axis='both')

plt.setp(axone.get_xticklabels(), rotation=90)
plt.savefig('output/try6.svg')
plt.show()

plt.close()
