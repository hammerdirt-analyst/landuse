# %%
# sys, file and nav packages:
import datetime as dt
import json
import functools
import time

# math packages:
import pandas as pd
import numpy as np
from scipy import stats
from statsmodels.distributions.empirical_distribution import ECDF

# charting:
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import ticker
from matplotlib import colors
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.gridspec import GridSpec
from mpl_toolkits.axes_grid1 import make_axes_locatable
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

import seaborn as sns

import IPython
from PIL import Image as PILImage
from IPython.display import Markdown as md
from IPython.display import display
from myst_nb import glue

import time

start_date = '2020-03-01'
end_date ='2021-05-31'

a_qty = 20

a_fail_rate = .5

use_fail = False

unit_label = 'p/100m'

# survey data:
dfx= pd.read_csv('resources/checked_sdata_eos_2020_21.csv')


dfBeaches = pd.read_csv("resources/beaches_with_land_use_rates.csv")
dfCodes = pd.read_csv("resources/codes_with_group_names_2015.csv")

# set the index of the beach data to location slug
dfBeaches.set_index('slug', inplace=True)

# set the index of to codes
dfCodes.set_index("code", inplace=True)

# code description map
code_d_map = dfCodes.description

# code material map
code_m_map = dfCodes.material

def scaleTheColumn(x):
    
    xmin = x.min()
    xmax = x.max()
    xscaled = (x-xmin)/(xmax-xmin)
    
    return xscaled



# this defines the css rules for the note-book table displays
header_row = {'selector': 'th:nth-child(1)', 'props': f'background-color: #FFF;'}
even_rows = {"selector": 'tr:nth-child(even)', 'props': f'background-color: rgba(139, 69, 19, 0.08);'}
odd_rows = {'selector': 'tr:nth-child(odd)', 'props': 'background: #FFF;'}
table_font = {'selector': 'tr', 'props': 'font-size: 12px;'}
table_css_styles = [even_rows, odd_rows, table_font, header_row]

# %% [markdown]
# # All Data
#
# This document details the methods used for the land use chapter of the IQAASL report. It has been expanded to include the supporting calculations for a manuscript based on the concepts intitially introduced in the report. Before consulting the results of all the data it may be interesting to understand how these figures relate when the same methods are applied at a smaller scale, such as a lake. See the previous two examples: Bielersee and Lac Léman.
#
# The calculations are the same at each Geopraphic level. The number of samples and the mix of landuse attributes changes with every subset of data. It is those changes and how they relate to the magnitude of trash encountered that concerns these enquiries. This document assumes the reader knows what beach-litter monitoring is and how it applies to the health of the environment.
#
# A statistical test is not a replacement for common sense. It is an another piece of evidence to consider along with the results from previous studies, the researchers personal experience as well as the history of the problem within the geographic constraints of the data.
#
# ## Notes
#
# __excluded data__
#
# At the time the report was published we did not have access to the land use data around Walensee. The good news is that it is now available with the most recent download. However, for this example the __data from Walensee is excluded__. This includes all samples that were taken in the region represented in the map below.

# %% [markdown]
# ```{figure} resources/images/walensee_scaled.jpeg
# ---
# name: 'walensee-map'
# ---
# ` `
# ```
# {numref}`figure %s: <walensee-map>` Detail of the survey area for where there was no land use data.

# %% [markdown]
# __objects of interest__
#
# The objects of interest are defined as __those objects where 20 or more were collected at one or more surveys__. In reference to the default data: that is the value of the quantity column:

# %%
pdtype = pd.core.frame.DataFrame
pstype = pd.core.series.Series



new_label_keys = {
    1:"industrial",
    2:"buildings",
    3:"buildings",
    4:"buildings",
    5:"buildings",
    6:"transport",
    7:"transport",
    8:"transport",
    9:"buildings",
    10:"recreation",
    11:"agriculture",
    12:"agriculture",
    13:"agriculture",
    14:"agriculture",
    15:"agriculture",
    16:"agriculture",
    17:"woods",
    18:"agriculture",
    19:"woods",
    20:"woods",
    21:"woods",
    22:"woods",
    23:"water",
    24:"water",
    25:"unproductive",
    26:"unproductive",
    27:"unproductive"
}


def combineLandUseFeatures(buffer_data: pdtype = None, a_col: str = "AS18_27", new_col: str = "label",
                           new_label_keys: dict = new_label_keys) -> pdtype:
    """Assigns labels to landuse values according to <label_keys_new>. The new labels,
    when aggregated, create groups of landuse values that are similar. For exmaple,
    all the different types of buildings are labeled "buildings"
    
    Args:
        buffer_data: The land use values at a given radius
        a_col: The original column name that holds the labels for the land use values
        new_col: The new name of the column with the new labels
    
    Returns:
        The data frame with the new column and the new labels    
    """    
    
    buffer_data.rename(columns={"slug":"location", a_col:new_col}, inplace=True)
    buffer_data[new_col] = buffer_data[new_col].apply(lambda x : new_label_keys[x])
    
    return buffer_data

def adjustLandUse(buffer_data: pdtype = None, exclude_these: list = [], locations: list = []) -> pdtype:
    """The surface area of the water feature is removed from landuse calcluation. This
    can be bypassed. However, the study considers the surface area of the water as a fixed
    feature that exchanges with the different landuse features (which are not fixed).
    
    Args:
        buffer_data: The land use values at a given radius
        exclude_these: The labels to be excluded from the land use total
        locations: The locations of interest with buffer data
        
    Returns:
        The dataframe with the locations in locations and without the excluded labels      
    """
    data = buffer_data[~buffer_data.label.isin(exclude_these)]
    data = data[data.location.isin(locations)]
    
    return data

def addRoadLengthToBuffer(buffer_data: pdtype = None, location: str = None, 
                          road_lengths: pstype = None, scale: float = 1000.0):
    """Adds the length of road network to the % land use values.
    """
    
    road_length = road_lengths.loc[location]
    if scale != 1:
        road_length = round(road_length/scale, 1)
    
    buffer_data["roads"] = road_length
    
    return buffer_data

def addIntersectsToBuffer(buffer_data: pdtype = None, location: str = None, 
                          intersects: pstype = None, scale: float = 100.0):
    
    """Adds the number of river intersections to the buffer.
    
    The river intersections are the points where rivers join the body of water of interest
    """
    
    n_intersects = intersects.loc[location]
        
    buffer_data["intersects"] = n_intersects
    
    return buffer_data


def calculatePercentLandUse(buffer_data: pdtype = None, location: str = None, label: str = "label",
                           add_intersects_roads: bool = True,  road_lengths: pstype = None, intersects: pstype = None,) -> pd.Series:
    """Figures the % of total of each landuse feature for one location.
    
    Args:
        buffer_data: The land use values at a given radius
        location: The survey location of interest
    
    Returns:
        A pandas series of the % of total for each landuse feature in the index
    """
    
    try:
        # try to reitrieve the land use data for a location
        location_data = buffer_data[buffer_data.location == location][label].value_counts()
    except ValueError:
        print("The location data could not retrieved")
        raise
    
    # the sum of all land use features in the radius
    total = location_data.sum()
    # the amount of the area attributed to water (lakes and rivers)
    water = location_data.loc["water"]   
    # divide the land_use values by the total minus the amount attributed to water
    results = location_data/(total-water)
    # name the series
    results.name = location
    # the intersects and road-lengths are calculated seprately
    # if add_intersects and roads is true, attach them to the
    # the land use values
    if add_intersects_roads:
        results = addIntersectsToBuffer(buffer_data=results, location=location, intersects=intersects)
        results = addRoadLengthToBuffer(buffer_data=results, location=location, road_lengths=road_lengths)
        
    
    return results

class BufferData:
    a_col="AS18_27"
    new_col = "label"
    exclude_these = []
    label_keys = new_label_keys
    beach_data = dfBeaches
    
    
    
    def __init__(self, file_name: str = None, locations: list = []):
        self.buffer = pd.read_csv(file_name)
        self.buffer_data = combineLandUseFeatures(buffer_data=self.buffer, a_col=self.a_col, new_col=self.new_col)
        self.adjusted_buffer = adjustLandUse(buffer_data=self.buffer_data, exclude_these=self.exclude_these, locations=locations)
        self.pctLandUse = None
        self.locations = locations
        
    def percentLandUse(self):
        
        if isinstance(self.pctLandUse, pdtype):
            return self.pctLandUse
        
        if isinstance(self.adjusted_buffer, pdtype):
            results = []
            road_lengths = self.beach_data.streets
            intersects = self.beach_data.intersects
            for location in self.locations:
                result = calculatePercentLandUse(buffer_data=self.adjusted_buffer, location=location, road_lengths=road_lengths, intersects=intersects)
                results.append(result)
        else:
            raise TypeError
            
        self.pctLandUse = pd.concat(results, axis=1)
        
        return self.pctLandUse

def timer(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        start_time = time.perf_counter()
        value = func(*args, **kwargs)
        end_time = time.perf_counter()
        run_time = end_time - start_time
        print("Finished {} in {} secs".format(repr(func.__name__), round(run_time, 3)))
        return value

    return wrapper

def assignLanduseValue(sample: pstype=None, land_use: str=None) -> float:
    # returns the requested value of land use from the sample
    # if the requested landuse value is not present in the buffer
    # zero is returned
    try:
        result = sample.loc[land_use]
    except KeyError:
        result = 0
    
    return result

def cleanSurveyResults(data):
    # performs data cleaning operations on the
    # default data
    
    data['loc_date'] = list(zip(data.location, data["date"]))
    data['date'] = pd.to_datetime(data["date"])
    
    # get rid of microplastics
    mcr = data[data.groupname == "micro plastics (< 5mm)"].code.unique()
    
    # replace the bad code
    data.code = data.code.replace('G207', 'G208')
    data = data[~data.code.isin(mcr)]
    
    # walensee has no landuse values
    data = data[data.water_name_slug != 'walensee']   
    
    return data

class SurveyResults:
    """Creates a dataframe from a valid filename. Assigns the column names and defines a list of
    codes and locations that can be used in the CodeData class.
    """
    
    file_name = 'resources/checked_sdata_eos_2020_21.csv'
    columns_to_keep=[
        'loc_date',
        'location', 
        'river_bassin',
        'water_name_slug',
        'city',
        'w_t', 
        'intersects', 
        'code', 
        'pcs_m',
        'quantity'
    ]
        
    def __init__(self, data: str = file_name, clean_data: bool = True, columns: list = columns_to_keep, w_t: str = None):
        self.dfx = pd.read_csv(data)
        self.df_results = None
        self.locations = None
        self.valid_codes = None
        self.clean_data = clean_data
        self.columns = columns
        self.w_t = w_t
        
    def validCodes(self):
        # creates a list of unique code values for the data set    
        conditions = [
            isinstance(self.df_results, pdtype),
            "code" in self.df_results.columns
        ]

        if all(conditions):

            try:
                valid_codes = self.df_results.code.unique()
            except ValueError:
                print("There was an error retrieving the unique code names, self.df.code.unique() failed.")
                raise
            else:
                self.valid_codes = valid_codes
                
        
    def surveyResults(self):
        
        # if this method has been called already
        # return the result
        if self.df_results is not None:
            return self.df_results
        
        # for the default data self.clean data must be called        
        if self.clean_data is True:
            fd = cleanSurveyResults(self.dfx)
            
        # if the data is clean then if can be used directly
        else:
            fd = self.dfx
        
        # filter the data by the variable w_t
        if self.w_t is not None:
            fd = fd[fd.w_t == self.w_t]            
         
        # keep only the required columns
        if self.columns:
            fd = fd[self.columns]
        
        # assign the survey results to the class attribute
        self.df_results = fd
        
        # define the list of codes in this df
        self.validCodes()
        
        return self.df_results
    
    def surveyLocations(self):
        if self.locations is not None:
            return self.locations
        if self.df_results is not None:
            self.locations = self.dfResults.location.unique()
            return self.locations
        else:
            print("There is no survey data loaded")
            return None    


class CodeData:
    
    def __init__(self, data: pdtype = None, code: str = None, **kwargs):
                
        self.data = data
        self.code = code
        self.code_data = None       
    
    def makeCodeData(self)->pdtype:
        
        if isinstance(self.code_data, pdtype):
            return self.code_data        
        
        conditions = [
            isinstance(self.data, pdtype)            
        ]
        
        if all(conditions):
            self.code_data = self.data[self.data.code == self.code]
            return self.code_data    
    
class CodeResults:   
        
    def __init__(self, code_data: pdtype = None, buffer: pdtype = None, code: str = None, 
                 method: callable = stats.spearmanr, **kwargs):        
        
        self.code_data = code_data
        self.buffer = buffer
        self.code = code
        self.method = method
        self.y = None
        self.x = None
        super().__init__()
    
        
    def landuseValueForOneCondition(self, land_use: str = None, locations: list = None)-> (np.array, np.array):
        
        x = self.code_data.pcs_m.values      
        y = [self.buffer[x].loc[land_use] for x in self.code_data.location.values]
        self.x, self.y = x, np.array(y)
                
        return self.x, self.y
    
    def rhoForALAndUseCategory(self, x: np.ndarray = None, y: np.ndarray = None) -> (float, float):
        # returns the asymptotic results if ranking based method is used        
        c, p = self.method(x, y)
        return c, p
    
    def getRho(self, x: np.array = None)-> float:
        # assigns y from self        
        result = self.method(x, self.y)
                       
        return result.correlation            
        
    def exactPValueForRho(self)-> float:
        # perform a permutation test instead of relying on 
        # the asymptotic p-value. Only one of the two inputs 
        # needs to be shuffled.
        p = stats.permutation_test((self.x,) , self.getRho, permutation_type='pairings', n_resamples=1000)
        
        return p


def makeBufferObject(file_name: str = "resources/buffer_output/luse_1500.csv", buffer_locations: list = None) -> (pdtype, pdtype):
    # Makes a buffer object by calling the BufferData class
    # calls the percentLandUse method and fills Nan values
    # returns the buffer_data object and pct land use values
    
    buffer_data = BufferData(file_name=file_name, locations=buffer_locations)
    pct_vals = buffer_data.percentLandUse()
    pct_vals.fillna(0, inplace=True)
    
    return buffer_data, pct_vals

def asymptoticAndExactPvalues(data: pdtype = None, buffer: pdtype = None, code: 'str'=None, land_use: 'str'=None)-> dict:
    
    code_data = CodeData(data=data, code=code).makeCodeData()
    code_results = CodeResults(code_data=code_data, buffer=buffer)
    
    x, y = code_results.landuseValueForOneCondition(land_use=land_use)
    ci, pi = code_results.rhoForALAndUseCategory(x, y)
    px = code_results.exactPValueForRho()
    
    return {"code": code, "landuse": land_use, "a_symp": (round(pi, 3), ci), "exact": (round(px.pvalue, 3), px.statistic,)}

@timer
def rhoForOneBuffer(data: pdtype = None, buffer_file: str = "resources/buffer_output/luse_1500.csv", 
                    codes: list=None, land_use: list=None)->(list, pdtype, pdtype):
    
    buffer_locations = data.location.unique()
    new_buffer, buffer_vals = makeBufferObject(file_name=buffer_file, buffer_locations=buffer_locations)    
        
    rhovals_for_this_buffer = []
    for code in codes:
        for use in land_use:
            results = asymptoticAndExactPvalues(data=data, buffer=buffer_vals, code=code, land_use=use)
            rhovals_for_this_buffer.append(results)
    
    return rhovals_for_this_buffer, new_buffer, buffer_vals

def resultsDf(rhovals: pdtype = None, pvals: pdtype = None)-> pdtype:
    results_df = []
    for i, n in enumerate(pvals.index):
        arow_of_ps = pvals.iloc[i]
        p_fail = arow_of_ps[ arow_of_ps > 0.05]
        arow_of_rhos = rhovals.iloc[i]
        
        for label in p_fail.index:
            arow_of_rhos[label] = 0
        results_df.append(arow_of_rhos)
    
    return results_df

def rotateText(x):
    return 'writing-mode: vertical-lr; transform: rotate(-180deg);  padding:10px; margins:0; vertical-align: baseline;'

def nObjectsPerLandUse(uses,surveys):
    results = {}
    for a_use in uses.index:
        total = surveys[surveys.code.isin(uses.loc[a_use])].quantity.sum()
        results.update({a_use:total})
    
    return pd.DataFrame(index=results.keys(), data=results.values(), columns=["total"])

fdx = SurveyResults()
df = fdx.surveyResults()

location_no_luse = ["linth_route9brucke",
                "seez_spennwiesenbrucke",
                'limmat_dietikon_keiserp',
                "seez"]

city_no_luse = ["Walenstadt", "Weesen", "Glarus Nord", "Quarten"]

df = df[~df.location.isin(location_no_luse)]
df = df[~df.city.isin(city_no_luse)]

df[["location","city", "water_name_slug","loc_date", "code", "pcs_m", "quantity"]].head().style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_69a0a tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_69a0a tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_69a0a tr {
#   font-size: 12px;
# }
# #T_69a0a th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_69a0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69a0a_level0_col0" class="col_heading level0 col0" >location</th>
#       <th id="T_69a0a_level0_col1" class="col_heading level0 col1" >city</th>
#       <th id="T_69a0a_level0_col2" class="col_heading level0 col2" >water_name_slug</th>
#       <th id="T_69a0a_level0_col3" class="col_heading level0 col3" >loc_date</th>
#       <th id="T_69a0a_level0_col4" class="col_heading level0 col4" >code</th>
#       <th id="T_69a0a_level0_col5" class="col_heading level0 col5" >pcs_m</th>
#       <th id="T_69a0a_level0_col6" class="col_heading level0 col6" >quantity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69a0a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69a0a_row0_col0" class="data row0 col0" >maladaire</td>
#       <td id="T_69a0a_row0_col1" class="data row0 col1" >La Tour-de-Peilz</td>
#       <td id="T_69a0a_row0_col2" class="data row0 col2" >lac-leman</td>
#       <td id="T_69a0a_row0_col3" class="data row0 col3" >('maladaire', '2021-05-01')</td>
#       <td id="T_69a0a_row0_col4" class="data row0 col4" >G191</td>
#       <td id="T_69a0a_row0_col5" class="data row0 col5" >0.010000</td>
#       <td id="T_69a0a_row0_col6" class="data row0 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_69a0a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69a0a_row1_col0" class="data row1 col0" >maladaire</td>
#       <td id="T_69a0a_row1_col1" class="data row1 col1" >La Tour-de-Peilz</td>
#       <td id="T_69a0a_row1_col2" class="data row1 col2" >lac-leman</td>
#       <td id="T_69a0a_row1_col3" class="data row1 col3" >('maladaire', '2021-05-01')</td>
#       <td id="T_69a0a_row1_col4" class="data row1 col4" >G35</td>
#       <td id="T_69a0a_row1_col5" class="data row1 col5" >0.010000</td>
#       <td id="T_69a0a_row1_col6" class="data row1 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_69a0a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69a0a_row2_col0" class="data row2 col0" >maladaire</td>
#       <td id="T_69a0a_row2_col1" class="data row2 col1" >La Tour-de-Peilz</td>
#       <td id="T_69a0a_row2_col2" class="data row2 col2" >lac-leman</td>
#       <td id="T_69a0a_row2_col3" class="data row2 col3" >('maladaire', '2021-05-01')</td>
#       <td id="T_69a0a_row2_col4" class="data row2 col4" >G21</td>
#       <td id="T_69a0a_row2_col5" class="data row2 col5" >0.010000</td>
#       <td id="T_69a0a_row2_col6" class="data row2 col6" >1</td>
#     </tr>
#     <tr>
#       <th id="T_69a0a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69a0a_row3_col0" class="data row3 col0" >maladaire</td>
#       <td id="T_69a0a_row3_col1" class="data row3 col1" >La Tour-de-Peilz</td>
#       <td id="T_69a0a_row3_col2" class="data row3 col2" >lac-leman</td>
#       <td id="T_69a0a_row3_col3" class="data row3 col3" >('maladaire', '2021-05-01')</td>
#       <td id="T_69a0a_row3_col4" class="data row3 col4" >G67</td>
#       <td id="T_69a0a_row3_col5" class="data row3 col5" >0.030000</td>
#       <td id="T_69a0a_row3_col6" class="data row3 col6" >2</td>
#     </tr>
#     <tr>
#       <th id="T_69a0a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_69a0a_row4_col0" class="data row4 col0" >maladaire</td>
#       <td id="T_69a0a_row4_col1" class="data row4 col1" >La Tour-de-Peilz</td>
#       <td id="T_69a0a_row4_col2" class="data row4 col2" >lac-leman</td>
#       <td id="T_69a0a_row4_col3" class="data row4 col3" >('maladaire', '2021-05-01')</td>
#       <td id="T_69a0a_row4_col4" class="data row4 col4" >G23</td>
#       <td id="T_69a0a_row4_col5" class="data row4 col5" >0.010000</td>
#       <td id="T_69a0a_row4_col6" class="data row4 col6" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# In the report the objects of interest were either in the top ten by quantity and/or found in at least 50% of the samples. Consider the research question when filtering the objects. A filter can be based on use as well as abundance or frequency.
#
# __percent attributed to buildings__
#
# Originally the % of land attributed to buildings was calculated by summing the area of each topographical representation of a building from the map layer. In this example the % attributed to buildings is calculated the same as forests, agriculture, unproductive, recreation and industrial. The number of 100 m squares attributed to citys was divided by the total number of 100 m squares in the buffer (minus the number of squares attributed to water).
#
# __rivers and lakes__
#
# In the precding two examples the data for the codes of interest came from locations that were on the same hydrologic feature. In this example all the data is considered together. Rivers are included and their is no distinction between features.
#
# ## The survey data
#
# The sampling period for the IQAASL project started in April 2020 and ended May 2021.

# %% [markdown]
# ```{figure} resources/images/all_survey_areas_summary.jpeg
# ---
# name: all_survey_locations
# ---
# ` `
# ```
# {numref}`figure %s: <all_survey_locations>` All survey locations IQAASL.

# %% [markdown]
# Summary data of the surveys, not including locations in the Walensee area:

# %%
## The survey results
locations = df.location.unique()
samples = df.loc_date.unique()
lakes = df[df.w_t == "l"].drop_duplicates("loc_date").w_t.value_counts().values[0]
river = df[df.w_t == "r"].drop_duplicates("loc_date").w_t.value_counts().values[0]
codes_identified = df[df.quantity > 0].code.unique()
codes_possible = df.code.unique()
total_id = df.quantity.sum()

data_summary = {
    "n locations": len(locations),
    "n samples": len(samples),
    "n lake samples": lakes,
    "n river samples": river,
    "n identified object types": len(codes_identified),
    "n possible object types": len(codes_possible),
    "total number of objects": total_id
}

pd.DataFrame(index = data_summary.keys(), data=data_summary.values()).style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_69320 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_69320 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_69320 tr {
#   font-size: 12px;
# }
# #T_69320 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_69320">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69320_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69320_level0_row0" class="row_heading level0 row0" >n locations</th>
#       <td id="T_69320_row0_col0" class="data row0 col0" >128</td>
#     </tr>
#     <tr>
#       <th id="T_69320_level0_row1" class="row_heading level0 row1" >n samples</th>
#       <td id="T_69320_row1_col0" class="data row1 col0" >349</td>
#     </tr>
#     <tr>
#       <th id="T_69320_level0_row2" class="row_heading level0 row2" >n lake samples</th>
#       <td id="T_69320_row2_col0" class="data row2 col0" >300</td>
#     </tr>
#     <tr>
#       <th id="T_69320_level0_row3" class="row_heading level0 row3" >n river samples</th>
#       <td id="T_69320_row3_col0" class="data row3 col0" >49</td>
#     </tr>
#     <tr>
#       <th id="T_69320_level0_row4" class="row_heading level0 row4" >n identified object types</th>
#       <td id="T_69320_row4_col0" class="data row4 col0" >191</td>
#     </tr>
#     <tr>
#       <th id="T_69320_level0_row5" class="row_heading level0 row5" >n possible object types</th>
#       <td id="T_69320_row5_col0" class="data row5 col0" >211</td>
#     </tr>
#     <tr>
#       <th id="T_69320_level0_row6" class="row_heading level0 row6" >total number of objects</th>
#       <td id="T_69320_row6_col0" class="data row6 col0" >46832</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Land use correlation
#
# For this example progressively more amounts of land were considered for each survey location. In the previous two examples we limited ourselves to a radius of 1500 m for all the survey locations from one lake. In this example all the survey results are considered, but the amount of land is increased by 500 m from the initial 1500 m up to 5 000 m. At 5 000 meters we skip a step and do one last test at 10k.
#
# The results at each radius are compared by number of correlations.
#
# __Recall__ Spearmans ranked correlation tests for a statistically significant monotonic relationship or association between two variables. The hypothesis is that there is no association between the land use profile and the survey results.
#
# The test results relate the direction of an association and whether or not that association we can reject the null hypothesis (p-value). For a test to be considered significant the p-value needs to be less than 0.05.
#
# * The null hypothesis: there is no monotonic relationship between the two variables
#
# * The alternate hypothesis: there is a monotonic relationship and the sign (+/-) indicates the direction
#
# It does not provide any information about the magnitude of the relationship. As an example consider the relationship of the survey results of cigarette ends with respect to the amount of land attributed to buildings or agriculture.
#
# ### Land use correlation example. Object = cigarette ends, landuse = buildings v/s agg
#
# When the survey results for cigarette ends are considered with respect to the percent of land attributed to buildings or agriculture the it appears that cigartette ends accumulate at different rates depending on the landuse. The plot below. demonstrates the relationship of the survey values under the two conditions.

# %% [markdown]
# ```{figure} resources/images/land_use_correlation_20_0.png
# ---
# name: 'rho_cigs_urban_rural'
# ---
# ` `
# ```
# {numref}`figure %s: <rho_cigs_urban_rural>` Left: survey totals cigarette ends with respect to % of land to buildings. = 0.39, p-value < .001. Right: survey totals cigarette ends with respect to % of land to aggriculture. = -0.31, p-value < .001.

# %% [markdown]
# This relationship is considered for all the objects of interest. As the value of rho increases the points tend to accumulate to the right of the chart, it is the opposite as rho approaches -1.
#
# ### Land use correlation @ 1500 m

# %%
no_luse_data = ["linth_route9brucke",
                "seez_spennwiesenbrucke",
                'limmat_dietikon_keiserp',
                "seez"]

df = df[~df.location.isin(no_luse_data)]

# the land use features we are interested in
land_use =["buildings",  "industrial", "roads", "recreation", "agriculture","woods", "intersects", "unproductive"]

# codes of interest
# we are interested in objects that were found in 1/2 surveys
fail = .5

# calculate the frequency that each code was found
codes_fail = df[df.quantity > 20].code.unique()

# identify the land_use data
buffer_file = "resources/buffer_output/luse_1500.csv"

# make the buffer and get the coeficients
rho_vals, new_buffer, buffer_vals = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)
# Out:
# Finished 'rhoForOneBuffer' in 111.826 secs

# %%
buffer_results = [{"code":x["code"], "use": x["landuse"], "exact_p": x["exact"][0], "p": x["a_symp"][0], "rho": x["exact"][1]} for x in rho_vals]
rho_at_buffer = pd.DataFrame(buffer_results)
    
pvals = rho_at_buffer.pivot_table(index="code", columns="use", values="exact_p", aggfunc='first')
rhovals = rho_at_buffer.pivot_table(index="code", columns="use", values="rho", aggfunc='first').round(3)

buffer_results = pd.DataFrame(resultsDf(rhovals, pvals))
buffer_results.columns.name = None
bfr = buffer_results.style.format(precision=2).set_table_styles(table_css_styles)
bfr = bfr.background_gradient(axis=None, vmin=buffer_results.min().min(), vmax=buffer_results.max().max(), cmap="coolwarm")
bfr = bfr.applymap_index(rotateText, axis=1)

glue("rho_at_1500", bfr, display=False)
# Out:
# <style type="text/css">
# #T_9fe81 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_9fe81 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_9fe81 tr {
#   font-size: 12px;
# }
# #T_9fe81 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_9fe81_row0_col0, #T_9fe81_row21_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_9fe81_row0_col1, #T_9fe81_row0_col2, #T_9fe81_row0_col4, #T_9fe81_row0_col5, #T_9fe81_row0_col7, #T_9fe81_row1_col0, #T_9fe81_row1_col1, #T_9fe81_row1_col3, #T_9fe81_row1_col4, #T_9fe81_row1_col5, #T_9fe81_row1_col6, #T_9fe81_row1_col7, #T_9fe81_row2_col1, #T_9fe81_row2_col2, #T_9fe81_row2_col3, #T_9fe81_row2_col4, #T_9fe81_row2_col5, #T_9fe81_row2_col7, #T_9fe81_row3_col0, #T_9fe81_row3_col1, #T_9fe81_row3_col2, #T_9fe81_row3_col3, #T_9fe81_row3_col4, #T_9fe81_row3_col5, #T_9fe81_row3_col6, #T_9fe81_row3_col7, #T_9fe81_row4_col3, #T_9fe81_row5_col2, #T_9fe81_row6_col3, #T_9fe81_row6_col4, #T_9fe81_row6_col5, #T_9fe81_row6_col7, #T_9fe81_row7_col0, #T_9fe81_row7_col1, #T_9fe81_row7_col2, #T_9fe81_row7_col3, #T_9fe81_row7_col4, #T_9fe81_row7_col5, #T_9fe81_row7_col7, #T_9fe81_row8_col2, #T_9fe81_row8_col3, #T_9fe81_row8_col4, #T_9fe81_row8_col5, #T_9fe81_row9_col1, #T_9fe81_row9_col2, #T_9fe81_row9_col5, #T_9fe81_row9_col6, #T_9fe81_row9_col7, #T_9fe81_row10_col0, #T_9fe81_row10_col1, #T_9fe81_row10_col2, #T_9fe81_row10_col3, #T_9fe81_row10_col4, #T_9fe81_row10_col5, #T_9fe81_row10_col6, #T_9fe81_row10_col7, #T_9fe81_row11_col0, #T_9fe81_row11_col1, #T_9fe81_row11_col2, #T_9fe81_row11_col5, #T_9fe81_row11_col6, #T_9fe81_row11_col7, #T_9fe81_row12_col2, #T_9fe81_row12_col3, #T_9fe81_row12_col5, #T_9fe81_row13_col2, #T_9fe81_row13_col3, #T_9fe81_row13_col5, #T_9fe81_row13_col6, #T_9fe81_row14_col3, #T_9fe81_row15_col1, #T_9fe81_row15_col3, #T_9fe81_row15_col4, #T_9fe81_row15_col5, #T_9fe81_row15_col6, #T_9fe81_row16_col3, #T_9fe81_row16_col5, #T_9fe81_row17_col0, #T_9fe81_row17_col1, #T_9fe81_row17_col2, #T_9fe81_row17_col3, #T_9fe81_row17_col4, #T_9fe81_row17_col5, #T_9fe81_row17_col6, #T_9fe81_row17_col7, #T_9fe81_row18_col0, #T_9fe81_row18_col2, #T_9fe81_row18_col4, #T_9fe81_row18_col6, #T_9fe81_row18_col7, #T_9fe81_row19_col1, #T_9fe81_row19_col2, #T_9fe81_row19_col4, #T_9fe81_row19_col5, #T_9fe81_row19_col7, #T_9fe81_row20_col1, #T_9fe81_row20_col2, #T_9fe81_row20_col3, #T_9fe81_row20_col4, #T_9fe81_row20_col5, #T_9fe81_row20_col7, #T_9fe81_row21_col1, #T_9fe81_row21_col2, #T_9fe81_row21_col5, #T_9fe81_row21_col7, #T_9fe81_row22_col1, #T_9fe81_row22_col2, #T_9fe81_row22_col4, #T_9fe81_row22_col5, #T_9fe81_row22_col6, #T_9fe81_row22_col7, #T_9fe81_row23_col4, #T_9fe81_row24_col1, #T_9fe81_row24_col2, #T_9fe81_row24_col3, #T_9fe81_row24_col5, #T_9fe81_row24_col7, #T_9fe81_row25_col0, #T_9fe81_row25_col1, #T_9fe81_row25_col2, #T_9fe81_row25_col3, #T_9fe81_row25_col5, #T_9fe81_row25_col6, #T_9fe81_row25_col7, #T_9fe81_row26_col2, #T_9fe81_row26_col3, #T_9fe81_row26_col7, #T_9fe81_row27_col0, #T_9fe81_row27_col1, #T_9fe81_row27_col2, #T_9fe81_row27_col3, #T_9fe81_row27_col4, #T_9fe81_row27_col5, #T_9fe81_row27_col6, #T_9fe81_row27_col7, #T_9fe81_row28_col0, #T_9fe81_row28_col1, #T_9fe81_row28_col2, #T_9fe81_row28_col3, #T_9fe81_row28_col4, #T_9fe81_row28_col5, #T_9fe81_row28_col6, #T_9fe81_row29_col0, #T_9fe81_row29_col1, #T_9fe81_row29_col2, #T_9fe81_row29_col5, #T_9fe81_row29_col7, #T_9fe81_row30_col0, #T_9fe81_row30_col2, #T_9fe81_row30_col4, #T_9fe81_row30_col5, #T_9fe81_row30_col6, #T_9fe81_row30_col7, #T_9fe81_row31_col1, #T_9fe81_row31_col2, #T_9fe81_row31_col3, #T_9fe81_row31_col5, #T_9fe81_row31_col7, #T_9fe81_row32_col0, #T_9fe81_row32_col1, #T_9fe81_row32_col2, #T_9fe81_row32_col3, #T_9fe81_row32_col4, #T_9fe81_row32_col5, #T_9fe81_row32_col6, #T_9fe81_row32_col7, #T_9fe81_row33_col1, #T_9fe81_row33_col7, #T_9fe81_row34_col0, #T_9fe81_row34_col1, #T_9fe81_row34_col2, #T_9fe81_row34_col4, #T_9fe81_row34_col6, #T_9fe81_row34_col7, #T_9fe81_row35_col1, #T_9fe81_row35_col2, #T_9fe81_row35_col5, #T_9fe81_row35_col6 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_9fe81_row0_col3, #T_9fe81_row12_col1, #T_9fe81_row21_col3 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_9fe81_row0_col6, #T_9fe81_row35_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_9fe81_row1_col2, #T_9fe81_row12_col0, #T_9fe81_row19_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_9fe81_row2_col0, #T_9fe81_row13_col7, #T_9fe81_row19_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_9fe81_row2_col6, #T_9fe81_row12_col7, #T_9fe81_row13_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_9fe81_row4_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_9fe81_row4_col1, #T_9fe81_row5_col5, #T_9fe81_row16_col4 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_9fe81_row4_col2, #T_9fe81_row16_col2, #T_9fe81_row23_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_9fe81_row4_col4 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_9fe81_row4_col5 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_9fe81_row4_col6, #T_9fe81_row6_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_9fe81_row4_col7 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_9fe81_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9fe81_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9fe81_row5_col3 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_9fe81_row5_col4, #T_9fe81_row18_col3 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_9fe81_row5_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_9fe81_row5_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_9fe81_row6_col1, #T_9fe81_row35_col3 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_9fe81_row6_col2, #T_9fe81_row26_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_9fe81_row6_col6, #T_9fe81_row22_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_9fe81_row7_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_9fe81_row8_col0, #T_9fe81_row18_col1, #T_9fe81_row20_col0, #T_9fe81_row20_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_9fe81_row8_col1, #T_9fe81_row14_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_9fe81_row8_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_9fe81_row8_col7 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_9fe81_row9_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_9fe81_row9_col3, #T_9fe81_row29_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_9fe81_row9_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_9fe81_row11_col3, #T_9fe81_row11_col4, #T_9fe81_row13_col4 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_9fe81_row12_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_9fe81_row12_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_9fe81_row13_col1, #T_9fe81_row15_col7, #T_9fe81_row26_col4 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_9fe81_row14_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_9fe81_row14_col1 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_9fe81_row14_col4 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_9fe81_row14_col5, #T_9fe81_row21_col4 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_9fe81_row14_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_9fe81_row14_col7 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_9fe81_row15_col0, #T_9fe81_row24_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_9fe81_row15_col2, #T_9fe81_row19_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_9fe81_row16_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_9fe81_row16_col1 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_9fe81_row16_col6, #T_9fe81_row21_col6, #T_9fe81_row23_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_9fe81_row16_col7 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_9fe81_row18_col5 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_9fe81_row22_col3,

# %% [markdown]
# ```{glue:figure} rho_at_1500
# ---
# name: 'rho_at_1500'
# ---
# ` `
# ```
# {numref}`Figure %s: <rho_at_1500>` The corelation coeficient of trash density to landuse features for All data. Coeffecients of 0 indicate that there is no statistical indication that the land use feature has an effect (positive or negative) on the trash density.

# %%
def collectBufferResultsRhoAndPvals(rho_vals):
    buffer_results = [{"code":x["code"], "use": x["landuse"], "exact_p": x["exact"][0], "p": x["a_symp"][0], "rho": x["exact"][1]} for x in rho_vals]
    rho_at_buffer = pd.DataFrame(buffer_results)
    
    pvals = rho_at_buffer.pivot_table(index="code", columns="use", values="exact_p", aggfunc='first')
    rhovals = rho_at_buffer.pivot_table(index="code", columns="use", values="rho", aggfunc='first').round(3)    
    buffer_results = pd.DataFrame(resultsDf(rhovals, pvals))
    
    return rho_at_buffer, pvals, rhovals, buffer_results

def styleBufferResults(buffer_results):
    buffer_results.columns.name = None
    bfr = buffer_results.style.format(precision=2).set_table_styles(table_css_styles)
    bfr = bfr.background_gradient(axis=None, vmin=buffer_results.min().min(), vmax=buffer_results.max().max(), cmap="coolwarm")
    bfr = bfr.applymap_index(rotateText, axis=1)
    
    return bfr

# %% [markdown]
# ### Land use correlation @ 2 000 m

# %%
# identify the land_use data
buffer_file = "resources/buffer_output/luse_2000.csv"

# make the buffer and get the coeficients
rho_vals_2k, new_buffer_2k, buffer_vals_2k = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)

rho_at_2k, pvals2k, rhovals2k, buffer_results2k = collectBufferResultsRhoAndPvals(rho_vals_2k)
styleBufferResults(buffer_results2k)
# Out:
# Finished 'rhoForOneBuffer' in 115.829 secs
# <style type="text/css">
# #T_45113 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_45113 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_45113 tr {
#   font-size: 12px;
# }
# #T_45113 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_45113_row0_col0, #T_45113_row22_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_45113_row0_col1, #T_45113_row0_col2, #T_45113_row0_col4, #T_45113_row0_col5, #T_45113_row0_col7, #T_45113_row1_col0, #T_45113_row1_col1, #T_45113_row1_col2, #T_45113_row1_col3, #T_45113_row1_col4, #T_45113_row1_col5, #T_45113_row1_col6, #T_45113_row1_col7, #T_45113_row2_col1, #T_45113_row2_col2, #T_45113_row2_col3, #T_45113_row2_col4, #T_45113_row2_col5, #T_45113_row2_col6, #T_45113_row2_col7, #T_45113_row3_col0, #T_45113_row3_col1, #T_45113_row3_col2, #T_45113_row3_col3, #T_45113_row3_col4, #T_45113_row3_col5, #T_45113_row3_col6, #T_45113_row3_col7, #T_45113_row4_col3, #T_45113_row5_col2, #T_45113_row6_col2, #T_45113_row6_col3, #T_45113_row6_col4, #T_45113_row6_col5, #T_45113_row6_col7, #T_45113_row7_col0, #T_45113_row7_col1, #T_45113_row7_col2, #T_45113_row7_col3, #T_45113_row7_col5, #T_45113_row8_col2, #T_45113_row8_col3, #T_45113_row8_col4, #T_45113_row8_col5, #T_45113_row9_col1, #T_45113_row9_col2, #T_45113_row9_col3, #T_45113_row9_col4, #T_45113_row9_col5, #T_45113_row9_col6, #T_45113_row9_col7, #T_45113_row10_col0, #T_45113_row10_col1, #T_45113_row10_col2, #T_45113_row10_col3, #T_45113_row10_col4, #T_45113_row10_col5, #T_45113_row10_col6, #T_45113_row10_col7, #T_45113_row11_col0, #T_45113_row11_col1, #T_45113_row11_col2, #T_45113_row11_col4, #T_45113_row11_col5, #T_45113_row11_col6, #T_45113_row11_col7, #T_45113_row12_col2, #T_45113_row12_col3, #T_45113_row12_col5, #T_45113_row13_col1, #T_45113_row13_col2, #T_45113_row13_col3, #T_45113_row13_col5, #T_45113_row13_col6, #T_45113_row13_col7, #T_45113_row14_col3, #T_45113_row15_col1, #T_45113_row15_col2, #T_45113_row15_col3, #T_45113_row15_col4, #T_45113_row15_col5, #T_45113_row15_col6, #T_45113_row16_col3, #T_45113_row16_col5, #T_45113_row17_col0, #T_45113_row17_col1, #T_45113_row17_col2, #T_45113_row17_col3, #T_45113_row17_col4, #T_45113_row17_col5, #T_45113_row17_col6, #T_45113_row17_col7, #T_45113_row18_col0, #T_45113_row18_col2, #T_45113_row18_col4, #T_45113_row18_col6, #T_45113_row19_col0, #T_45113_row19_col1, #T_45113_row19_col2, #T_45113_row19_col4, #T_45113_row19_col5, #T_45113_row19_col7, #T_45113_row20_col0, #T_45113_row20_col1, #T_45113_row20_col2, #T_45113_row20_col3, #T_45113_row20_col4, #T_45113_row20_col5, #T_45113_row20_col7, #T_45113_row21_col1, #T_45113_row21_col2, #T_45113_row21_col5, #T_45113_row21_col7, #T_45113_row22_col1, #T_45113_row22_col2, #T_45113_row22_col4, #T_45113_row22_col5, #T_45113_row22_col6, #T_45113_row22_col7, #T_45113_row23_col4, #T_45113_row24_col0, #T_45113_row24_col1, #T_45113_row24_col2, #T_45113_row24_col3, #T_45113_row24_col4, #T_45113_row24_col5, #T_45113_row24_col7, #T_45113_row25_col1, #T_45113_row25_col2, #T_45113_row25_col3, #T_45113_row25_col5, #T_45113_row25_col6, #T_45113_row25_col7, #T_45113_row26_col2, #T_45113_row26_col3, #T_45113_row26_col7, #T_45113_row27_col0, #T_45113_row27_col1, #T_45113_row27_col2, #T_45113_row27_col3, #T_45113_row27_col4, #T_45113_row27_col5, #T_45113_row27_col6, #T_45113_row27_col7, #T_45113_row28_col0, #T_45113_row28_col1, #T_45113_row28_col2, #T_45113_row28_col3, #T_45113_row28_col4, #T_45113_row28_col5, #T_45113_row28_col6, #T_45113_row28_col7, #T_45113_row29_col0, #T_45113_row29_col1, #T_45113_row29_col2, #T_45113_row29_col5, #T_45113_row30_col0, #T_45113_row30_col2, #T_45113_row30_col4, #T_45113_row30_col5, #T_45113_row30_col6, #T_45113_row31_col1, #T_45113_row31_col3, #T_45113_row31_col5, #T_45113_row31_col7, #T_45113_row32_col0, #T_45113_row32_col1, #T_45113_row32_col2, #T_45113_row32_col3, #T_45113_row32_col4, #T_45113_row32_col5, #T_45113_row32_col6, #T_45113_row32_col7, #T_45113_row33_col1, #T_45113_row33_col6, #T_45113_row33_col7, #T_45113_row34_col0, #T_45113_row34_col1, #T_45113_row34_col2, #T_45113_row34_col4, #T_45113_row34_col6, #T_45113_row34_col7, #T_45113_row35_col1, #T_45113_row35_col2, #T_45113_row35_col5, #T_45113_row35_col6, #T_45113_row35_col7 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_45113_row0_col3, #T_45113_row12_col1, #T_45113_row21_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_45113_row0_col6, #T_45113_row7_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_45113_row2_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_45113_row4_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_45113_row4_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_45113_row4_col2, #T_45113_row12_col4, #T_45113_row19_col3 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_45113_row4_col4 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_45113_row4_col5 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_45113_row4_col6, #T_45113_row12_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_45113_row4_col7, #T_45113_row30_col1 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_45113_row5_col0, #T_45113_row5_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_45113_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_45113_row5_col3 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_45113_row5_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_45113_row5_col5 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_45113_row5_col7 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_45113_row6_col0, #T_45113_row33_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_45113_row6_col1 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_45113_row6_col6 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_45113_row7_col6, #T_45113_row20_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_45113_row7_col7, #T_45113_row30_col7 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_45113_row8_col0 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_45113_row8_col1, #T_45113_row16_col2 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_45113_row8_col6 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_45113_row8_col7, #T_45113_row13_col0 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_45113_row9_col0, #T_45113_row19_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_45113_row11_col3, #T_45113_row18_col7, #T_45113_row29_col4 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_45113_row12_col0, #T_45113_row35_col0 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_45113_row12_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_45113_row13_col4, #T_45113_row29_col7, #T_45113_row31_col2 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_45113_row14_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_45113_row14_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_45113_row14_col2, #T_45113_row26_col5 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_45113_row14_col4 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_45113_row14_col5, #T_45113_row23_col3 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_45113_row14_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_45113_row14_col7, #T_45113_row21_col6, #T_45113_row33_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_45113_row15_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_45113_row15_col7, #T_45113_row22_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_45113_row16_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_45113_row16_col1, #T_45113_row29_col6 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_45113_row16_col4 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_45113_row16_col6, #T_45113_row18_col1, #T_45113_row26_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_45113_row16_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_45113_row18_col3 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_4511

# %% [markdown]
# ### Land use correlation @ 2 500 m

# %%
# identify the land_use data
buffer_file = "resources/buffer_output/luse_2500.csv"

# make the buffer and get the coeficients
rho_vals_2_5k, new_buffer_2_5k, buffer_vals_2_5k = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)

rho_at_25k, pvals25k, rhovals25k, buffer_results25k = collectBufferResultsRhoAndPvals(rho_vals_2_5k)
styleBufferResults(buffer_results25k)
# Out:
# Finished 'rhoForOneBuffer' in 114.825 secs
# <style type="text/css">
# #T_ec9bc tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_ec9bc tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_ec9bc tr {
#   font-size: 12px;
# }
# #T_ec9bc th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_ec9bc_row0_col0, #T_ec9bc_row0_col1, #T_ec9bc_row0_col2, #T_ec9bc_row0_col4, #T_ec9bc_row0_col5, #T_ec9bc_row0_col6, #T_ec9bc_row0_col7, #T_ec9bc_row1_col0, #T_ec9bc_row1_col1, #T_ec9bc_row1_col3, #T_ec9bc_row1_col4, #T_ec9bc_row1_col5, #T_ec9bc_row1_col6, #T_ec9bc_row1_col7, #T_ec9bc_row2_col1, #T_ec9bc_row2_col2, #T_ec9bc_row2_col3, #T_ec9bc_row2_col4, #T_ec9bc_row2_col5, #T_ec9bc_row2_col6, #T_ec9bc_row2_col7, #T_ec9bc_row3_col0, #T_ec9bc_row3_col1, #T_ec9bc_row3_col2, #T_ec9bc_row3_col3, #T_ec9bc_row3_col4, #T_ec9bc_row3_col5, #T_ec9bc_row3_col6, #T_ec9bc_row3_col7, #T_ec9bc_row4_col3, #T_ec9bc_row5_col2, #T_ec9bc_row6_col2, #T_ec9bc_row6_col3, #T_ec9bc_row6_col4, #T_ec9bc_row6_col5, #T_ec9bc_row6_col6, #T_ec9bc_row6_col7, #T_ec9bc_row7_col0, #T_ec9bc_row7_col1, #T_ec9bc_row7_col2, #T_ec9bc_row7_col3, #T_ec9bc_row7_col5, #T_ec9bc_row7_col6, #T_ec9bc_row7_col7, #T_ec9bc_row8_col2, #T_ec9bc_row8_col3, #T_ec9bc_row8_col4, #T_ec9bc_row8_col5, #T_ec9bc_row9_col1, #T_ec9bc_row9_col2, #T_ec9bc_row9_col4, #T_ec9bc_row9_col5, #T_ec9bc_row9_col6, #T_ec9bc_row9_col7, #T_ec9bc_row10_col0, #T_ec9bc_row10_col1, #T_ec9bc_row10_col2, #T_ec9bc_row10_col3, #T_ec9bc_row10_col4, #T_ec9bc_row10_col5, #T_ec9bc_row10_col6, #T_ec9bc_row10_col7, #T_ec9bc_row11_col0, #T_ec9bc_row11_col1, #T_ec9bc_row11_col2, #T_ec9bc_row11_col4, #T_ec9bc_row11_col5, #T_ec9bc_row11_col6, #T_ec9bc_row11_col7, #T_ec9bc_row12_col2, #T_ec9bc_row12_col3, #T_ec9bc_row12_col4, #T_ec9bc_row12_col5, #T_ec9bc_row13_col0, #T_ec9bc_row13_col2, #T_ec9bc_row13_col4, #T_ec9bc_row13_col5, #T_ec9bc_row13_col6, #T_ec9bc_row13_col7, #T_ec9bc_row14_col3, #T_ec9bc_row15_col1, #T_ec9bc_row15_col2, #T_ec9bc_row15_col3, #T_ec9bc_row15_col4, #T_ec9bc_row15_col5, #T_ec9bc_row15_col6, #T_ec9bc_row16_col2, #T_ec9bc_row16_col5, #T_ec9bc_row17_col0, #T_ec9bc_row17_col1, #T_ec9bc_row17_col2, #T_ec9bc_row17_col3, #T_ec9bc_row17_col4, #T_ec9bc_row17_col5, #T_ec9bc_row17_col6, #T_ec9bc_row17_col7, #T_ec9bc_row18_col0, #T_ec9bc_row18_col2, #T_ec9bc_row18_col4, #T_ec9bc_row18_col6, #T_ec9bc_row19_col0, #T_ec9bc_row19_col1, #T_ec9bc_row19_col2, #T_ec9bc_row19_col4, #T_ec9bc_row19_col5, #T_ec9bc_row19_col7, #T_ec9bc_row20_col0, #T_ec9bc_row20_col1, #T_ec9bc_row20_col2, #T_ec9bc_row20_col3, #T_ec9bc_row20_col4, #T_ec9bc_row20_col5, #T_ec9bc_row20_col7, #T_ec9bc_row21_col2, #T_ec9bc_row21_col5, #T_ec9bc_row21_col7, #T_ec9bc_row22_col1, #T_ec9bc_row22_col2, #T_ec9bc_row22_col4, #T_ec9bc_row22_col5, #T_ec9bc_row22_col6, #T_ec9bc_row22_col7, #T_ec9bc_row23_col0, #T_ec9bc_row24_col2, #T_ec9bc_row24_col3, #T_ec9bc_row24_col5, #T_ec9bc_row24_col7, #T_ec9bc_row25_col1, #T_ec9bc_row25_col2, #T_ec9bc_row25_col3, #T_ec9bc_row25_col5, #T_ec9bc_row25_col6, #T_ec9bc_row25_col7, #T_ec9bc_row26_col2, #T_ec9bc_row26_col3, #T_ec9bc_row26_col7, #T_ec9bc_row27_col0, #T_ec9bc_row27_col1, #T_ec9bc_row27_col2, #T_ec9bc_row27_col3, #T_ec9bc_row27_col4, #T_ec9bc_row27_col5, #T_ec9bc_row27_col6, #T_ec9bc_row27_col7, #T_ec9bc_row28_col0, #T_ec9bc_row28_col1, #T_ec9bc_row28_col2, #T_ec9bc_row28_col3, #T_ec9bc_row28_col4, #T_ec9bc_row28_col5, #T_ec9bc_row28_col6, #T_ec9bc_row28_col7, #T_ec9bc_row29_col0, #T_ec9bc_row29_col1, #T_ec9bc_row29_col2, #T_ec9bc_row29_col5, #T_ec9bc_row30_col0, #T_ec9bc_row30_col2, #T_ec9bc_row30_col4, #T_ec9bc_row30_col5, #T_ec9bc_row30_col6, #T_ec9bc_row31_col2, #T_ec9bc_row31_col3, #T_ec9bc_row31_col5, #T_ec9bc_row32_col0, #T_ec9bc_row32_col1, #T_ec9bc_row32_col2, #T_ec9bc_row32_col3, #T_ec9bc_row32_col4, #T_ec9bc_row32_col5, #T_ec9bc_row32_col6, #T_ec9bc_row32_col7, #T_ec9bc_row33_col1, #T_ec9bc_row33_col7, #T_ec9bc_row34_col0, #T_ec9bc_row34_col1, #T_ec9bc_row34_col2, #T_ec9bc_row34_col4, #T_ec9bc_row34_col6, #T_ec9bc_row34_col7, #T_ec9bc_row35_col0, #T_ec9bc_row35_col1, #T_ec9bc_row35_col2, #T_ec9bc_row35_col4, #T_ec9bc_row35_col5, #T_ec9bc_row35_col6, #T_ec9bc_row35_col7 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_ec9bc_row0_col3, #T_ec9bc_row6_col1, #T_ec9bc_row21_col3 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_ec9bc_row1_col2, #T_ec9bc_row9_col0, #T_ec9bc_row24_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_ec9bc_row2_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ec9bc_row4_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_ec9bc_row4_col1 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_ec9bc_row4_col2, #T_ec9bc_row19_col3, #T_ec9bc_row26_col4 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_ec9bc_row4_col4 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_ec9bc_row4_col5 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_ec9bc_row4_col6, #T_ec9bc_row12_col6, #T_ec9bc_row16_col0, #T_ec9bc_row24_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_ec9bc_row4_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_ec9bc_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ec9bc_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ec9bc_row5_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_ec9bc_row5_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_ec9bc_row5_col5 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_ec9bc_row5_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_ec9bc_row5_col7, #T_ec9bc_row33_col0 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ec9bc_row6_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_ec9bc_row7_col4, #T_ec9bc_row23_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_ec9bc_row8_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_ec9bc_row8_col1, #T_ec9bc_row13_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_ec9bc_row8_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_ec9bc_row8_col7 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_ec9bc_row9_col3, #T_ec9bc_row29_col3 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_ec9bc_row11_col3, #T_ec9bc_row21_col1, #T_ec9bc_row25_col4, #T_ec9bc_row29_col4, #T_ec9bc_row31_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_ec9bc_row12_col0, #T_ec9bc_row18_col5, #T_ec9bc_row26_col6, #T_ec9bc_row30_col1, #T_ec9bc_row31_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_ec9bc_row12_col1 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_ec9bc_row12_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_ec9bc_row13_col1, #T_ec9bc_row24_col1 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_ec9bc_row14_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_ec9bc_row14_col1 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_ec9bc_row14_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_ec9bc_row14_col4 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_ec9bc_row14_col5 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_ec9bc_row14_col6 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ec9bc_row14_col7 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_ec9bc_row15_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_ec9bc_row15_col7 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_ec9bc_row16_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_ec9bc_row16_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_ec9bc_row16_col4 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_ec9bc_row16_col6, #T_ec9bc_row23_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_ec9bc_row16_col7 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_ec9bc_row18_col1 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_ec9bc_row18_col3 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_ec9bc_row18_col7, #T_ec9bc_row26_col5 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_ec9bc_row19_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_ec9bc_row20_col6

# %% [markdown]
# ### Land use correlation @ 3 000 m

# %%
# identify the land_use data
buffer_file = "resources/buffer_output/luse_3000.csv"

# make the buffer and get the coeficients
rho_vals_3k, new_buffer_3k, buffer_vals_3k = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)

rho_at_3k, pvals3k, rhovals3k, buffer_results3k = collectBufferResultsRhoAndPvals(rho_vals_3k)
styleBufferResults(buffer_results3k)
# Out:
# Finished 'rhoForOneBuffer' in 116.836 secs
# <style type="text/css">
# #T_0042e tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_0042e tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_0042e tr {
#   font-size: 12px;
# }
# #T_0042e th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_0042e_row0_col0, #T_0042e_row0_col1, #T_0042e_row0_col2, #T_0042e_row0_col4, #T_0042e_row0_col5, #T_0042e_row0_col6, #T_0042e_row0_col7, #T_0042e_row1_col0, #T_0042e_row1_col1, #T_0042e_row1_col3, #T_0042e_row1_col4, #T_0042e_row1_col5, #T_0042e_row1_col6, #T_0042e_row1_col7, #T_0042e_row2_col1, #T_0042e_row2_col2, #T_0042e_row2_col3, #T_0042e_row2_col4, #T_0042e_row2_col5, #T_0042e_row2_col6, #T_0042e_row2_col7, #T_0042e_row3_col0, #T_0042e_row3_col1, #T_0042e_row3_col2, #T_0042e_row3_col3, #T_0042e_row3_col4, #T_0042e_row3_col5, #T_0042e_row3_col6, #T_0042e_row3_col7, #T_0042e_row4_col3, #T_0042e_row4_col7, #T_0042e_row5_col2, #T_0042e_row6_col2, #T_0042e_row6_col3, #T_0042e_row6_col4, #T_0042e_row6_col5, #T_0042e_row6_col6, #T_0042e_row6_col7, #T_0042e_row7_col1, #T_0042e_row7_col2, #T_0042e_row7_col3, #T_0042e_row7_col4, #T_0042e_row7_col5, #T_0042e_row7_col6, #T_0042e_row7_col7, #T_0042e_row8_col2, #T_0042e_row8_col3, #T_0042e_row8_col4, #T_0042e_row8_col5, #T_0042e_row9_col0, #T_0042e_row9_col1, #T_0042e_row9_col2, #T_0042e_row9_col4, #T_0042e_row9_col5, #T_0042e_row9_col6, #T_0042e_row9_col7, #T_0042e_row10_col0, #T_0042e_row10_col1, #T_0042e_row10_col2, #T_0042e_row10_col3, #T_0042e_row10_col4, #T_0042e_row10_col5, #T_0042e_row10_col6, #T_0042e_row10_col7, #T_0042e_row11_col0, #T_0042e_row11_col1, #T_0042e_row11_col2, #T_0042e_row11_col4, #T_0042e_row11_col5, #T_0042e_row11_col6, #T_0042e_row11_col7, #T_0042e_row12_col2, #T_0042e_row12_col3, #T_0042e_row12_col4, #T_0042e_row12_col5, #T_0042e_row13_col0, #T_0042e_row13_col2, #T_0042e_row13_col4, #T_0042e_row13_col5, #T_0042e_row13_col6, #T_0042e_row13_col7, #T_0042e_row14_col3, #T_0042e_row15_col1, #T_0042e_row15_col2, #T_0042e_row15_col3, #T_0042e_row15_col4, #T_0042e_row15_col5, #T_0042e_row15_col6, #T_0042e_row15_col7, #T_0042e_row16_col2, #T_0042e_row16_col5, #T_0042e_row17_col0, #T_0042e_row17_col1, #T_0042e_row17_col2, #T_0042e_row17_col3, #T_0042e_row17_col4, #T_0042e_row17_col5, #T_0042e_row17_col6, #T_0042e_row17_col7, #T_0042e_row18_col0, #T_0042e_row18_col2, #T_0042e_row18_col6, #T_0042e_row19_col0, #T_0042e_row19_col1, #T_0042e_row19_col2, #T_0042e_row19_col5, #T_0042e_row19_col6, #T_0042e_row19_col7, #T_0042e_row20_col0, #T_0042e_row20_col1, #T_0042e_row20_col2, #T_0042e_row20_col3, #T_0042e_row20_col4, #T_0042e_row20_col5, #T_0042e_row20_col7, #T_0042e_row21_col2, #T_0042e_row21_col4, #T_0042e_row21_col5, #T_0042e_row21_col7, #T_0042e_row22_col0, #T_0042e_row22_col1, #T_0042e_row22_col2, #T_0042e_row22_col4, #T_0042e_row22_col5, #T_0042e_row22_col6, #T_0042e_row22_col7, #T_0042e_row24_col2, #T_0042e_row24_col3, #T_0042e_row24_col4, #T_0042e_row24_col5, #T_0042e_row24_col7, #T_0042e_row25_col1, #T_0042e_row25_col2, #T_0042e_row25_col3, #T_0042e_row25_col5, #T_0042e_row25_col6, #T_0042e_row25_col7, #T_0042e_row26_col2, #T_0042e_row26_col3, #T_0042e_row26_col6, #T_0042e_row26_col7, #T_0042e_row27_col0, #T_0042e_row27_col1, #T_0042e_row27_col2, #T_0042e_row27_col3, #T_0042e_row27_col5, #T_0042e_row27_col6, #T_0042e_row27_col7, #T_0042e_row28_col0, #T_0042e_row28_col1, #T_0042e_row28_col2, #T_0042e_row28_col3, #T_0042e_row28_col4, #T_0042e_row28_col5, #T_0042e_row28_col6, #T_0042e_row28_col7, #T_0042e_row29_col0, #T_0042e_row29_col2, #T_0042e_row29_col4, #T_0042e_row29_col5, #T_0042e_row30_col0, #T_0042e_row30_col2, #T_0042e_row30_col4, #T_0042e_row30_col5, #T_0042e_row30_col6, #T_0042e_row31_col2, #T_0042e_row31_col3, #T_0042e_row31_col5, #T_0042e_row32_col0, #T_0042e_row32_col1, #T_0042e_row32_col2, #T_0042e_row32_col3, #T_0042e_row32_col4, #T_0042e_row32_col5, #T_0042e_row32_col6, #T_0042e_row32_col7, #T_0042e_row33_col1, #T_0042e_row33_col7, #T_0042e_row34_col0, #T_0042e_row34_col1, #T_0042e_row34_col2, #T_0042e_row34_col4, #T_0042e_row34_col6, #T_0042e_row34_col7, #T_0042e_row35_col0, #T_0042e_row35_col1, #T_0042e_row35_col2, #T_0042e_row35_col4, #T_0042e_row35_col5, #T_0042e_row35_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_0042e_row0_col3, #T_0042e_row21_col1 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_0042e_row1_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_0042e_row2_col0 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_0042e_row4_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_0042e_row4_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_0042e_row4_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_0042e_row4_col4, #T_0042e_row14_col4 {
#   background-color: #d1493f;
#   color: #f1f1f1;
# }
# #T_0042e_row4_col5 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_0042e_row4_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_0042e_row5_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_0042e_row5_col1, #T_0042e_row14_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0042e_row5_col3, #T_0042e_row33_col6 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_0042e_row5_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_0042e_row5_col5 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_0042e_row5_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_0042e_row5_col7 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_0042e_row6_col0, #T_0042e_row31_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_0042e_row6_col1, #T_0042e_row27_col4, #T_0042e_row31_col1 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_0042e_row7_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_0042e_row8_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_0042e_row8_col1, #T_0042e_row11_col3, #T_0042e_row24_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_0042e_row8_col6 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_0042e_row8_col7 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_0042e_row9_col3, #T_0042e_row13_col3, #T_0042e_row14_col2, #T_0042e_row31_col4 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_0042e_row12_col0, #T_0042e_row25_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_0042e_row12_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_0042e_row12_col6 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_0042e_row12_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_0042e_row13_col1, #T_0042e_row29_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_0042e_row14_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_0042e_row14_col5, #T_0042e_row23_col3, #T_0042e_row23_col6, #T_0042e_row23_col7 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_0042e_row14_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0042e_row14_col7, #T_0042e_row15_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_0042e_row16_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_0042e_row16_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_0042e_row16_col3 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_0042e_row16_col4 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_0042e_row16_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_0042e_row16_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_0042e_row18_col1 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_0042e_row18_col3 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_0042e_row18_col4, #T_0042e_row18_col5, #T_0042e_row19_col4, #T_0042e_row20_col6, #T_0042e_row35_col6 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_0042e_row18_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_0042e_row19_col3 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_0042e_row21_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_0042e_row21_col3 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_0042e_row21_col6, #T_0042e_row23_col5 {
#   background-color: #96b7ff

# %% [markdown]
# ### Land use correlation @ 3 500 m

# %%
# identify the land_use data
buffer_file = "resources/buffer_output/luse_3500.csv"

# make the buffer and get the coeficients
rho_vals_3_5k, new_buffer_3_5k, buffer_vals_3_5k = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)

rho_at_35k, pvals35k, rhovals35k, buffer_results35k = collectBufferResultsRhoAndPvals(rho_vals_3_5k)
styleBufferResults(buffer_results35k)
# Out:
# Finished 'rhoForOneBuffer' in 118.425 secs
# <style type="text/css">
# #T_7ba6b tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_7ba6b tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_7ba6b tr {
#   font-size: 12px;
# }
# #T_7ba6b th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_7ba6b_row0_col0, #T_7ba6b_row0_col1, #T_7ba6b_row0_col2, #T_7ba6b_row0_col4, #T_7ba6b_row0_col5, #T_7ba6b_row0_col6, #T_7ba6b_row0_col7, #T_7ba6b_row1_col0, #T_7ba6b_row1_col1, #T_7ba6b_row1_col3, #T_7ba6b_row1_col4, #T_7ba6b_row1_col5, #T_7ba6b_row1_col6, #T_7ba6b_row1_col7, #T_7ba6b_row2_col1, #T_7ba6b_row2_col2, #T_7ba6b_row2_col3, #T_7ba6b_row2_col4, #T_7ba6b_row2_col5, #T_7ba6b_row2_col6, #T_7ba6b_row2_col7, #T_7ba6b_row3_col0, #T_7ba6b_row3_col1, #T_7ba6b_row3_col2, #T_7ba6b_row3_col3, #T_7ba6b_row3_col4, #T_7ba6b_row3_col5, #T_7ba6b_row3_col6, #T_7ba6b_row3_col7, #T_7ba6b_row4_col7, #T_7ba6b_row5_col2, #T_7ba6b_row6_col2, #T_7ba6b_row6_col3, #T_7ba6b_row6_col5, #T_7ba6b_row6_col6, #T_7ba6b_row6_col7, #T_7ba6b_row7_col0, #T_7ba6b_row7_col1, #T_7ba6b_row7_col2, #T_7ba6b_row7_col3, #T_7ba6b_row7_col4, #T_7ba6b_row7_col5, #T_7ba6b_row7_col6, #T_7ba6b_row7_col7, #T_7ba6b_row8_col2, #T_7ba6b_row8_col3, #T_7ba6b_row8_col4, #T_7ba6b_row8_col5, #T_7ba6b_row9_col0, #T_7ba6b_row9_col1, #T_7ba6b_row9_col2, #T_7ba6b_row9_col3, #T_7ba6b_row9_col4, #T_7ba6b_row9_col5, #T_7ba6b_row9_col6, #T_7ba6b_row9_col7, #T_7ba6b_row10_col0, #T_7ba6b_row10_col1, #T_7ba6b_row10_col2, #T_7ba6b_row10_col3, #T_7ba6b_row10_col4, #T_7ba6b_row10_col5, #T_7ba6b_row10_col6, #T_7ba6b_row10_col7, #T_7ba6b_row11_col0, #T_7ba6b_row11_col1, #T_7ba6b_row11_col2, #T_7ba6b_row11_col4, #T_7ba6b_row11_col5, #T_7ba6b_row11_col6, #T_7ba6b_row11_col7, #T_7ba6b_row12_col2, #T_7ba6b_row12_col3, #T_7ba6b_row12_col5, #T_7ba6b_row13_col0, #T_7ba6b_row13_col1, #T_7ba6b_row13_col2, #T_7ba6b_row13_col4, #T_7ba6b_row13_col5, #T_7ba6b_row13_col6, #T_7ba6b_row13_col7, #T_7ba6b_row14_col3, #T_7ba6b_row15_col1, #T_7ba6b_row15_col2, #T_7ba6b_row15_col3, #T_7ba6b_row15_col4, #T_7ba6b_row15_col5, #T_7ba6b_row15_col6, #T_7ba6b_row15_col7, #T_7ba6b_row16_col5, #T_7ba6b_row17_col0, #T_7ba6b_row17_col1, #T_7ba6b_row17_col2, #T_7ba6b_row17_col3, #T_7ba6b_row17_col4, #T_7ba6b_row17_col5, #T_7ba6b_row17_col6, #T_7ba6b_row17_col7, #T_7ba6b_row18_col0, #T_7ba6b_row18_col2, #T_7ba6b_row18_col6, #T_7ba6b_row19_col0, #T_7ba6b_row19_col1, #T_7ba6b_row19_col2, #T_7ba6b_row19_col4, #T_7ba6b_row19_col5, #T_7ba6b_row19_col6, #T_7ba6b_row19_col7, #T_7ba6b_row20_col0, #T_7ba6b_row20_col1, #T_7ba6b_row20_col2, #T_7ba6b_row20_col3, #T_7ba6b_row20_col4, #T_7ba6b_row20_col5, #T_7ba6b_row20_col6, #T_7ba6b_row20_col7, #T_7ba6b_row21_col1, #T_7ba6b_row21_col2, #T_7ba6b_row21_col4, #T_7ba6b_row21_col5, #T_7ba6b_row21_col7, #T_7ba6b_row22_col0, #T_7ba6b_row22_col1, #T_7ba6b_row22_col2, #T_7ba6b_row22_col4, #T_7ba6b_row22_col5, #T_7ba6b_row22_col6, #T_7ba6b_row24_col2, #T_7ba6b_row24_col3, #T_7ba6b_row24_col4, #T_7ba6b_row24_col5, #T_7ba6b_row24_col7, #T_7ba6b_row25_col0, #T_7ba6b_row25_col1, #T_7ba6b_row25_col2, #T_7ba6b_row25_col3, #T_7ba6b_row25_col4, #T_7ba6b_row25_col5, #T_7ba6b_row25_col6, #T_7ba6b_row25_col7, #T_7ba6b_row26_col2, #T_7ba6b_row26_col3, #T_7ba6b_row26_col7, #T_7ba6b_row27_col0, #T_7ba6b_row27_col1, #T_7ba6b_row27_col2, #T_7ba6b_row27_col3, #T_7ba6b_row27_col5, #T_7ba6b_row27_col6, #T_7ba6b_row27_col7, #T_7ba6b_row28_col0, #T_7ba6b_row28_col1, #T_7ba6b_row28_col2, #T_7ba6b_row28_col3, #T_7ba6b_row28_col4, #T_7ba6b_row28_col5, #T_7ba6b_row28_col6, #T_7ba6b_row28_col7, #T_7ba6b_row29_col0, #T_7ba6b_row29_col2, #T_7ba6b_row29_col4, #T_7ba6b_row29_col5, #T_7ba6b_row30_col0, #T_7ba6b_row30_col2, #T_7ba6b_row30_col4, #T_7ba6b_row30_col5, #T_7ba6b_row30_col6, #T_7ba6b_row31_col1, #T_7ba6b_row31_col3, #T_7ba6b_row31_col5, #T_7ba6b_row32_col0, #T_7ba6b_row32_col1, #T_7ba6b_row32_col2, #T_7ba6b_row32_col3, #T_7ba6b_row32_col4, #T_7ba6b_row32_col5, #T_7ba6b_row32_col6, #T_7ba6b_row32_col7, #T_7ba6b_row33_col1, #T_7ba6b_row33_col7, #T_7ba6b_row34_col0, #T_7ba6b_row34_col1, #T_7ba6b_row34_col2, #T_7ba6b_row34_col4, #T_7ba6b_row34_col6, #T_7ba6b_row34_col7, #T_7ba6b_row35_col0, #T_7ba6b_row35_col1, #T_7ba6b_row35_col2, #T_7ba6b_row35_col4, #T_7ba6b_row35_col5, #T_7ba6b_row35_col7 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7ba6b_row0_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_7ba6b_row1_col2, #T_7ba6b_row16_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_7ba6b_row2_col0, #T_7ba6b_row30_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_7ba6b_row4_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_7ba6b_row4_col1, #T_7ba6b_row18_col3 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_7ba6b_row4_col2, #T_7ba6b_row18_col7 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_7ba6b_row4_col3, #T_7ba6b_row8_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_7ba6b_row4_col4 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_7ba6b_row4_col5 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_7ba6b_row4_col6 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_7ba6b_row5_col0, #T_7ba6b_row5_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_7ba6b_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7ba6b_row5_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_7ba6b_row5_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_7ba6b_row5_col5 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_7ba6b_row5_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_7ba6b_row6_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_7ba6b_row6_col1 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_7ba6b_row6_col4, #T_7ba6b_row16_col3, #T_7ba6b_row22_col7 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_7ba6b_row8_col1, #T_7ba6b_row21_col3, #T_7ba6b_row27_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_7ba6b_row8_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_7ba6b_row8_col7 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_7ba6b_row11_col3, #T_7ba6b_row24_col1, #T_7ba6b_row30_col7 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_7ba6b_row12_col0 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_7ba6b_row12_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_7ba6b_row12_col4, #T_7ba6b_row13_col3 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_7ba6b_row12_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_7ba6b_row12_col7, #T_7ba6b_row24_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_7ba6b_row14_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_7ba6b_row14_col1 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_7ba6b_row14_col2, #T_7ba6b_row26_col4, #T_7ba6b_row30_col3 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_7ba6b_row14_col4 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_7ba6b_row14_col5 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_7ba6b_row14_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7ba6b_row14_col7 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_7ba6b_row15_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_7ba6b_row16_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_7ba6b_row16_col1 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_7ba6b_row16_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_7ba6b_row16_col4 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_7ba6b_row16_col6, #T_7ba6b_row18_col1, #T_7ba6b_row33_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_7ba6b_row18_col4, #T_7ba6b_row21_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_7ba6b_row18_col5, #T_7ba6b_row29_col1, #T_7ba6b_row31_col0, #T_7ba6b_row31_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_7ba6b_row19_col3 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_7ba6b_row21_col0 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_7ba6b_row22_col3 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_7ba6b_row23_col0, #T_7ba6

# %% [markdown]
# ### Land use correlation @ 4 000 m

# %%
# identify the land_use data
buffer_file = "resources/buffer_output/luse_4000.csv"

# make the buffer and get the coeficients
rho_vals_4k, new_buffer_4k, buffer_vals_4k = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)

rho_at_4k, pvals4k, rhovals4k, buffer_results4k = collectBufferResultsRhoAndPvals(rho_vals_4k)
styleBufferResults(buffer_results4k)
# Out:
# Finished 'rhoForOneBuffer' in 113.989 secs
# <style type="text/css">
# #T_9594e tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_9594e tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_9594e tr {
#   font-size: 12px;
# }
# #T_9594e th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_9594e_row0_col0, #T_9594e_row0_col1, #T_9594e_row0_col2, #T_9594e_row0_col4, #T_9594e_row0_col5, #T_9594e_row0_col6, #T_9594e_row0_col7, #T_9594e_row1_col0, #T_9594e_row1_col1, #T_9594e_row1_col2, #T_9594e_row1_col3, #T_9594e_row1_col4, #T_9594e_row1_col5, #T_9594e_row1_col6, #T_9594e_row1_col7, #T_9594e_row2_col0, #T_9594e_row2_col1, #T_9594e_row2_col2, #T_9594e_row2_col3, #T_9594e_row2_col4, #T_9594e_row2_col5, #T_9594e_row2_col6, #T_9594e_row2_col7, #T_9594e_row3_col0, #T_9594e_row3_col1, #T_9594e_row3_col2, #T_9594e_row3_col3, #T_9594e_row3_col4, #T_9594e_row3_col5, #T_9594e_row3_col6, #T_9594e_row3_col7, #T_9594e_row4_col3, #T_9594e_row4_col7, #T_9594e_row5_col2, #T_9594e_row6_col2, #T_9594e_row6_col3, #T_9594e_row6_col4, #T_9594e_row6_col5, #T_9594e_row6_col6, #T_9594e_row6_col7, #T_9594e_row7_col0, #T_9594e_row7_col1, #T_9594e_row7_col2, #T_9594e_row7_col3, #T_9594e_row7_col4, #T_9594e_row7_col5, #T_9594e_row7_col6, #T_9594e_row8_col2, #T_9594e_row8_col3, #T_9594e_row8_col4, #T_9594e_row8_col5, #T_9594e_row9_col1, #T_9594e_row9_col2, #T_9594e_row9_col4, #T_9594e_row9_col5, #T_9594e_row9_col6, #T_9594e_row9_col7, #T_9594e_row10_col0, #T_9594e_row10_col1, #T_9594e_row10_col2, #T_9594e_row10_col3, #T_9594e_row10_col4, #T_9594e_row10_col5, #T_9594e_row10_col6, #T_9594e_row10_col7, #T_9594e_row11_col0, #T_9594e_row11_col1, #T_9594e_row11_col2, #T_9594e_row11_col4, #T_9594e_row11_col5, #T_9594e_row11_col6, #T_9594e_row11_col7, #T_9594e_row12_col2, #T_9594e_row12_col3, #T_9594e_row12_col5, #T_9594e_row13_col0, #T_9594e_row13_col1, #T_9594e_row13_col2, #T_9594e_row13_col4, #T_9594e_row13_col5, #T_9594e_row13_col6, #T_9594e_row13_col7, #T_9594e_row14_col3, #T_9594e_row15_col1, #T_9594e_row15_col2, #T_9594e_row15_col3, #T_9594e_row15_col4, #T_9594e_row15_col5, #T_9594e_row15_col6, #T_9594e_row16_col3, #T_9594e_row16_col5, #T_9594e_row17_col0, #T_9594e_row17_col1, #T_9594e_row17_col2, #T_9594e_row17_col3, #T_9594e_row17_col4, #T_9594e_row17_col5, #T_9594e_row17_col6, #T_9594e_row17_col7, #T_9594e_row18_col0, #T_9594e_row18_col2, #T_9594e_row19_col0, #T_9594e_row19_col1, #T_9594e_row19_col2, #T_9594e_row19_col4, #T_9594e_row19_col5, #T_9594e_row19_col6, #T_9594e_row19_col7, #T_9594e_row20_col0, #T_9594e_row20_col1, #T_9594e_row20_col2, #T_9594e_row20_col3, #T_9594e_row20_col4, #T_9594e_row20_col5, #T_9594e_row20_col6, #T_9594e_row20_col7, #T_9594e_row21_col1, #T_9594e_row21_col2, #T_9594e_row21_col5, #T_9594e_row21_col7, #T_9594e_row22_col1, #T_9594e_row22_col2, #T_9594e_row22_col4, #T_9594e_row22_col5, #T_9594e_row22_col6, #T_9594e_row22_col7, #T_9594e_row24_col0, #T_9594e_row24_col1, #T_9594e_row24_col2, #T_9594e_row24_col3, #T_9594e_row24_col4, #T_9594e_row24_col5, #T_9594e_row24_col6, #T_9594e_row24_col7, #T_9594e_row25_col0, #T_9594e_row25_col1, #T_9594e_row25_col2, #T_9594e_row25_col3, #T_9594e_row25_col4, #T_9594e_row25_col5, #T_9594e_row25_col6, #T_9594e_row25_col7, #T_9594e_row26_col2, #T_9594e_row26_col3, #T_9594e_row26_col7, #T_9594e_row27_col1, #T_9594e_row27_col2, #T_9594e_row27_col3, #T_9594e_row27_col5, #T_9594e_row27_col6, #T_9594e_row27_col7, #T_9594e_row28_col0, #T_9594e_row28_col1, #T_9594e_row28_col2, #T_9594e_row28_col3, #T_9594e_row28_col4, #T_9594e_row28_col5, #T_9594e_row28_col6, #T_9594e_row28_col7, #T_9594e_row29_col0, #T_9594e_row29_col2, #T_9594e_row29_col4, #T_9594e_row29_col5, #T_9594e_row30_col0, #T_9594e_row30_col4, #T_9594e_row30_col5, #T_9594e_row30_col6, #T_9594e_row31_col0, #T_9594e_row31_col1, #T_9594e_row31_col2, #T_9594e_row31_col3, #T_9594e_row31_col5, #T_9594e_row32_col0, #T_9594e_row32_col1, #T_9594e_row32_col2, #T_9594e_row32_col3, #T_9594e_row32_col4, #T_9594e_row32_col5, #T_9594e_row32_col7, #T_9594e_row33_col1, #T_9594e_row33_col7, #T_9594e_row34_col0, #T_9594e_row34_col1, #T_9594e_row34_col2, #T_9594e_row34_col4, #T_9594e_row34_col6, #T_9594e_row34_col7, #T_9594e_row35_col0, #T_9594e_row35_col1, #T_9594e_row35_col2, #T_9594e_row35_col4, #T_9594e_row35_col5, #T_9594e_row35_col7 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_9594e_row0_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_9594e_row4_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_9594e_row4_col1 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_9594e_row4_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_9594e_row4_col4 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_9594e_row4_col5 {
#   background-color: #cb3e38;
#   color: #f1f1f1;
# }
# #T_9594e_row4_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_9594e_row5_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_9594e_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9594e_row5_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_9594e_row5_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_9594e_row5_col5 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_9594e_row5_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_9594e_row5_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_9594e_row6_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_9594e_row6_col1, #T_9594e_row11_col3, #T_9594e_row12_col4, #T_9594e_row23_col0 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_9594e_row7_col7, #T_9594e_row9_col3, #T_9594e_row15_col7, #T_9594e_row21_col4, #T_9594e_row27_col4, #T_9594e_row29_col3 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_9594e_row8_col0, #T_9594e_row8_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_9594e_row8_col1, #T_9594e_row30_col7 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_9594e_row8_col7 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_9594e_row9_col0, #T_9594e_row22_col0, #T_9594e_row27_col0 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_9594e_row12_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_9594e_row12_col1, #T_9594e_row26_col5 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_9594e_row12_col6, #T_9594e_row18_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_9594e_row12_col7, #T_9594e_row14_col7, #T_9594e_row21_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_9594e_row13_col3 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_9594e_row14_col0 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_9594e_row14_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_9594e_row14_col2, #T_9594e_row19_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_9594e_row14_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_9594e_row14_col5 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_9594e_row14_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9594e_row15_col0, #T_9594e_row26_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_9594e_row16_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_9594e_row16_col1 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_9594e_row16_col2 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_9594e_row16_col4, #T_9594e_row23_col6, #T_9594e_row33_col2 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_9594e_row16_col6, #T_9594e_row33_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_9594e_row16_col7, #T_9594e_row18_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_9594e_row18_col3 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_9594e_row18_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_9594e_row18_col6 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_9594e_row18_col7 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_9594e_row21_col0 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_9594e_row21_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_9594e_row22_col3, #T_9594e_row26_col4, #T_9594e_row29_col6 {
#   background-c

# %% [markdown]
# ### Land use correlation @ 4 500 m

# %%
# identify the land_use data
buffer_file = "resources/buffer_output/luse_4500.csv"

# make the buffer and get the coeficients
rho_vals_4_5k, new_buffer_4_5k, buffer_vals_4_5k = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)

rho_at_45k, pvals45k, rhovals45k, buffer_results45k = collectBufferResultsRhoAndPvals(rho_vals_4_5k)
styleBufferResults(buffer_results45k)
# Out:
# Finished 'rhoForOneBuffer' in 112.002 secs
# <style type="text/css">
# #T_6cfe7 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_6cfe7 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_6cfe7 tr {
#   font-size: 12px;
# }
# #T_6cfe7 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_6cfe7_row0_col0, #T_6cfe7_row0_col1, #T_6cfe7_row0_col2, #T_6cfe7_row0_col4, #T_6cfe7_row0_col5, #T_6cfe7_row0_col6, #T_6cfe7_row0_col7, #T_6cfe7_row1_col0, #T_6cfe7_row1_col1, #T_6cfe7_row1_col2, #T_6cfe7_row1_col3, #T_6cfe7_row1_col4, #T_6cfe7_row1_col5, #T_6cfe7_row1_col6, #T_6cfe7_row1_col7, #T_6cfe7_row2_col0, #T_6cfe7_row2_col1, #T_6cfe7_row2_col2, #T_6cfe7_row2_col3, #T_6cfe7_row2_col4, #T_6cfe7_row2_col5, #T_6cfe7_row2_col6, #T_6cfe7_row2_col7, #T_6cfe7_row3_col0, #T_6cfe7_row3_col1, #T_6cfe7_row3_col2, #T_6cfe7_row3_col3, #T_6cfe7_row3_col4, #T_6cfe7_row3_col5, #T_6cfe7_row3_col6, #T_6cfe7_row3_col7, #T_6cfe7_row4_col3, #T_6cfe7_row4_col7, #T_6cfe7_row5_col2, #T_6cfe7_row6_col2, #T_6cfe7_row6_col3, #T_6cfe7_row6_col5, #T_6cfe7_row6_col6, #T_6cfe7_row6_col7, #T_6cfe7_row7_col0, #T_6cfe7_row7_col1, #T_6cfe7_row7_col2, #T_6cfe7_row7_col3, #T_6cfe7_row7_col4, #T_6cfe7_row7_col5, #T_6cfe7_row7_col6, #T_6cfe7_row8_col2, #T_6cfe7_row8_col3, #T_6cfe7_row8_col5, #T_6cfe7_row8_col7, #T_6cfe7_row9_col0, #T_6cfe7_row9_col1, #T_6cfe7_row9_col2, #T_6cfe7_row9_col4, #T_6cfe7_row9_col5, #T_6cfe7_row9_col6, #T_6cfe7_row9_col7, #T_6cfe7_row10_col0, #T_6cfe7_row10_col1, #T_6cfe7_row10_col2, #T_6cfe7_row10_col3, #T_6cfe7_row10_col4, #T_6cfe7_row10_col5, #T_6cfe7_row10_col6, #T_6cfe7_row10_col7, #T_6cfe7_row11_col0, #T_6cfe7_row11_col1, #T_6cfe7_row11_col2, #T_6cfe7_row11_col4, #T_6cfe7_row11_col5, #T_6cfe7_row11_col6, #T_6cfe7_row11_col7, #T_6cfe7_row12_col2, #T_6cfe7_row12_col3, #T_6cfe7_row12_col5, #T_6cfe7_row13_col0, #T_6cfe7_row13_col1, #T_6cfe7_row13_col2, #T_6cfe7_row13_col4, #T_6cfe7_row13_col5, #T_6cfe7_row13_col6, #T_6cfe7_row13_col7, #T_6cfe7_row14_col3, #T_6cfe7_row15_col1, #T_6cfe7_row15_col2, #T_6cfe7_row15_col3, #T_6cfe7_row15_col4, #T_6cfe7_row15_col5, #T_6cfe7_row15_col6, #T_6cfe7_row16_col2, #T_6cfe7_row16_col5, #T_6cfe7_row17_col0, #T_6cfe7_row17_col1, #T_6cfe7_row17_col2, #T_6cfe7_row17_col3, #T_6cfe7_row17_col4, #T_6cfe7_row17_col5, #T_6cfe7_row17_col6, #T_6cfe7_row17_col7, #T_6cfe7_row18_col0, #T_6cfe7_row18_col2, #T_6cfe7_row18_col6, #T_6cfe7_row19_col0, #T_6cfe7_row19_col1, #T_6cfe7_row19_col4, #T_6cfe7_row19_col5, #T_6cfe7_row19_col6, #T_6cfe7_row19_col7, #T_6cfe7_row20_col0, #T_6cfe7_row20_col1, #T_6cfe7_row20_col2, #T_6cfe7_row20_col3, #T_6cfe7_row20_col4, #T_6cfe7_row20_col5, #T_6cfe7_row20_col6, #T_6cfe7_row20_col7, #T_6cfe7_row21_col1, #T_6cfe7_row21_col2, #T_6cfe7_row21_col4, #T_6cfe7_row21_col5, #T_6cfe7_row21_col7, #T_6cfe7_row22_col0, #T_6cfe7_row22_col1, #T_6cfe7_row22_col2, #T_6cfe7_row22_col4, #T_6cfe7_row22_col5, #T_6cfe7_row22_col6, #T_6cfe7_row24_col0, #T_6cfe7_row24_col2, #T_6cfe7_row24_col3, #T_6cfe7_row24_col4, #T_6cfe7_row24_col5, #T_6cfe7_row24_col6, #T_6cfe7_row24_col7, #T_6cfe7_row25_col0, #T_6cfe7_row25_col1, #T_6cfe7_row25_col2, #T_6cfe7_row25_col3, #T_6cfe7_row25_col4, #T_6cfe7_row25_col5, #T_6cfe7_row25_col6, #T_6cfe7_row25_col7, #T_6cfe7_row26_col2, #T_6cfe7_row26_col3, #T_6cfe7_row26_col7, #T_6cfe7_row27_col0, #T_6cfe7_row27_col1, #T_6cfe7_row27_col2, #T_6cfe7_row27_col3, #T_6cfe7_row27_col5, #T_6cfe7_row27_col6, #T_6cfe7_row27_col7, #T_6cfe7_row28_col0, #T_6cfe7_row28_col1, #T_6cfe7_row28_col2, #T_6cfe7_row28_col3, #T_6cfe7_row28_col4, #T_6cfe7_row28_col5, #T_6cfe7_row28_col6, #T_6cfe7_row28_col7, #T_6cfe7_row29_col0, #T_6cfe7_row29_col2, #T_6cfe7_row29_col4, #T_6cfe7_row29_col5, #T_6cfe7_row30_col0, #T_6cfe7_row30_col4, #T_6cfe7_row30_col5, #T_6cfe7_row30_col6, #T_6cfe7_row31_col0, #T_6cfe7_row31_col1, #T_6cfe7_row31_col2, #T_6cfe7_row31_col3, #T_6cfe7_row31_col4, #T_6cfe7_row31_col5, #T_6cfe7_row31_col7, #T_6cfe7_row32_col0, #T_6cfe7_row32_col1, #T_6cfe7_row32_col2, #T_6cfe7_row32_col3, #T_6cfe7_row32_col4, #T_6cfe7_row32_col5, #T_6cfe7_row32_col7, #T_6cfe7_row33_col1, #T_6cfe7_row33_col7, #T_6cfe7_row34_col0, #T_6cfe7_row34_col1, #T_6cfe7_row34_col2, #T_6cfe7_row34_col4, #T_6cfe7_row34_col6, #T_6cfe7_row34_col7, #T_6cfe7_row35_col0, #T_6cfe7_row35_col1, #T_6cfe7_row35_col2, #T_6 ...
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_6cfe7_row0_col3, #T_6cfe7_row8_col1, #T_6cfe7_row21_col3, #T_6cfe7_row30_col7 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_6cfe7_row4_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_6cfe7_row4_col1 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_6cfe7_row4_col2, #T_6cfe7_row33_col2 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_6cfe7_row4_col4 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_6cfe7_row4_col5 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_6cfe7_row4_col6 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_6cfe7_row5_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_6cfe7_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6cfe7_row5_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_6cfe7_row5_col4 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_6cfe7_row5_col5 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_6cfe7_row5_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6cfe7_row5_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_6cfe7_row6_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_6cfe7_row6_col1, #T_6cfe7_row11_col3, #T_6cfe7_row23_col7, #T_6cfe7_row24_col1, #T_6cfe7_row26_col4 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_6cfe7_row6_col4, #T_6cfe7_row15_col7, #T_6cfe7_row29_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_6cfe7_row7_col7, #T_6cfe7_row9_col3, #T_6cfe7_row12_col4, #T_6cfe7_row13_col3, #T_6cfe7_row27_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_6cfe7_row8_col0 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_6cfe7_row8_col4 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_6cfe7_row8_col6 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_6cfe7_row12_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_6cfe7_row12_col1, #T_6cfe7_row30_col3 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_6cfe7_row12_col6, #T_6cfe7_row18_col1 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_6cfe7_row12_col7, #T_6cfe7_row14_col7 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_6cfe7_row14_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_6cfe7_row14_col1 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_6cfe7_row14_col2, #T_6cfe7_row26_col5 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_6cfe7_row14_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_6cfe7_row14_col5 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_6cfe7_row14_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6cfe7_row15_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_6cfe7_row16_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_6cfe7_row16_col1 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_6cfe7_row16_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_6cfe7_row16_col4 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_6cfe7_row16_col6, #T_6cfe7_row23_col4, #T_6cfe7_row23_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_6cfe7_row16_col7 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_6cfe7_row18_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_6cfe7_row18_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_6cfe7_row18_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_6cfe7_row18_col7, #T_6cfe7_row33_col5 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_6cfe7_row19_col2 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_6cfe7_row19_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_6cfe7_row21_col0, #T_6cfe7_row33_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_6cfe7_row21_

# %% [markdown]
# ### Land use correlation @ 5 000 m

# %%
# identify the land_use data
buffer_file = "resources/buffer_output/luse_5k.csv"

# make the buffer and get the coeficients
rho_vals_5k, new_buffer_5k, buffer_vals_5k = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)

rho_at_5k, pvals5k, rhovals5k, buffer_results5k = collectBufferResultsRhoAndPvals(rho_vals_5k)
styleBufferResults(buffer_results5k)
# Out:
# Finished 'rhoForOneBuffer' in 114.164 secs
# <style type="text/css">
# #T_970f4 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_970f4 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_970f4 tr {
#   font-size: 12px;
# }
# #T_970f4 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_970f4_row0_col0, #T_970f4_row0_col1, #T_970f4_row0_col2, #T_970f4_row0_col4, #T_970f4_row0_col5, #T_970f4_row0_col6, #T_970f4_row0_col7, #T_970f4_row1_col0, #T_970f4_row1_col1, #T_970f4_row1_col2, #T_970f4_row1_col3, #T_970f4_row1_col4, #T_970f4_row1_col5, #T_970f4_row1_col6, #T_970f4_row1_col7, #T_970f4_row2_col1, #T_970f4_row2_col2, #T_970f4_row2_col3, #T_970f4_row2_col4, #T_970f4_row2_col5, #T_970f4_row2_col6, #T_970f4_row2_col7, #T_970f4_row3_col0, #T_970f4_row3_col1, #T_970f4_row3_col2, #T_970f4_row3_col3, #T_970f4_row3_col4, #T_970f4_row3_col5, #T_970f4_row3_col6, #T_970f4_row3_col7, #T_970f4_row4_col7, #T_970f4_row6_col2, #T_970f4_row6_col3, #T_970f4_row6_col5, #T_970f4_row6_col6, #T_970f4_row6_col7, #T_970f4_row7_col0, #T_970f4_row7_col1, #T_970f4_row7_col2, #T_970f4_row7_col3, #T_970f4_row7_col4, #T_970f4_row7_col5, #T_970f4_row7_col6, #T_970f4_row8_col2, #T_970f4_row8_col3, #T_970f4_row8_col5, #T_970f4_row8_col7, #T_970f4_row9_col1, #T_970f4_row9_col2, #T_970f4_row9_col4, #T_970f4_row9_col5, #T_970f4_row9_col6, #T_970f4_row9_col7, #T_970f4_row10_col0, #T_970f4_row10_col1, #T_970f4_row10_col2, #T_970f4_row10_col3, #T_970f4_row10_col4, #T_970f4_row10_col5, #T_970f4_row10_col6, #T_970f4_row10_col7, #T_970f4_row11_col0, #T_970f4_row11_col1, #T_970f4_row11_col2, #T_970f4_row11_col4, #T_970f4_row11_col5, #T_970f4_row11_col6, #T_970f4_row11_col7, #T_970f4_row12_col2, #T_970f4_row12_col3, #T_970f4_row12_col4, #T_970f4_row12_col5, #T_970f4_row12_col7, #T_970f4_row13_col0, #T_970f4_row13_col1, #T_970f4_row13_col2, #T_970f4_row13_col4, #T_970f4_row13_col5, #T_970f4_row13_col6, #T_970f4_row13_col7, #T_970f4_row14_col3, #T_970f4_row14_col7, #T_970f4_row15_col1, #T_970f4_row15_col2, #T_970f4_row15_col3, #T_970f4_row15_col4, #T_970f4_row15_col5, #T_970f4_row15_col6, #T_970f4_row15_col7, #T_970f4_row16_col2, #T_970f4_row16_col5, #T_970f4_row16_col7, #T_970f4_row17_col0, #T_970f4_row17_col1, #T_970f4_row17_col2, #T_970f4_row17_col3, #T_970f4_row17_col4, #T_970f4_row17_col5, #T_970f4_row17_col6, #T_970f4_row17_col7, #T_970f4_row18_col0, #T_970f4_row18_col6, #T_970f4_row19_col0, #T_970f4_row19_col1, #T_970f4_row19_col4, #T_970f4_row19_col5, #T_970f4_row19_col6, #T_970f4_row19_col7, #T_970f4_row20_col0, #T_970f4_row20_col1, #T_970f4_row20_col2, #T_970f4_row20_col3, #T_970f4_row20_col4, #T_970f4_row20_col5, #T_970f4_row20_col6, #T_970f4_row20_col7, #T_970f4_row21_col1, #T_970f4_row21_col2, #T_970f4_row21_col4, #T_970f4_row21_col5, #T_970f4_row21_col7, #T_970f4_row22_col0, #T_970f4_row22_col1, #T_970f4_row22_col4, #T_970f4_row22_col5, #T_970f4_row22_col6, #T_970f4_row22_col7, #T_970f4_row23_col7, #T_970f4_row24_col0, #T_970f4_row24_col2, #T_970f4_row24_col3, #T_970f4_row24_col4, #T_970f4_row24_col5, #T_970f4_row24_col6, #T_970f4_row24_col7, #T_970f4_row25_col0, #T_970f4_row25_col1, #T_970f4_row25_col2, #T_970f4_row25_col3, #T_970f4_row25_col4, #T_970f4_row25_col5, #T_970f4_row25_col6, #T_970f4_row25_col7, #T_970f4_row26_col0, #T_970f4_row26_col1, #T_970f4_row26_col2, #T_970f4_row26_col3, #T_970f4_row26_col7, #T_970f4_row27_col0, #T_970f4_row27_col1, #T_970f4_row27_col2, #T_970f4_row27_col3, #T_970f4_row27_col4, #T_970f4_row27_col5, #T_970f4_row27_col6, #T_970f4_row27_col7, #T_970f4_row28_col0, #T_970f4_row28_col1, #T_970f4_row28_col2, #T_970f4_row28_col3, #T_970f4_row28_col4, #T_970f4_row28_col5, #T_970f4_row28_col6, #T_970f4_row28_col7, #T_970f4_row29_col0, #T_970f4_row29_col2, #T_970f4_row29_col4, #T_970f4_row29_col5, #T_970f4_row30_col0, #T_970f4_row30_col4, #T_970f4_row30_col5, #T_970f4_row31_col0, #T_970f4_row31_col1, #T_970f4_row31_col2, #T_970f4_row31_col3, #T_970f4_row31_col4, #T_970f4_row31_col5, #T_970f4_row32_col0, #T_970f4_row32_col1, #T_970f4_row32_col2, #T_970f4_row32_col3, #T_970f4_row32_col4, #T_970f4_row32_col5, #T_970f4_row32_col7, #T_970f4_row33_col1, #T_970f4_row33_col7, #T_970f4_row34_col0, #T_970f4_row34_col1, #T_970f4_row34_col4, #T_970f4_row34_col6, #T_970f4_row34_col7, #T_970f4_row35_col0, #T_970f4_row35_col1,  ...
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_970f4_row0_col3, #T_970f4_row21_col3, #T_970f4_row26_col4, #T_970f4_row30_col7 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_970f4_row2_col0 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_970f4_row4_col0 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_970f4_row4_col1 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_970f4_row4_col2 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_970f4_row4_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_970f4_row4_col4 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_970f4_row4_col5 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_970f4_row4_col6 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_970f4_row5_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_970f4_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_970f4_row5_col2, #T_970f4_row7_col7, #T_970f4_row13_col3 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_970f4_row5_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_970f4_row5_col4 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_970f4_row5_col5 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_970f4_row5_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_970f4_row5_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_970f4_row6_col0, #T_970f4_row29_col1 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_970f4_row6_col1, #T_970f4_row23_col6 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_970f4_row6_col4 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_970f4_row8_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_970f4_row8_col1, #T_970f4_row24_col1 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_970f4_row8_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_970f4_row8_col6 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_970f4_row9_col0, #T_970f4_row31_col7 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_970f4_row9_col3, #T_970f4_row29_col3 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_970f4_row11_col3, #T_970f4_row29_col6 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_970f4_row12_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_970f4_row12_col1, #T_970f4_row22_col3 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_970f4_row12_col6 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_970f4_row14_col0 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_970f4_row14_col1 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_970f4_row14_col2 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_970f4_row14_col4 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_970f4_row14_col5, #T_970f4_row18_col7 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_970f4_row14_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_970f4_row15_col0 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_970f4_row16_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_970f4_row16_col1 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_970f4_row16_col3 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_970f4_row16_col4 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_970f4_row16_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_970f4_row18_col1 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_970f4_row18_col2, #T_970f4_row22_col2, #T_970f4_row30_col2, #T_970f4_row33_col0 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_970f4_row18_col3 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_970f4_row18_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_970f4_row18_col5, #T_970f4_row34_col2 {
#   back

# %% [markdown]
# ### Land use correlation @ 10 000 m

# %%
# identify the land_use data
buffer_file = "resources/buffer_output/luse_10k.csv"

# make the buffer and get the coeficients
rho_vals_10k, new_buffer_10k, buffer_vals_10k = rhoForOneBuffer(data=df, buffer_file=buffer_file , codes=codes_fail, land_use=land_use)

rho_at_10k, pvals10k, rhovals10k, buffer_results10k = collectBufferResultsRhoAndPvals(rho_vals_10k)
styleBufferResults(buffer_results10k)
# Out:
# Finished 'rhoForOneBuffer' in 158.403 secs
# <style type="text/css">
# #T_358af tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_358af tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_358af tr {
#   font-size: 12px;
# }
# #T_358af th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_358af_row0_col0, #T_358af_row0_col1, #T_358af_row0_col4, #T_358af_row0_col5, #T_358af_row0_col6, #T_358af_row1_col0, #T_358af_row1_col1, #T_358af_row1_col2, #T_358af_row1_col3, #T_358af_row1_col4, #T_358af_row1_col5, #T_358af_row1_col6, #T_358af_row1_col7, #T_358af_row2_col0, #T_358af_row2_col1, #T_358af_row2_col2, #T_358af_row2_col3, #T_358af_row2_col4, #T_358af_row2_col5, #T_358af_row2_col6, #T_358af_row2_col7, #T_358af_row3_col0, #T_358af_row3_col1, #T_358af_row3_col2, #T_358af_row3_col3, #T_358af_row3_col4, #T_358af_row3_col5, #T_358af_row3_col6, #T_358af_row3_col7, #T_358af_row4_col0, #T_358af_row4_col3, #T_358af_row4_col7, #T_358af_row5_col6, #T_358af_row6_col0, #T_358af_row6_col1, #T_358af_row6_col2, #T_358af_row6_col3, #T_358af_row6_col4, #T_358af_row6_col5, #T_358af_row6_col6, #T_358af_row6_col7, #T_358af_row7_col0, #T_358af_row7_col1, #T_358af_row7_col2, #T_358af_row7_col3, #T_358af_row7_col4, #T_358af_row7_col5, #T_358af_row7_col6, #T_358af_row8_col0, #T_358af_row8_col2, #T_358af_row8_col3, #T_358af_row8_col4, #T_358af_row8_col5, #T_358af_row8_col6, #T_358af_row8_col7, #T_358af_row9_col0, #T_358af_row9_col1, #T_358af_row9_col2, #T_358af_row9_col4, #T_358af_row9_col5, #T_358af_row9_col6, #T_358af_row9_col7, #T_358af_row10_col0, #T_358af_row10_col1, #T_358af_row10_col2, #T_358af_row10_col3, #T_358af_row10_col4, #T_358af_row10_col5, #T_358af_row10_col6, #T_358af_row11_col0, #T_358af_row11_col1, #T_358af_row11_col2, #T_358af_row11_col4, #T_358af_row11_col5, #T_358af_row11_col6, #T_358af_row11_col7, #T_358af_row12_col0, #T_358af_row12_col2, #T_358af_row12_col3, #T_358af_row12_col5, #T_358af_row12_col6, #T_358af_row12_col7, #T_358af_row13_col0, #T_358af_row13_col5, #T_358af_row13_col6, #T_358af_row13_col7, #T_358af_row14_col0, #T_358af_row14_col3, #T_358af_row14_col6, #T_358af_row14_col7, #T_358af_row15_col0, #T_358af_row15_col1, #T_358af_row15_col2, #T_358af_row15_col3, #T_358af_row15_col4, #T_358af_row15_col5, #T_358af_row15_col6, #T_358af_row15_col7, #T_358af_row16_col0, #T_358af_row16_col2, #T_358af_row16_col5, #T_358af_row16_col6, #T_358af_row16_col7, #T_358af_row17_col0, #T_358af_row17_col1, #T_358af_row17_col2, #T_358af_row17_col3, #T_358af_row17_col4, #T_358af_row17_col5, #T_358af_row17_col6, #T_358af_row17_col7, #T_358af_row18_col0, #T_358af_row19_col1, #T_358af_row19_col4, #T_358af_row19_col5, #T_358af_row20_col0, #T_358af_row20_col1, #T_358af_row20_col2, #T_358af_row20_col3, #T_358af_row20_col4, #T_358af_row20_col5, #T_358af_row20_col6, #T_358af_row20_col7, #T_358af_row21_col1, #T_358af_row21_col2, #T_358af_row21_col4, #T_358af_row21_col5, #T_358af_row21_col6, #T_358af_row22_col0, #T_358af_row22_col1, #T_358af_row22_col2, #T_358af_row22_col4, #T_358af_row22_col5, #T_358af_row22_col6, #T_358af_row23_col0, #T_358af_row23_col1, #T_358af_row23_col2, #T_358af_row23_col4, #T_358af_row23_col6, #T_358af_row23_col7, #T_358af_row24_col1, #T_358af_row24_col3, #T_358af_row24_col4, #T_358af_row24_col5, #T_358af_row25_col0, #T_358af_row25_col1, #T_358af_row25_col2, #T_358af_row25_col3, #T_358af_row25_col4, #T_358af_row25_col5, #T_358af_row25_col6, #T_358af_row25_col7, #T_358af_row26_col0, #T_358af_row26_col1, #T_358af_row26_col2, #T_358af_row26_col3, #T_358af_row26_col4, #T_358af_row26_col6, #T_358af_row26_col7, #T_358af_row27_col0, #T_358af_row27_col1, #T_358af_row27_col2, #T_358af_row27_col3, #T_358af_row27_col5, #T_358af_row27_col6, #T_358af_row27_col7, #T_358af_row28_col0, #T_358af_row28_col1, #T_358af_row28_col2, #T_358af_row28_col3, #T_358af_row28_col4, #T_358af_row28_col5, #T_358af_row28_col6, #T_358af_row28_col7, #T_358af_row29_col0, #T_358af_row29_col1, #T_358af_row29_col2, #T_358af_row29_col3, #T_358af_row29_col4, #T_358af_row29_col5, #T_358af_row29_col6, #T_358af_row30_col0, #T_358af_row30_col5, #T_358af_row31_col0, #T_358af_row31_col1, #T_358af_row31_col2, #T_358af_row31_col3, #T_358af_row31_col4, #T_358af_row31_col5, #T_358af_row31_col7, #T_358af_row32_col0, #T_358af_row32_col1, #T_358af_row32_col2, #T_358af_ ...
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_358af_row0_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_358af_row0_col3, #T_358af_row10_col7, #T_358af_row21_col3 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_358af_row0_col7 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_358af_row4_col1, #T_358af_row34_col7 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_358af_row4_col2 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_358af_row4_col4, #T_358af_row21_col7 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_358af_row4_col5, #T_358af_row5_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_358af_row4_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_358af_row5_col0 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_358af_row5_col2 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_358af_row5_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_358af_row5_col4 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_358af_row5_col5 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_358af_row5_col7, #T_358af_row19_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_358af_row7_col7 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_358af_row8_col1 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_358af_row9_col3, #T_358af_row13_col2, #T_358af_row19_col6, #T_358af_row30_col7 {
#   background-color: #f4c6af;
#   color: #000000;
# }
# #T_358af_row11_col3, #T_358af_row16_col4 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_358af_row12_col1 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_358af_row12_col4 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_358af_row13_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_358af_row13_col3, #T_358af_row29_col7 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_358af_row13_col4, #T_358af_row14_col2 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_358af_row14_col1, #T_358af_row18_col3 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_358af_row14_col4 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_358af_row14_col5 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_358af_row16_col1 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_358af_row16_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_358af_row18_col1 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_358af_row18_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_358af_row18_col4 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_358af_row18_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_358af_row18_col6 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_358af_row18_col7 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_358af_row19_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_358af_row19_col3 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_358af_row19_col7 {
#   background-color: #f59f80;
#   color: #000000;
# }
# #T_358af_row21_col0, #T_358af_row30_col1, #T_358af_row30_col2, #T_358af_row30_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_358af_row22_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_358af_row22_col7, #T_358af_row24_col6, #T_358af_row24_col7 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_358af_row23_col3 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_358af_row23_col5 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_358af_row24_col

# %% [markdown]
# ### Covariance of explanatory variables @ 1500 m

# %%
buffer_percents = buffer_vals.T
buffer_percents = buffer_percents[land_use]
rho = buffer_percents.corr(method='spearman')
pval = buffer_percents.corr(method=lambda x, y: stats.spearmanr(x, y)[1])
pless = pd.DataFrame(resultsDf(rho, pval))

pless.columns.name = None
bfr = pless.style.format(precision=2).set_table_styles(table_css_styles)
bfr = bfr.background_gradient(axis=None, vmin=rho.min().min(), vmax=rho.max().max(), cmap="coolwarm")
bfr = bfr.applymap_index(rotateText, axis=1)
bfr
# Out:
# <style type="text/css">
# #T_ce378 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_ce378 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_ce378 tr {
#   font-size: 12px;
# }
# #T_ce378 th:nth-child(1) {
#   background-color: #FFF;
# }
# #T_ce378_row0_col0, #T_ce378_row0_col6, #T_ce378_row1_col1, #T_ce378_row1_col4, #T_ce378_row1_col7, #T_ce378_row2_col2, #T_ce378_row3_col3, #T_ce378_row3_col6, #T_ce378_row4_col1, #T_ce378_row4_col4, #T_ce378_row4_col5, #T_ce378_row4_col6, #T_ce378_row5_col4, #T_ce378_row5_col5, #T_ce378_row5_col6, #T_ce378_row6_col0, #T_ce378_row6_col3, #T_ce378_row6_col4, #T_ce378_row6_col5, #T_ce378_row6_col6, #T_ce378_row7_col1, #T_ce378_row7_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_ce378_row0_col1, #T_ce378_row1_col0, #T_ce378_row6_col7, #T_ce378_row7_col6 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_ce378_row0_col2, #T_ce378_row2_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_ce378_row0_col3, #T_ce378_row3_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ce378_row0_col4, #T_ce378_row4_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_ce378_row0_col5, #T_ce378_row5_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_ce378_row0_col7, #T_ce378_row7_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_ce378_row1_col2, #T_ce378_row2_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_ce378_row1_col3, #T_ce378_row3_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_ce378_row1_col5, #T_ce378_row5_col1 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_ce378_row1_col6, #T_ce378_row6_col1 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_ce378_row2_col3, #T_ce378_row3_col2 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_ce378_row2_col4, #T_ce378_row4_col2 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_ce378_row2_col5, #T_ce378_row5_col2 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_ce378_row2_col6, #T_ce378_row6_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ce378_row2_col7, #T_ce378_row3_col7, #T_ce378_row7_col2, #T_ce378_row7_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_ce378_row3_col4, #T_ce378_row4_col3 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_ce378_row3_col5, #T_ce378_row5_col3 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_ce378_row4_col7, #T_ce378_row7_col4 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_ce378_row5_col7, #T_ce378_row7_col5 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_ce378_level0_col0, #T_ce378_level0_col1, #T_ce378_level0_col2, #T_ce378_level0_col3, #T_ce378_level0_col4, #T_ce378_level0_col5, #T_ce378_level0_col6, #T_ce378_level0_col7 {
#   writing-mode: vertical-lr;
#   transform: rotate(-180deg);
#   padding: 10px;
#   margins: 0;
#   vertical-align: baseline;
# }
# </style>
# <table id="T_ce378">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce378_level0_col0" class="col_heading level0 col0" >buildings</th>
#       <th id="T_ce378_level0_col1" class="col_heading level0 col1" >industrial</th>
#       <th id="T_ce378_level0_col2" class="col_heading level0 col2" >roads</th>
#       <th id="T_ce378_level0_col3" class="col_heading level0 col3" >recreation</th>
#       <th id="T_ce378_level0_col4" class="col_heading level0 col4" >agriculture</th>
#       <th id="T_ce378_level0_col5" class="col_heading level0 col5" >woods</th>
#       <th id="T_ce378_level0_col6" class="col_heading level0 col6" >intersects</th>
#       <th id="T_ce378_level0_col7" class="col_heading level0 col7" >unproductive</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce378_level0_row0" class="row_heading level0 row0" >buildings</th>
#       <td id="T_ce378_row0_col0" class="data row0 col0" >0.00</td>
#       <td id="T_ce378_row0_col1" class="data row0 col1" >0.20</td>
#       <td id="T_ce378_row0_col2" class="data row0 col2" >0.48</td>
#       <td id="T_ce378_row0_col3" class="data row0 col3" >0.69</td>
#       <td id="T_ce378_row0_col4" class="data row0 col4" >-0.67</td>
#       <td id="T_ce378_row0_col5" class="data row0 col5" >-0.65</td>
#       <td id="T_ce378_row0_col6" class="data row0 col6" >0.00</td>
#       <td id="T_ce378_row0_col7" class="data row0 col7" >-0.61</td>
#     </tr>
#     <tr>
#       <th id="T_ce378_level0_row1" class="row_heading level0 row1" >industrial</th>
#       <td id="T_ce378_row1_col0" class="data row1 col0" >0.20</td>
#       <td id="T_ce378_row1_col1" class="data row1 col1" >0.00</td>
#       <td id="T_ce378_row1_col2" class="data row1 col2" >0.38</td>
#       <td id="T_ce378_row1_col3" class="data row1 col3" >0.31</td>
#       <td id="T_ce378_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_ce378_row1_col5" class="data row1 col5" >-0.26</td>
#       <td id="T_ce378_row1_col6" class="data row1 col6" >-0.21</td>
#       <td id="T_ce378_row1_col7" class="data row1 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_ce378_level0_row2" class="row_heading level0 row2" >roads</th>
#       <td id="T_ce378_row2_col0" class="data row2 col0" >0.48</td>
#       <td id="T_ce378_row2_col1" class="data row2 col1" >0.38</td>
#       <td id="T_ce378_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_ce378_row2_col3" class="data row2 col3" >0.44</td>
#       <td id="T_ce378_row2_col4" class="data row2 col4" >-0.37</td>
#       <td id="T_ce378_row2_col5" class="data row2 col5" >-0.20</td>
#       <td id="T_ce378_row2_col6" class="data row2 col6" >-0.68</td>
#       <td id="T_ce378_row2_col7" class="data row2 col7" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_ce378_level0_row3" class="row_heading level0 row3" >recreation</th>
#       <td id="T_ce378_row3_col0" class="data row3 col0" >0.69</td>
#       <td id="T_ce378_row3_col1" class="data row3 col1" >0.31</td>
#       <td id="T_ce378_row3_col2" class="data row3 col2" >0.44</td>
#       <td id="T_ce378_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_ce378_row3_col4" class="data row3 col4" >-0.47</td>
#       <td id="T_ce378_row3_col5" class="data row3 col5" >-0.55</td>
#       <td id="T_ce378_row3_col6" class="data row3 col6" >0.00</td>
#       <td id="T_ce378_row3_col7" class="data row3 col7" >-0.34</td>
#     </tr>
#     <tr>
#       <th id="T_ce378_level0_row4" class="row_heading level0 row4" >agriculture</th>
#       <td id="T_ce378_row4_col0" class="data row4 col0" >-0.67</td>
#       <td id="T_ce378_row4_col1" class="data row4 col1" >0.00</td>
#       <td id="T_ce378_row4_col2" class="data row4 col2" >-0.37</td>
#       <td id="T_ce378_row4_col3" class="data row4 col3" >-0.47</td>
#       <td id="T_ce378_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_ce378_row4_col5" class="data row4 col5" >0.00</td>
#       <td id="T_ce378_row4_col6" class="data row4 col6" >0.00</td>
#       <td id="T_ce378_row4_col7" class="data row4 col7" >0.40</td>
#     </tr>
#     <tr>
#       <th id="T_ce378_level0_row5" class="row_heading level0 row5" >woods</th>
#       <td id="T_ce378_row5_col0" class="data row5 col0" >-0.65</td>
#       <td id="T_ce378_row5_col1" class="data row5 col1" >-0.26</td>
#       <td id="T_ce378_row5_col2" class="data row5 col2" >-0.20</td>
#       <td id="T_ce378_row5_col3" class="data row5 col3" >-0.55</td>
#       <td id="T_ce378_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_ce378_row5_col5" class="data row5 col5" >0.00</td>
#       <td id="T_ce378_row5_col6" class="data row5 col6" >0.00</td>
#       <td id="T_ce378_row5_col7" class="data row5 col7" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_ce378_level0_row6" class="row_heading level0 row6" >intersects</th>
#       <td id="T_ce378_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_ce378_row6_col1" class="data row6 col1" >-0.21</td>
#       <td id="T_ce378_row6_col2" class="data row6 col2" >-0.68</td>
#       <td id="T_ce378_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_ce378_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_ce378_row6_col5" class="data row6 col5" >0.00</td>
#       <td id="T_ce378_row6_col6" class="data row6 col

# %% [markdown]
# ### Land use characteristics @ 1500 m

# %%
fdx = SurveyResults()
df = fdx.surveyResults()
location_no_luse = ["linth_route9brucke",
                "seez_spennwiesenbrucke",
                'limmat_dietikon_keiserp',
                "seez"]

city_no_luse = ["Walenstadt", "Weesen", "Glarus Nord", "Quarten"]

df = df[~df.location.isin(no_luse_data)]
df = df[~df.city.isin(city_no_luse)]

dfdt = df.groupby(["loc_date", "location"], as_index=False).pcs_m.sum()

def applyBufferDataToSurveys(data, buffer_data):
    
    locations = data.location.unique()
    
    
    for location in locations:
        if location in buffer_data.columns:
            landuse = buffer_data[location]
            data.loc[data.location == location, landuse.index] = landuse.values
        else:
            print(location)
            pass
    return data

daily_totals_landuse = applyBufferDataToSurveys(dfdt, buffer_vals)



pretty_names = {"buildings":"Built-up environment [%]",
                'industrial':'Industries [%]',
                'recreation': 'Recreational [%]',
                'agriculture':'Agriculture [%]',
                'woods':'Forests [%]',               
                'unproductive':'Unproductive land [%]',
                'roads':'Road network \nlength [km]',
                'intersects': 'Rivers/canals [#]',
               }

# method to get the ranked correlation of pcs_m to each explanatory variable
def make_plot_with_spearmans(data, ax, n):
    sns.scatterplot(data=data, x=n, y=unit_label, ax=ax, color='black', s=30, edgecolor='white', alpha=0.6)
    corr, a_p = stats.spearmanr(data[n], data[unit_label])
    return ax, corr, a_p

sns.set_style("whitegrid")
fig, axs = plt.subplots(1,4, figsize=(10,3.2), sharey=True)

data = daily_totals_landuse
loi = ['buildings', 'industrial','recreation','agriculture','woods','unproductive', 'intersects', 'roads']
for i, n in enumerate(loi[:4]):
    ax=axs[i]
    
    # the ECDF of the land use variable
    the_data = ECDF(data[n].values)
    sns.lineplot(x=the_data.x, y= (the_data.y), ax=ax, color='dodgerblue', label="% of surface area" )
    
    # get the median % of land use for each variable under consideration from the data
    the_median = data[n].median()
    
    # plot the median and drop horzontal and vertical lines
    ax.scatter([the_median], .5, color='red',s=50, linewidth=2, zorder=100, label="the median")
    ax.vlines(x=the_median, ymin=0, ymax=.5, color='red', linewidth=2)
    ax.hlines(xmax=the_median, xmin=0, y=0.5, color='red', linewidth=2)
    
    #remove the legend from ax   
    ax.get_legend().remove()
    
    if i == 0:
        ax.set_ylabel("Share of \nsurveys [%]", labelpad = 15)
    else:
        pass
    
    # add the median value from all locations to the ax title
    ax.set_title(F"median: {(round(the_median, 2))}",fontsize=12, loc='left')
    ax.set_xlabel(pretty_names[n], fontsize=14, labelpad=15)

plt.tight_layout()

plt.show()

# %%
fig, axs = plt.subplots(1,4, figsize=(10,3.2), sharey=True)
for i, n in enumerate(loi[4:]):
    ax=axs[i]
    
    # the ECDF of the land use variable
    the_data = ECDF(data[n].values)
    sns.lineplot(x=the_data.x, y= (the_data.y), ax=ax, color='dodgerblue', label="% of surface area" )
    
    # get the median % of land use for each variable under consideration from the data
    the_median = data[n].median()
    
    # plot the median and drop horzontal and vertical lines
    ax.scatter([the_median], .5, color='red',s=50, linewidth=2, zorder=100, label="the median")
    ax.vlines(x=the_median, ymin=0, ymax=.5, color='red', linewidth=2)
    ax.hlines(xmax=the_median, xmin=0, y=0.5, color='red', linewidth=2)
    
    #remove the legend from ax   
    ax.get_legend().remove()
    
    if i == 0:
        ax.set_ylabel("Share of \nsurveys [%]", labelpad = 15)
    else:
        pass
    
    # add the median value from all locations to the ax title
    ax.set_title(F"median: {(round(the_median, 2))}",fontsize=12, loc='left')
    ax.set_xlabel(pretty_names[n], fontsize=14, labelpad=15)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Total correlations, total positive correlations, total negative corrrelations for each buffer radius

# %%
def countTheNumberOfCorrelationsPerBuffer(pvals: pdtype = None, rhovals: pdtype = None) -> (pdtype, pstype):
    
    # the number of times p <= 0.05
    number_p_less_than = (pvals <= 0.05).sum()
    number_p_less_than.name = "correlated"
    
    # the number of postive correlations
    number_pos = (rhovals > 0).sum()
    number_pos.name = "positive"
    
    # the number of negative correlations
    number_neg = (rhovals < 0).sum()
    number_neg.name = "negative"

    ncorrelated = pd.DataFrame([number_p_less_than, number_pos, number_neg])
    ncorrelated["total"] = ncorrelated.sum(axis=1)
    totals = ncorrelated.total
    
    
    return ncorrelated, totals

ncorrelated, total = countTheNumberOfCorrelationsPerBuffer(pvals, rhovals)

pairs = [
    (pvals, rhovals, "1.5k"),
    (pvals2k, rhovals2k, "2k"),
    (pvals25k, rhovals25k, "2.5k"),
    (pvals3k, rhovals3k, "3k"),
    (pvals35k, rhovals35k, "3.5k"),
    (pvals4k, rhovals4k, "4k"),
    (pvals45k, rhovals45k, "4.5k"),
    (pvals5k, rhovals5k, "5k"),
    (pvals10k, rhovals10k, "10k")
]

rho_vals_all = [
    rho_at_buffer,
    rho_at_2k,
    rho_at_25k,
    rho_at_3k,
    rho_at_35k,
    rho_at_4k,
    rho_at_45k,
    rho_at_5k,
    rho_at_10k
]

buffers = [
    new_buffer,
    new_buffer_2k,
    new_buffer_2_5k,
    new_buffer_3k,
    new_buffer_3_5k,
    new_buffer_4k,
    new_buffer_4_5k,
    new_buffer_5k,
    new_buffer_10k
]    

rhos_and_ps = []
for pair in pairs:
    _, total = countTheNumberOfCorrelationsPerBuffer(pair[0], pair[1])
    total.name = pair[2]
    rhos_and_ps.append(total)

correlation_results = pd.DataFrame(rhos_and_ps)

res = correlation_results.style.set_table_styles(table_css_styles)
res
# Out:
# <style type="text/css">
# #T_7eea3 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_7eea3 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_7eea3 tr {
#   font-size: 12px;
# }
# #T_7eea3 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_7eea3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7eea3_level0_col0" class="col_heading level0 col0" >correlated</th>
#       <th id="T_7eea3_level0_col1" class="col_heading level0 col1" >positive</th>
#       <th id="T_7eea3_level0_col2" class="col_heading level0 col2" >negative</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eea3_level0_row0" class="row_heading level0 row0" >1.5k</th>
#       <td id="T_7eea3_row0_col0" class="data row0 col0" >110</td>
#       <td id="T_7eea3_row0_col1" class="data row0 col1" >52</td>
#       <td id="T_7eea3_row0_col2" class="data row0 col2" >58</td>
#     </tr>
#     <tr>
#       <th id="T_7eea3_level0_row1" class="row_heading level0 row1" >2k</th>
#       <td id="T_7eea3_row1_col0" class="data row1 col0" >101</td>
#       <td id="T_7eea3_row1_col1" class="data row1 col1" >51</td>
#       <td id="T_7eea3_row1_col2" class="data row1 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_7eea3_level0_row2" class="row_heading level0 row2" >2.5k</th>
#       <td id="T_7eea3_row2_col0" class="data row2 col0" >101</td>
#       <td id="T_7eea3_row2_col1" class="data row2 col1" >51</td>
#       <td id="T_7eea3_row2_col2" class="data row2 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_7eea3_level0_row3" class="row_heading level0 row3" >3k</th>
#       <td id="T_7eea3_row3_col0" class="data row3 col0" >98</td>
#       <td id="T_7eea3_row3_col1" class="data row3 col1" >50</td>
#       <td id="T_7eea3_row3_col2" class="data row3 col2" >48</td>
#     </tr>
#     <tr>
#       <th id="T_7eea3_level0_row4" class="row_heading level0 row4" >3.5k</th>
#       <td id="T_7eea3_row4_col0" class="data row4 col0" >96</td>
#       <td id="T_7eea3_row4_col1" class="data row4 col1" >50</td>
#       <td id="T_7eea3_row4_col2" class="data row4 col2" >46</td>
#     </tr>
#     <tr>
#       <th id="T_7eea3_level0_row5" class="row_heading level0 row5" >4k</th>
#       <td id="T_7eea3_row5_col0" class="data row5 col0" >95</td>
#       <td id="T_7eea3_row5_col1" class="data row5 col1" >50</td>
#       <td id="T_7eea3_row5_col2" class="data row5 col2" >45</td>
#     </tr>
#     <tr>
#       <th id="T_7eea3_level0_row6" class="row_heading level0 row6" >4.5k</th>
#       <td id="T_7eea3_row6_col0" class="data row6 col0" >92</td>
#       <td id="T_7eea3_row6_col1" class="data row6 col1" >51</td>
#       <td id="T_7eea3_row6_col2" class="data row6 col2" >41</td>
#     </tr>
#     <tr>
#       <th id="T_7eea3_level0_row7" class="row_heading level0 row7" >5k</th>
#       <td id="T_7eea3_row7_col0" class="data row7 col0" >91</td>
#       <td id="T_7eea3_row7_col1" class="data row7 col1" >47</td>
#       <td id="T_7eea3_row7_col2" class="data row7 col2" >44</td>
#     </tr>
#     <tr>
#       <th id="T_7eea3_level0_row8" class="row_heading level0 row8" >10k</th>
#       <td id="T_7eea3_row8_col0" class="data row8 col0" >78</td>
#       <td id="T_7eea3_row8_col1" class="data row8 col1" >53</td>
#       <td id="T_7eea3_row8_col2" class="data row8 col2" >25</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Changes of land use profile for different buffer zones
#
# As the radius of the buffer zone changes the land use mix changes. Defining the radius of the buffer zone is determined by the scale at which the reporting is being done. For the report to Switzerland the target administrative level was the municipality. Therefore a radius of 1500m was appropriate, given the geographic size of a municipality in Switzerland.

# %%
def combineAdjustedBuffers(buffers, pairs):
    
    combined_buffers = []
    for i,n in enumerate(pairs):
        a_buffer=buffers[i].adjusted_buffer
        a_buffer["radius"] = n[2]
        combined_buffers.append(a_buffer[["label", "radius"]])
        
    return pd.concat(combined_buffers, axis=0)
combined_buffers = combineAdjustedBuffers(buffers, pairs)

total_radius = combined_buffers.groupby("radius", as_index=False).label.value_counts()

total_radius = total_radius[total_radius.label != "water"]
total_radius = total_radius.pivot(index="radius", columns="label")
total_radius.columns = total_radius.columns.droplevel()
total_radius = total_radius.div(total_radius.sum(axis=1), axis=0).T
total_radius = total_radius[[total_radius.columns[0], *total_radius.columns[2:], total_radius.columns[1]]]
total_radius = total_radius.mul(100).astype(int)
total_radius.columns.name = None
total_radius.index.name = None
total_radius.style.set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_6763f tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_6763f tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_6763f tr {
#   font-size: 12px;
# }
# #T_6763f th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_6763f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6763f_level0_col0" class="col_heading level0 col0" >1.5k</th>
#       <th id="T_6763f_level0_col1" class="col_heading level0 col1" >2.5k</th>
#       <th id="T_6763f_level0_col2" class="col_heading level0 col2" >2k</th>
#       <th id="T_6763f_level0_col3" class="col_heading level0 col3" >3.5k</th>
#       <th id="T_6763f_level0_col4" class="col_heading level0 col4" >3k</th>
#       <th id="T_6763f_level0_col5" class="col_heading level0 col5" >4.5k</th>
#       <th id="T_6763f_level0_col6" class="col_heading level0 col6" >4k</th>
#       <th id="T_6763f_level0_col7" class="col_heading level0 col7" >5k</th>
#       <th id="T_6763f_level0_col8" class="col_heading level0 col8" >10k</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6763f_level0_row0" class="row_heading level0 row0" >agriculture</th>
#       <td id="T_6763f_row0_col0" class="data row0 col0" >24</td>
#       <td id="T_6763f_row0_col1" class="data row0 col1" >26</td>
#       <td id="T_6763f_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_6763f_row0_col3" class="data row0 col3" >29</td>
#       <td id="T_6763f_row0_col4" class="data row0 col4" >28</td>
#       <td id="T_6763f_row0_col5" class="data row0 col5" >31</td>
#       <td id="T_6763f_row0_col6" class="data row0 col6" >30</td>
#       <td id="T_6763f_row0_col7" class="data row0 col7" >32</td>
#       <td id="T_6763f_row0_col8" class="data row0 col8" >40</td>
#     </tr>
#     <tr>
#       <th id="T_6763f_level0_row1" class="row_heading level0 row1" >buildings</th>
#       <td id="T_6763f_row1_col0" class="data row1 col0" >28</td>
#       <td id="T_6763f_row1_col1" class="data row1 col1" >25</td>
#       <td id="T_6763f_row1_col2" class="data row1 col2" >26</td>
#       <td id="T_6763f_row1_col3" class="data row1 col3" >22</td>
#       <td id="T_6763f_row1_col4" class="data row1 col4" >23</td>
#       <td id="T_6763f_row1_col5" class="data row1 col5" >19</td>
#       <td id="T_6763f_row1_col6" class="data row1 col6" >20</td>
#       <td id="T_6763f_row1_col7" class="data row1 col7" >18</td>
#       <td id="T_6763f_row1_col8" class="data row1 col8" >8</td>
#     </tr>
#     <tr>
#       <th id="T_6763f_level0_row2" class="row_heading level0 row2" >industrial</th>
#       <td id="T_6763f_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_6763f_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_6763f_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_6763f_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_6763f_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_6763f_row2_col5" class="data row2 col5" >2</td>
#       <td id="T_6763f_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_6763f_row2_col7" class="data row2 col7" >2</td>
#       <td id="T_6763f_row2_col8" class="data row2 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6763f_level0_row3" class="row_heading level0 row3" >recreation</th>
#       <td id="T_6763f_row3_col0" class="data row3 col0" >5</td>
#       <td id="T_6763f_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_6763f_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_6763f_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_6763f_row3_col4" class="data row3 col4" >4</td>
#       <td id="T_6763f_row3_col5" class="data row3 col5" >3</td>
#       <td id="T_6763f_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_6763f_row3_col7" class="data row3 col7" >2</td>
#       <td id="T_6763f_row3_col8" class="data row3 col8" >1</td>
#     </tr>
#     <tr>
#       <th id="T_6763f_level0_row4" class="row_heading level0 row4" >transport</th>
#       <td id="T_6763f_row4_col0" class="data row4 col0" >12</td>
#       <td id="T_6763f_row4_col1" class="data row4 col1" >10</td>
#       <td id="T_6763f_row4_col2" class="data row4 col2" >11</td>
#       <td id="T_6763f_row4_col3" class="data row4 col3" >9</td>
#       <td id="T_6763f_row4_col4" class="data row4 col4" >10</td>
#       <td id="T_6763f_row4_col5" class="data row4 col5" >8</td>
#       <td id="T_6763f_row4_col6" class="data row4 col6" >8</td>
#       <td id="T_6763f_row4_col7" class="data row4 col7" >8</td>
#       <td id="T_6763f_row4_col8" class="data row4 col8" >4</td>
#     </tr>
#     <tr>
#       <th id="T_6763f_level0_row5" class="row_heading level0 row5" >unproductive</th>
#       <td id="T_6763f_row5_col0" class="data row5 col0" >2</td>
#       <td id="T_6763f_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_6763f_row5_col2" class="data row5 col2" >1</td>
#       <td id="T_6763f_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_6763f_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_6763f_row5_col5" class="data row5 col5" >2</td>
#       <td id="T_6763f_row5_col6" class="data row5 col6" >1</td>
#       <td id="T_6763f_row5_col7" class="data row5 col7" >2</td>
#       <td id="T_6763f_row5_col8" class="data row5 col8" >5</td>
#     </tr>
#     <tr>
#       <th id="T_6763f_level0_row6" class="row_heading level0 row6" >woods</th>
#       <td id="T_6763f_row6_col0" class="data row6 col0" >24</td>
#       <td id="T_6763f_row6_col1" class="data row6 col1" >28</td>
#       <td id="T_6763f_row6_col2" class="data row6 col2" >26</td>
#       <td id="T_6763f_row6_col3" class="data row6 col3" >30</td>
#       <td id="T_6763f_row6_col4" class="data row6 col4" >29</td>
#       <td id="T_6763f_row6_col5" class="data row6 col5" >32</td>
#       <td id="T_6763f_row6_col6" class="data row6 col6" >31</td>
#       <td id="T_6763f_row6_col7" class="data row6 col7" >33</td>
#       <td id="T_6763f_row6_col8" class="data row6 col8" >38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# __Below:__ Chart of different land use profiles at different buffer radiuses

# %%
data =total_radius.values
labels = total_radius.index
colors = total_radius.index
xlabels = [str(x) for x in total_radius.columns]

colors = ['bisque','lightcoral','k','orchid','lightgrey','saddlebrown', 'forestgreen']

bottom = [0]*(len(total_radius.columns))

width = 0.8      # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(8,5))

for i,group in enumerate(data):
    ax.bar(xlabels, group, width, bottom=bottom, label=labels[i], color = colors[i])
    bottom += group


ax.set_ylabel('Land-use profile [%]', fontsize=16)

ax.set_xlabel("Buffer zone radius [m]", labelpad =15, fontsize=16)
ax.set_facecolor('white')

ax.spines['top'].set_color('0.5')
ax.spines['right'].set_color('0.5')
ax.spines['bottom'].set_color('0.5')
ax.spines['left'].set_color('0.5')
ax.set_ylim(0,100)

ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(labelcolor='k', labelsize=14, width=1)

ax.legend(bbox_to_anchor=(1,1), facecolor = 'white', fontsize=14)

plt.show()

# %% [markdown]
# ### Sum of the total number of objects with a correlation (positive or negative) collected under the different land use categories

# %%
def numberOfObjectsCorrelatedPerAttribute(rho_at_buffer: pdtype = None, df: pdtype = None) -> pdtype:
    
    # select all the codes that have a p-value less than 0.05
    p_less_than = rho_at_buffer[rho_at_buffer.exact_p <= 0.05]

    # group the codes by land use attribute
    p_less_than_use_codes = p_less_than.groupby("use").code.unique()

    # sume the number of objects with a correlation (positive or negative) for each land use attribute
    results = nObjectsPerLandUse(p_less_than_use_codes,df)
    
    return results

numberOfObjectsCorrelatedPerAttribute(rho_at_buffer, df)
# Out:
#               total
# agriculture   29679
# buildings     18225
# industrial    14762
# intersects    20688
# recreation    26231
# roads         17108
# unproductive  21316
# woods         21047

# %% [markdown]
# ### The % total of materials of the objects of interest with respect to the total number of objects collected.

# %%
def thePercentTotalOfMaterials(codes, df, materialmap):
    
    total = df.quantity.sum()
    buffer_codes = df[df.code.isin(codes)].copy()
    buffer_codes["material"] = buffer_codes.code.apply(lambda x: materialmap[x])
    
    material_df = pd.DataFrame(buffer_codes.groupby("material").quantity.sum()/total).round(3)
    
    material_df["quantity"] = material_df.quantity.apply(lambda x: f'{int((x*100))}%')
    
    return material_df

thePercentTotalOfMaterials(codes_fail, df, code_m_map)
# Out:
#          quantity
# material
# Cloth          0%
# Glass          5%
# Metal          2%
# Paper          1%
# Plastic       75%

# %% [markdown]
# ### The % total of the objects of interest with respect to all objects collected.

# %%
def thePercentTotalOfTheTopXObjects(df, codes):
    index = [f'ratio of the items of interest over all items:',f'number of items of interest:']
    item_totals = df.groupby("code").quantity.sum().sort_values(ascending=False)
    top_x = item_totals.loc[codes].sum()
    total = df.quantity.sum()
    data = [f"{(round((top_x /total)*100))}%","{:,}".format(round(top_x))]
    return pd.DataFrame(data=data, index=index, columns=["value"])

thePercentTotalOfTheTopXObjects(df,codes_fail)
# Out:
#                                                  value
# ratio of the items of interest over all items:     84%
# number of items of interest:                    39,442

# %% [markdown]
# ### The cumulative totals of the objects of interest, grouped by economic source
#
# The object of interest were grouped according to economic source by considering the possible uses for each object, as defined in the object description and sources columns of the default codes data:
#
# 1. tobaco: "Tobacco", "Smoking related"
# 2. industry: 'Industry','Construction', 'Industrial', 'Manufacturing'
# 3. sanitary: "Sanitary", "Personal hygiene", "Water treatment"
# 4. packaging: 'Packaging (non-food)','Packaging films nonfood or unknown', 'Paper packaging'
# 5. food:  'Food and drinks','Foil wrappers, aluminum foil', 'Food and drinks', 'Food and drink'
# 6. fragments: 'Plastic fragments and pieces', 'Plastic fragments angular <5mm', 'Styrofoam < 5mm', 'Plastic fragments rounded <5mm', 'Foamed  plastic <5mm', 'Fragmented plastics'

# %%
def check_condition(x, conditions, i):
    
    if list(set(x)&set(conditions[i])):
        data = conditions[i][0]        
    elif i == 0 and not list(set(x)&set(conditions[i])):
        data = "Others"    
    else:
        data = check_condition(x, conditions, i-1)
    return data

# define the broad categories:
tobaco = ["Tobacco", "Smoking related"]
industry = ['Industry','Construction', 'Industrial', 'Manufacturing']
sanitary = ["Sanitary", "Personal hygiene", "Water treatment"]
packaging = ['Packaging (non-food)','Packaging films nonfood or unknown', 'Paper packaging']
food = ['Food and drinks','Foil wrappers, aluminum foil', 'Food and drinks', 'Food and drink']
fragments = ['Plastic fragments and pieces',
             'Plastic fragments angular <5mm',
             'Styrofoam < 5mm', 
             'Plastic fragments rounded <5mm',
             'Foamed  plastic <5mm',
             'Fragmented plastics',
            ]

conditions = [tobaco, industry, sanitary, packaging, food, fragments]


dT20 = df[df.code.isin(codes_fail)].groupby("code", as_index=False).quantity.sum().sort_values("quantity", ascending=False)
dT20["description"] = dT20.code.map(lambda x: code_d_map[x])
dT20.set_index("code", drop=True, inplace=True)

    
for each_code in dT20.index:
    srcs = dfCodes.loc[each_code][["source", "source_two", "source_three", "description"]]
    a = check_condition(srcs.values, conditions, len(conditions)-1)
    dT20.loc[each_code, "Type"] = a
    
total_type = dT20.groupby(["Type"], as_index=False).quantity.sum()
total_type["Proportion [%]"] = ((total_type.quantity/df.quantity.sum())*100).round(1)
total_type.style.format(precision=1).set_table_styles(table_css_styles)
# Out:
# <style type="text/css">
# #T_19e82 tr:nth-child(even) {
#   background-color: rgba(139, 69, 19, 0.08);
# }
# #T_19e82 tr:nth-child(odd) {
#   background: #FFF;
# }
# #T_19e82 tr {
#   font-size: 12px;
# }
# #T_19e82 th:nth-child(1) {
#   background-color: #FFF;
# }
# </style>
# <table id="T_19e82">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_19e82_level0_col0" class="col_heading level0 col0" >Type</th>
#       <th id="T_19e82_level0_col1" class="col_heading level0 col1" >quantity</th>
#       <th id="T_19e82_level0_col2" class="col_heading level0 col2" >Proportion [%]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19e82_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19e82_row0_col0" class="data row0 col0" >Food and drinks</td>
#       <td id="T_19e82_row0_col1" class="data row0 col1" >7652</td>
#       <td id="T_19e82_row0_col2" class="data row0 col2" >16.3</td>
#     </tr>
#     <tr>
#       <th id="T_19e82_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19e82_row1_col0" class="data row1 col0" >Industry</td>
#       <td id="T_19e82_row1_col1" class="data row1 col1" >10060</td>
#       <td id="T_19e82_row1_col2" class="data row1 col2" >21.5</td>
#     </tr>
#     <tr>
#       <th id="T_19e82_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19e82_row2_col0" class="data row2 col0" >Others</td>
#       <td id="T_19e82_row2_col1" class="data row2 col1" >3001</td>
#       <td id="T_19e82_row2_col2" class="data row2 col2" >6.4</td>
#     </tr>
#     <tr>
#       <th id="T_19e82_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_19e82_row3_col0" class="data row3 col0" >Packaging (non-food)</td>
#       <td id="T_19e82_row3_col1" class="data row3 col1" >971</td>
#       <td id="T_19e82_row3_col2" class="data row3 col2" >2.1</td>
#     </tr>
#     <tr>
#       <th id="T_19e82_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_19e82_row4_col0" class="data row4 col0" >Plastic fragments and pieces</td>
#       <td id="T_19e82_row4_col1" class="data row4 col1" >6943</td>
#       <td id="T_19e82_row4_col2" class="data row4 col2" >14.8</td>
#     </tr>
#     <tr>
#       <th id="T_19e82_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_19e82_row5_col0" class="data row5 col0" >Sanitary</td>
#       <td id="T_19e82_row5_col1" class="data row5 col1" >2381</td>
#       <td id="T_19e82_row5_col2" class="data row5 col2" >5.1</td>
#     </tr>
#     <tr>
#       <th id="T_19e82_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_19e82_row6_col0" class="data row6 col0" >Tobacco</td>
#       <td id="T_19e82_row6_col1" class="data row6 col1" >8434</td>
#       <td id="T_19e82_row6_col2" class="data row6 col2" >18.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(figsize=(7,9))
colors = {'Industry': 'firebrick', 'Tobacco': 'darkslategrey', 'Food and drinks': 'navy', 'Plastic fragments and pieces':'lightgrey',
         'Others':'linen','Sanitary':'plum','Packaging (non-food)':'saddlebrown'}

width = 0.6

labels = list(colors.keys())
handles = [plt.Rectangle((0,0),1,1, color=colors[label]) for label in labels]

ax.barh(dT20.description, dT20.quantity, color=[colors[i] for i in dT20.Type], edgecolor='darkgrey')
ax.invert_yaxis()  
ax.set_ylabel('')
xticks = [0,1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]
ax.set_xticks(xticks)
ax.set_xticklabels([str(x) for x in xticks])


ax.set_xlabel('Total item count', fontsize=16, labelpad =15)
ax.xaxis.set_ticks_position('bottom')
ax.yaxis.set_ticks_position('left')
ax.tick_params(labelcolor='k', labelsize=10, width=1)
ax.yaxis.grid(color='lightgray')
ax.xaxis.grid(color='lightgray')
ax.set_facecolor('white')

plt.legend(handles, labels, fontsize=13,facecolor='white', loc="lower right")
for ha in ax.legend_.legendHandles:
    ha.set_edgecolor("darkgrey")

plt.grid(True)
ax.spines['top'].set_color('0.5')
ax.spines['right'].set_color('0.5')
ax.spines['bottom'].set_color('0.5')
ax.spines['left'].set_color('0.5')

# plt.savefig('C:/Users/schre086/figures/land_use_ch/top_20items.png', bbox_inches='tight')

plt.show()

# %% [markdown]
# #### Litter items of local origin
#
# Items that have four or more positive associations with a land use category.

# %%
correlated = rho_at_buffer[(rho_at_buffer.exact_p <= 0.05) & (rho_at_buffer.rho > 0)]
local = correlated.code.value_counts()
local = local[local >= 4]
local.name = "correlations"
quantity = df[df.code.isin(local.index)].groupby("code").quantity.sum()
items_of_local_origin = pd.DataFrame([local, quantity]).T
items_of_local_origin
# Out:
#       correlations  quantity
# G27              4      7821
# G904             4       279
# G177             4       482

# %% [markdown]
# #### Ubiquitous items
#
# Items that have three or less positive associations with a land use category and are positively associated with river or stream intersections.

# %%
correlated = rho_at_buffer[(rho_at_buffer.exact_p <= 0.05) & (rho_at_buffer.rho > 0)]
pos_intersects = rho_at_buffer[(rho_at_buffer.use == "intersects") & (rho_at_buffer.exact_p <= 0.05)]
correlated = correlated[correlated.code.isin(pos_intersects.code.unique())]
local = correlated.code.value_counts()
local = local[local <= 3]
local.name = "correlations"
quantity = df[df.code.isin(local.index)].groupby("code").quantity.sum()
items_of_local_origin = pd.DataFrame([local, quantity]).T
items_of_local_origin
# Out:
#         correlations  quantity
# G98                3       581
# G941               3       857
# G178               3       668
# G21                2       593
# G23                2       405
# Gfrags             2      6943
# G74                2      1546
# G67                1      2221
# G10                1       422
# G89                1       916
# G70                1       390
# G944               1        34
# Gfoam              1      4833

# %% [markdown]
# #### Other items
#
# Items that have three or less positive associations with a land use category and are NOT positively associated with river or stream intersections.

# %%
correlated = rho_at_buffer[(rho_at_buffer.exact_p <= 0.05) & (rho_at_buffer.rho > 0)]
pos_intersects = rho_at_buffer[(rho_at_buffer.use == "intersects") & (rho_at_buffer.exact_p > 0.05)]
correlated = correlated[correlated.code.isin(pos_intersects.code.unique())]
local = correlated.code.value_counts()
local = local[local <= 3]
local.name = "correlations"
quantity = df[df.code.isin(local.index)].groupby("code").quantity.sum()
items_of_local_origin = pd.DataFrame([local, quantity]).T
items_of_local_origin
# Out:
#       correlations  quantity
# G30              3      3159
# G923             3       223
# G3               2       277
# G25              2       613
# G24              2       509
# G200             1      2051
# G95              1      1369
# G208             1       165
# G940             1       131
# G922             1       233

# %% [markdown]
# ## Annex
# Land-use attributes of the survey locations.

# %%
results = buffer_vals.T.round(3)

res = results[display_columns].style.format(precision=3).set_table_styles(table_css_styles)

glue("all_luse", res, display=False)

# %% [markdown]
# ```{glue:figure} all_luse
# ---
# name: all_luse
# ---
# ` `
# ```
# {numref}`figure %s: <all_luse>` The land use attributes of the survey locations @ 1 500 m radius

# %%
today = dt.datetime.now().date().strftime("%d/%m/%Y")
where = "Biel, CH"

my_block = f"""

This script updated {today} in {where}

> \u2764\ufe0f what you do everyday

_ANALYSTATHAMMERDIRT_
"""

md(my_block)
